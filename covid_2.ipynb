# %%
from google.colab import files

# Install Kaggle library
# !pip install  kaggle

# !mkdir .kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.4.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# mkdir: cannot create directory ‘.kaggle’: File exists

# %%
import json
token = {"username":"abolimarathe","key":"53f6206052b7e46e5736781e4a76ca15"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}
# Out:
# - path is now set to: {/content}

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                           title                                                size  lastUpdated          downloadCount
# ------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# allen-institute-for-ai/CORD-19-research-challenge             COVID-19 Open Research Dataset Challenge (CORD-19)    3GB  2020-06-03 23:32:41          71785
# roche-data-science-coalition/uncover                          UNCOVER COVID-19 Challenge                          179MB  2020-05-21 18:57:53          10483
# stefanlarson/outofscope-intent-classification-dataset         Out-of-Scope Intent Classification Dataset          285KB  2020-05-15 03:04:34              1
# gomes555/road-transport-brazil                                Road transport dataset in brazil                     62MB  2020-05-26 02:52:34              4
# kushshah95/the-insurance-company-tic-benchmark                The Insurance Company (TIC) Benchmark               262KB  2020-05-27 16:36:41              1
# ruchi798/tv-shows-on-netflix-prime-video-hulu-and-disney      TV shows on Netflix, Prime Video, Hulu and Disney+   88KB  2020-05-25 15:38:39             12
# ruchi798/movies-on-netflix-prime-video-hulu-and-disney        Movies on Netflix, Prime Video, Hulu and Disney+    627KB  2020-05-22 23:48:01             47
# ruchi798/malnutrition-across-the-globe                        Malnutrition across the globe                        79KB  2020-05-25 09:51:45             14
# rmjacobsen/property-listings-for-5-south-american-countries   Property Listings for 5 South American Countries    475MB  2020-05-25 02:05:38              1
# jessicali9530/animal-crossing-new-horizons-nookplaza-dataset  Animal Crossing New Horizons NookPlaza Catalog      577KB  2020-05-18 22:50:26             42
# biancaferreira/african-wildlife                               African Wildlife                                    448MB  2020-05-25 13:42:19              2
# siddharthm1698/coursera-course-dataset                        Coursera Course Dataset                              23KB  2020-05-25 05:52:27             10
# yamaerenay/spotify-dataset-19212020-160k-tracks               Spotify Dataset 1921-2020, 160k+ Tracks              17MB  2020-05-25 11:31:07             24
# kianwee/agricultural-raw-material-prices-19902020             Agricultural Raw Material prices (1990-2020)         23KB  2020-05-27 04:51:29              0
# devinaconley/covid19-mobility-data                            COVID-19 Google mobility data                         4MB  2020-06-04 12:15:15              2
# benroshan/factors-affecting-campus-placement                  Campus Recruitment                                    5KB  2020-04-11 11:09:02           5523
# bobbyscience/league-of-legends-diamond-ranked-games-10-min    League of Legends Diamond Ranked Games (10 min)     539KB  2020-04-13 13:53:02           2542
# fireballbyedimyrnmom/us-counties-covid-19-dataset             US counties COVID 19 dataset                          2MB  2020-06-04 11:17:03           7247
# divyansh22/flight-delay-prediction                            January Flight Delay Prediction                      23MB  2020-04-14 13:15:41           1850
# clmentbisaillon/fake-and-real-news-dataset                    Fake and real news dataset                           41MB  2020-03-26 18:51:15           4998

# %%
# !kaggle datasets download -d smid80/coronavirus-covid19-tweets-early-april -p /content
# Out:
# coronavirus-covid19-tweets-early-april.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip \*.zip
# Out:
# Archive:  coronavirus-covid19-tweets-early-april.zip
# replace 2020-03-29 Coronavirus Tweets.CSV? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
from gensim import models, corpora 
import spacy
import re
from spacy.tokenizer import Tokenizer
from spacy.tokenizer import _get_regex_pattern
nlp = spacy.load("en_core_web_sm") 
import numpy as np 
from nltk.corpus import stopwords
import nltk 
import pandas as pd

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
d1 = pd.read_csv("2020-03-29 Coronavirus Tweets.CSV")
d2 = pd.read_csv("2020-03-30 Coronavirus Tweets.CSV")
d3 = pd.read_csv("2020-03-31 Coronavirus Tweets.CSV")
d4 = pd.read_csv("2020-04-01 Coronavirus Tweets.CSV")
d5 = pd.read_csv("2020-04-02 Coronavirus Tweets.CSV")
d6 = pd.read_csv("2020-04-03 Coronavirus Tweets.CSV")
d7 = pd.read_csv("2020-04-04 Coronavirus Tweets.CSV")
d8 = pd.read_csv("2020-04-05 Coronavirus Tweets.CSV")
d9 = pd.read_csv("2020-04-06 Coronavirus Tweets.CSV")
d10 = pd.read_csv("2020-04-07 Coronavirus Tweets.CSV")
d11 = pd.read_csv("2020-04-08 Coronavirus Tweets.CSV")
d12 = pd.read_csv("2020-04-09 Coronavirus Tweets.CSV")
d13 = pd.read_csv("2020-04-10 Coronavirus Tweets.CSV")
d14 = pd.read_csv("2020-04-11 Coronavirus Tweets.CSV")
d15 = pd.read_csv("2020-04-12 Coronavirus Tweets.CSV")
d16 = pd.read_csv("2020-04-13 Coronavirus Tweets.CSV")
d17 = pd.read_csv("2020-04-14 Coronavirus Tweets.CSV")
d18 = pd.read_csv("2020-04-15 Coronavirus Tweets.CSV")

# %%
d1= d1[['text','lang','country_code','created_at']]
d1 = d1[d1['lang']=='en']

d2= d2[['text','lang','country_code','created_at']]
d2 = d2[d2['lang']=='en']

d3= d3[['text','lang','country_code','created_at']]
d3 = d3[d3['lang']=='en']

d4= d4[['text','lang','country_code','created_at']]
d4 = d4[d4['lang']=='en']

d5= d5[['text','lang','country_code','created_at']]
d5 = d5[d5['lang']=='en']

d6= d6[['text','lang','country_code','created_at']]
d6 = d6[d6['lang']=='en']

d7= d7[['text','lang','country_code','created_at']]
d7 = d7[d7['lang']=='en']

d8= d8[['text','lang','country_code','created_at']]
d8 = d8[d8['lang']=='en']

d9= d9[['text','lang','country_code','created_at']]
d9 = d9[d9['lang']=='en']

d10= d10[['text','lang','country_code','created_at']]
d10 = d10[d10['lang']=='en']

d11= d11[['text','lang','country_code','created_at']]
d11 = d11[d11['lang']=='en']

d12= d12[['text','lang','country_code','created_at']]
d12 = d12[d12['lang']=='en']

d13= d13[['text','lang','country_code','created_at']]
d13 = d13[d13['lang']=='en']

d14= d14[['text','lang','country_code','created_at']]
d14 = d14[d14['lang']=='en']

d15= d15[['text','lang','country_code','created_at']]
d15 = d15[d15['lang']=='en']

d16= d16[['text','lang','country_code','created_at']]
d16 = d16[d16['lang']=='en']

d17= d17[['text','lang','country_code','created_at']]
d17 = d17[d17['lang']=='en']

d18= d18[['text','lang','country_code','created_at']]
d18 = d18[d18['lang']=='en']

# %%
d1.dropna(inplace=True)
d2.dropna(inplace=True)
d3.dropna(inplace=True)
d4.dropna(inplace=True)
d5.dropna(inplace=True)
d6.dropna(inplace=True)
d7.dropna(inplace=True)
d8.dropna(inplace=True)
d9.dropna(inplace=True)
d10.dropna(inplace=True)
d11.dropna(inplace=True)
d12.dropna(inplace=True)
d13.dropna(inplace=True)
d14.dropna(inplace=True)
d15.dropna(inplace=True)
d16.dropna(inplace=True)
d17.dropna(inplace=True)
d18.dropna(inplace=True)

# %%
d3
# Out:
#                                                      text  ...            created_at
# 203     This is how far back they have to put the swab...  ...  2020-03-31T00:00:04Z
# 220     Mayor @KeishaBottoms to WH on #COVID19 - “Allo...  ...  2020-03-31T00:00:05Z
# 394     Big trip 5 mi to north...checked out Yountvill...  ...  2020-03-31T00:00:18Z
# 435     Nurses are being threatened and disciplined fo...  ...  2020-03-31T00:00:21Z
# 485     What colour is that virus? #coronavirus https:...  ...  2020-03-31T00:00:25Z
# ...                                                   ...  ...                   ...
# 669727  YOU OK WITH THIS DOCTOR SENATOR @BillCassidy ?...  ...  2020-03-31T23:59:40Z
# 669736  This a good look? 😷\n▪️▪️▪️\n▪️▪️▪️\n#coronavi...  ...  2020-03-31T23:59:42Z
# 669753  Every question from each journalist at tomorro...  ...  2020-03-31T23:59:46Z
# 669789  This may be the first time I actually want som...  ...  2020-03-31T23:59:53Z
# 669795  It’s my Birthday 🎂 #stuck #inside #coronavirus...  ...  2020-03-31T23:59:54Z
#
# [18381 rows x 4 columns]

# %%
d1.reset_index(inplace = True) 
d2.reset_index(inplace = True)
d3.reset_index(inplace = True)
d4.reset_index(inplace = True)
d5.reset_index(inplace = True)
d6.reset_index(inplace = True)
d7.reset_index(inplace = True)
d8.reset_index(inplace = True)
d9.reset_index(inplace = True)
d10.reset_index(inplace = True)
d11.reset_index(inplace = True)
d12.reset_index(inplace = True)
d13.reset_index(inplace = True)
d14.reset_index(inplace = True)
d15.reset_index(inplace = True)
d16.reset_index(inplace = True)
d17.reset_index(inplace = True)
d18.reset_index(inplace = True)










new = d1["created_at"].str.split("T", n = 1, expand = True)
d1["date"]= new[0] 
d1["time"]= new[1] 

new = d2["created_at"].str.split("T", n = 1, expand = True)
d2["date"]= new[0] 
d2["time"]= new[1] 

new = d3["created_at"].str.split("T", n = 1, expand = True)
d3["date"]= new[0] 
d3["time"]= new[1] 

new = d4["created_at"].str.split("T", n = 1, expand = True)
d4["date"]= new[0] 
d4["time"]= new[1] 

new = d5["created_at"].str.split("T", n = 1, expand = True)
d5["date"]= new[0] 
d5["time"]= new[1] 

new = d6["created_at"].str.split("T", n = 1, expand = True)
d6["date"]= new[0] 
d6["time"]= new[1] 

new = d7["created_at"].str.split("T", n = 1, expand = True)
d7["date"]= new[0] 
d7["time"]= new[1] 

new = d8["created_at"].str.split("T", n = 1, expand = True)
d8["date"]= new[0] 
d8["time"]= new[1] 

new = d9["created_at"].str.split("T", n = 1, expand = True)
d9["date"]= new[0] 
d9["time"]= new[1] 

new = d10["created_at"].str.split("T", n = 1, expand = True)
d10["date"]= new[0] 
d10["time"]= new[1] 

new = d11["created_at"].str.split("T", n = 1, expand = True)
d11["date"]= new[0] 
d11["time"]= new[1] 

new = d12["created_at"].str.split("T", n = 1, expand = True)
d12["date"]= new[0] 
d12["time"]= new[1] 

new = d13["created_at"].str.split("T", n = 1, expand = True)
d13["date"]= new[0] 
d13["time"]= new[1] 

new = d14["created_at"].str.split("T", n = 1, expand = True)
d14["date"]= new[0] 
d14["time"]= new[1] 

new = d15["created_at"].str.split("T", n = 1, expand = True)
d15["date"]= new[0] 
d15["time"]= new[1] 

new = d16["created_at"].str.split("T", n = 1, expand = True)
d16["date"]= new[0] 
d16["time"]= new[1] 

new = d17["created_at"].str.split("T", n = 1, expand = True)
d17["date"]= new[0] 
d17["time"]= new[1] 

new = d18["created_at"].str.split("T", n = 1, expand = True)
d18["date"]= new[0] 
d18["time"]= new[1]

# %%
len(d1) +len(d2)+len(d3)+len(d4)+len(d5)+len(d6)+len(d7)+len(d8)+len(d9)+len(d10)+len(d11)+len(d12)+len(d13)+len(d14)+len(d15)+len(d16)+len(d17)+len(d18)
# Out:
# 230769

# %%
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
d1
# Out:
#         index  ...       time
# 0         293  ...  00:00:16Z
# 1         393  ...  00:00:29Z
# 2         481  ...  00:00:39Z
# 3         499  ...  00:00:42Z
# 4         500  ...  00:00:42Z
# ...       ...  ...        ...
# 17850  564053  ...  23:59:41Z
# 17851  564102  ...  23:59:52Z
# 17852  564113  ...  23:59:54Z
# 17853  564114  ...  23:59:54Z
# 17854  564119  ...  23:59:55Z
#
# [17855 rows x 7 columns]

# %%
d1 = d1.append(d2)
d1 =d1.append(d3)
d1 =d1.append(d4)
d1 =d1.append(d5)
d1 =d1.append(d6)
d1 =d1.append(d7)
d1 =d1.append(d8)
d1 =d1.append(d9)
d1 =d1.append(d10)
d1 =d1.append(d11)
d1 =d1.append(d12)
d1 =d1.append(d13)
d1 =d1.append(d14)
d1 =d1.append(d15)
d1 =d1.append(d16)
d1 =d1.append(d17)
d1 =d1.append(d18)

# %%
hashtags = d1['text'].apply(lambda x: re.findall(r'\B#\w*[a-zA-Z]+\w*',x))
print(hashtags)
print(len(hashtags))
d1['hashtag'] = hashtags
# Out:
# 0                                              [#Covid_19]
# 1                                               [#COVID19]
# 2                                               [#COVID19]
# 3        [#covid19, #cavalierkingcharles, #daftdug, #La...
# 4                                 [#Covid_19, #medtwitter]
#                                ...
# 11415        [#WHO, #COVID19, #coronavirus, #GlobalHealth]
# 11416             [#COVID19, #everyproblemisanopportunity]
# 11417                             [#coronavirus, #Science]
# 11418                                           [#COVID19]
# 11419                               [#CoronavirusPandemic]
# Name: text, Length: 230769, dtype: object
# 230769

# %%
len(d1)
# Out:
# 230769

# %%
d1
# Out:
#         index  ...                                            hashtag
# 0         293  ...                                        [#Covid_19]
# 1         393  ...                                         [#COVID19]
# 2         481  ...                                         [#COVID19]
# 3         499  ...  [#covid19, #cavalierkingcharles, #daftdug, #La...
# 4         500  ...                           [#Covid_19, #medtwitter]
# ...       ...  ...                                                ...
# 11415  475039  ...      [#WHO, #COVID19, #coronavirus, #GlobalHealth]
# 11416  475072  ...           [#COVID19, #everyproblemisanopportunity]
# 11417  475075  ...                           [#coronavirus, #Science]
# 11418  475191  ...                                         [#COVID19]
# 11419  475199  ...                             [#CoronavirusPandemic]
#
# [230769 rows x 8 columns]

# %%
d1.reset_index(inplace=True)
from nltk.tokenize import TweetTokenizer
tweet_tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])

# Sad Emoticons
emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])

#Emoji patterns
emoji_pattern = re.compile("["
         u"\U0001F600-\U0001F64F"  # emoticons
         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
         u"\U0001F680-\U0001F6FF"  # transport & map symbols
         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
         u"\U00002702-\U000027B0"
         u"\U000024C2-\U0001F251"
         "]+", flags=re.UNICODE)


#combine sad and happy emoticons
emoticons = emoticons_happy.union(emoticons_sad)

def clean_tweets(tweet):
 
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(tweet)
    #removing mentions
    tweet = re.sub(r':', '', tweet)
    tweet = re.sub(r'‚Ä¶', '', tweet)
#replace consecutive non-ASCII characters with a space
    tweet = re.sub(r'[^\x00-\x7F]+',' ', tweet)
#remove emojis from tweet
    tweet = emoji_pattern.sub(r'', tweet)
#filter using NLTK library append it to a string
    filtered_tweet = [w for w in word_tokens if not w in stop_words]
    filtered_tweet = []
#looping through conditions
    for w in word_tokens:
#check tokens against stop words , emoticons and punctuations
        if w not in stop_words and w not in emoticons and w not in string.punctuation:
            filtered_tweet.append(w)
    return ' '.join(filtered_tweet)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re #regular expressions
import string 

from nltk.corpus import stopwords
from nltk import word_tokenize

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

reuse = False
i =0 

for tweet in d1["text"]:
  
   d1.at[i,"text"] = clean_tweets(tweet)
   i = i+1

# %%
d1
# Out:
#         level_0  ...                                            hashtag
# 0             0  ...                                        [#Covid_19]
# 1             1  ...                                         [#COVID19]
# 2             2  ...                                         [#COVID19]
# 3             3  ...  [#covid19, #cavalierkingcharles, #daftdug, #La...
# 4             4  ...                           [#Covid_19, #medtwitter]
# ...         ...  ...                                                ...
# 230764    11415  ...      [#WHO, #COVID19, #coronavirus, #GlobalHealth]
# 230765    11416  ...           [#COVID19, #everyproblemisanopportunity]
# 230766    11417  ...                           [#coronavirus, #Science]
# 230767    11418  ...                                         [#COVID19]
# 230768    11419  ...                             [#CoronavirusPandemic]
#
# [230769 rows x 9 columns]

# %%
d1['text']= d1['text'].replace({'\n':" ","\t":" "})

# %%
# !pip install tweet-preprocessor
# Out:
# Requirement already satisfied: tweet-preprocessor in /usr/local/lib/python3.6/dist-packages (0.6.0)

# %%
import dask.dataframe as dsk
import multiprocessing as mp
from dask.multiprocessing import get
import preprocessor as p

ddf = dsk.from_pandas(d1,npartitions=4*mp.cpu_count())

# %%
ddf['text'] = ddf['text'].map_partitions(lambda x: x.apply(p.clean),meta=('clean_text','str')).compute(scheduler='processes')

# %%
df = ddf.compute(scheduler='processes')
df.head()
# Out:
#    level_0  index  ...       time                                            hashtag
# 0        0    293  ...  00:00:16Z                                        [#Covid_19]
# 1        1    393  ...  00:00:29Z                                         [#COVID19]
# 2        2    481  ...  00:00:39Z                                         [#COVID19]
# 3        3    499  ...  00:00:42Z  [#covid19, #cavalierkingcharles, #daftdug, #La...
# 4        4    500  ...  00:00:42Z                           [#Covid_19, #medtwitter]
#
# [5 rows x 9 columns]

# %%
from textblob import TextBlob

def get_sentiment(text):
    blob = TextBlob(text)
    return [blob.sentiment.polarity, blob.sentiment.subjectivity]

# %%
polarity,subjectivity = [], []
for i in range(len(df)):
    pol , sub = get_sentiment(df['text'][i])
    polarity.append(pol)
    subjectivity.append(sub)
    
df['polarity'] = polarity
df['subjectivity'] = subjectivity
df.head()
# Out:
#    level_0  index  ... polarity subjectivity
# 0        0    293  ...    0.000     0.000000
# 1        1    393  ...    0.200     0.200000
# 2        2    481  ...   -0.525     0.700000
# 3        3    499  ...    0.250     0.333333
# 4        4    500  ...   -0.150     0.512500
#
# [5 rows x 11 columns]

# %%
i =0 

for tweet in d1["text"]:
  
   d1.at[i,"text"] = word_tokenize(tweet)
   
   i = i + 1

# %%
d1
# Out:
#         level_0  ...                                            hashtag
# 0             0  ...                                        [#Covid_19]
# 1             1  ...                                         [#COVID19]
# 2             2  ...                                         [#COVID19]
# 3             3  ...  [#covid19, #cavalierkingcharles, #daftdug, #La...
# 4             4  ...                           [#Covid_19, #medtwitter]
# ...         ...  ...                                                ...
# 230764    11415  ...      [#WHO, #COVID19, #coronavirus, #GlobalHealth]
# 230765    11416  ...           [#COVID19, #everyproblemisanopportunity]
# 230766    11417  ...                           [#coronavirus, #Science]
# 230767    11418  ...                                         [#COVID19]
# 230768    11419  ...                             [#CoronavirusPandemic]
#
# [230769 rows x 9 columns]

# %%
i =0 

for tweet in d1["text"]:
  
   d1.at[i,"text"] = str(tweet).lower()
   
   i = i + 1

# %%
d1
# Out:
#         level_0  ...                                            hashtag
# 0             0  ...                                        [#Covid_19]
# 1             1  ...                                         [#COVID19]
# 2             2  ...                                         [#COVID19]
# 3             3  ...  [#covid19, #cavalierkingcharles, #daftdug, #La...
# 4             4  ...                           [#Covid_19, #medtwitter]
# ...         ...  ...                                                ...
# 230764    11415  ...      [#WHO, #COVID19, #coronavirus, #GlobalHealth]
# 230765    11416  ...           [#COVID19, #everyproblemisanopportunity]
# 230766    11417  ...                           [#coronavirus, #Science]
# 230767    11418  ...                                         [#COVID19]
# 230768    11419  ...                             [#CoronavirusPandemic]
#
# [230769 rows x 9 columns]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

stop_words = set(stopwords.words('english')) 
  
i =0 

for tweet in d1["text"]:
     
  word_tokens = tweet
  
  filtered_sentence = [w for w in word_tokens if not w in stop_words] 

  d1.at[i,"text"] = filtered_sentence

  i = i + 1

# %%
# !pip install pyLDAvis
# !pip install --upgrade gensim
# Out:
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.6/dist-packages (2.1.2)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.0.4)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: jinja2>=2.7.2 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (2.11.2)
# Requirement already satisfied: funcy in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.14)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (0.15.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (3.6.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (2.7.1)
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (0.34.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.18.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.17.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.17.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2>=2.7.2->pyLDAvis) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (8.3.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (1.4.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (1.8.1)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (0.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (47.1.1)
# Requirement already up-to-date: gensim in /usr/local/lib/python3.6/dist-packages (3.8.3)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (2.0.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.18.4)
# Requirement already satisfied, skipping upgrade: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (1.13.19)
# Requirement already satisfied, skipping upgrade: boto in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (2.23.0)
# Requirement already satisfied, skipping upgrade: botocore<1.17.0,>=1.16.19 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (1.16.19)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (0.10.0)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (0.3.3)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2.9)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.17.0,>=1.16.19->boto3->smart-open>=1.8.1->gensim) (2.8.1)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.17.0,>=1.16.19->boto3->smart-open>=1.8.1->gensim) (0.15.2)

# %%
import nltk
import sys
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd
import os,glob
import matplotlib.pyplot as plt

import gensim #for building LDA algorithm
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def make_bigrams(texts, data_words):
  #create bigrams
  bigram = gensim.models.Phrases(data_words, min_count=1, threshold=10) # higher threshold fewer phrases.
  #faster model
  bigram_mod = gensim.models.phrases.Phraser(bigram)
  return [bigram_mod[doc] for doc in texts]

def word2id(data_lemmatized):
  #representing each word with a unique ID
  # Create Dictionary
  id2word = corpora.Dictionary(data_lemmatized)
  # Create Corpus
  texts = data_lemmatized
  # Term Document Frequency
  corpus = [id2word.doc2bow(text) for text in texts]
  return corpus, id2word
  
def build_LDA(topics_num, corpus, id2word):
  lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=topics_num, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
  
  print(lda_model.print_topics())
  return lda_model

# %%
d1.text = d1.text.astype(str)

# %%
corpus, id2word = word2id(d1.text )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-5bf1de5a1fcf> in <module>()
#       1
# ----> 2 corpus, id2word = word2id(d1.text )
#
# <ipython-input-47-30b1f9526047> in word2id(data_lemmatized)
#       9   #representing each word with a unique ID
#      10   # Create Dictionary
# ---> 11   id2word = corpora.Dictionary(data_lemmatized)
#      12   # Create Corpus
#      13   texts = data_lemmatized
#
# /usr/local/lib/python3.6/dist-packages/gensim/corpora/dictionary.py in __init__(self, documents, prune_at)
#      89
#      90         if documents is not None:
# ---> 91             self.add_documents(documents, prune_at=prune_at)
#      92
#      93     def __getitem__(self, tokenid):
#
# /usr/local/lib/python3.6/dist-packages/gensim/corpora/dictionary.py in add_documents(self, documents, prune_at)
#     210
#     211             # update Dictionary with the document
# --> 212             self.doc2bow(document, allow_update=True)  # ignore the result, here we only care about updating token ids
#     213
#     214         logger.info(
#
# /usr/local/lib/python3.6/dist-packages/gensim/corpora/dictionary.py in doc2bow(self, document, allow_update, return_missing)
#     250         """
#     251         if isinstance(document, string_types):
# --> 252             raise TypeError("doc2bow expects an array of unicode tokens on input, not a single string")
#     253
#     254         # Construct (word, frequency) mapping.
#
# TypeError: doc2bow expects an array of unicode tokens on input, not a single string

# %%
lda_model = build_LDA(10,corpus,id2word)
# Out:
# [(0, '0.000*"\'ಬ" + 0.000*"\'ಪ" + 0.000*"\'ಲ" + 0.000*"\'ರ" + 0.000*"\'ಯ" + 0.000*"\'ವ" + 0.000*"\'ಗ" + 0.000*"\'ದ" + 0.000*"\'ಿ" + 0.000*"\'ನ"'), (1, '0.352*"\'" + 0.334*"," + 0.080*"\'\'" + 0.059*"``" + 0.030*"\'n" + 0.018*"\'r" + 0.018*"\'e" + 0.017*"\'c" + 0.012*"\'u" + 0.010*"\'l"'), (2, '0.393*"\'" + 0.336*"," + 0.073*"``" + 0.063*"\'\'" + 0.020*"\'e" + 0.014*"\'n" + 0.012*"\'r" + 0.011*"\'c" + 0.008*"\'l" + 0.008*"\'u"'), (3, '0.370*"\'" + 0.315*"," + 0.091*"``" + 0.090*"\'\'" + 0.019*"\'e" + 0.015*"\'r" + 0.013*"\'n" + 0.011*"\'c" + 0.010*"\'l" + 0.007*"\'h"'), (4, '0.368*"\'" + 0.349*"," + 0.083*"\'\'" + 0.069*"``" + 0.030*"\'e" + 0.014*"\'h" + 0.010*"\'l" + 0.010*"\'n" + 0.009*"\'r" + 0.009*"\'c"'), (5, '0.000*"\'ಬ" + 0.000*"\'ಪ" + 0.000*"\'ಲ" + 0.000*"\'ರ" + 0.000*"\'ಯ" + 0.000*"\'ವ" + 0.000*"\'ಗ" + 0.000*"\'ದ" + 0.000*"\'ಿ" + 0.000*"\'ನ"'), (6, '0.000*"\'ಬ" + 0.000*"\'ಪ" + 0.000*"\'ಲ" + 0.000*"\'ರ" + 0.000*"\'ಯ" + 0.000*"\'ವ" + 0.000*"\'ಗ" + 0.000*"\'ದ" + 0.000*"\'ಿ" + 0.000*"\'ನ"'), (7, '0.363*"\'" + 0.312*"," + 0.096*"\'\'" + 0.087*"``" + 0.031*"\'e" + 0.017*"\'n" + 0.016*"\'l" + 0.013*"\'r" + 0.011*"\'p" + 0.008*"\'c"'), (8, '0.397*"\'" + 0.325*"," + 0.069*"``" + 0.056*"\'\'" + 0.028*"\'e" + 0.017*"\'r" + 0.014*"\'c" + 0.011*"\'n" + 0.009*"\'h" + 0.007*"\'/"'), (9, '0.323*"," + 0.321*"\'" + 0.061*"``" + 0.045*"\'\'" + 0.022*"\'0" + 0.016*"\'/" + 0.015*"\'2" + 0.015*"\'c" + 0.015*"\'u" + 0.015*"\'1"')]

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3      0.201929 -0.007110       1        1  19.309149
# 2      0.202749 -0.004214       2        1  17.389469
# 8      0.202875 -0.001287       3        1  17.222696
# 1      0.203348 -0.004376       4        1  13.674326
# 7      0.203915 -0.014078       5        1  13.563951
# 4      0.204192 -0.008599       6        1  13.406418
# 9      0.192206  0.040334       7        1   5.433973
# 5     -0.470404 -0.000223       8        1   0.000006
# 6     -0.470404 -0.000223       9        1   0.000006
# 0     -0.470404 -0.000223      10        1   0.000005, topic_info=     Term          Freq         Total Category  logprob  loglift
# 15      ,  3.992667e+07  3.992667e+07  Default  30.0000  30.0000
# 0       '  4.539936e+07  4.539936e+07  Default  29.0000  29.0000
# 1      ''  9.193971e+06  9.193971e+06  Default  28.0000  28.0000
# 18     ``  9.102070e+06  9.102070e+06  Default  27.0000  27.0000
# 27     '/  5.108220e+05  5.108220e+05  Default  26.0000  26.0000
# ...   ...           ...           ...      ...      ...      ...
# 1099   'え  2.040267e-03  7.014071e-01  Topic10  -8.0935  10.8799
# 1022   '𝐝  2.040267e-03  7.008390e-01  Topic10  -8.0935  10.8807
# 1112   '🍇  2.040267e-03  7.008921e-01  Topic10  -8.0935  10.8806
# 1122   'ያ  2.040267e-03  7.008377e-01  Topic10  -8.0935  10.8807
# 1121   'ወ  2.040267e-03  7.008377e-01  Topic10  -8.0935  10.8807
#
# [522 rows x 6 columns], token_table=      Topic      Freq Term
# term
# 0         1  0.192020    '
# 0         2  0.183691    '
# 0         3  0.183458    '
# 0         4  0.129236    '
# 0         5  0.132292    '
# ...     ...       ...  ...
# 47        2  0.771271    “
# 47        3  0.030395    “
# 48        1  0.163833    ”
# 48        2  0.816250    ”
# 48        3  0.019784    ”
#
# [371 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 9, 2, 8, 5, 10, 6, 7, 1])

# %%
pyLDAvis.gensim.prepare(lda_model, corpus, id2word, mds='tsne')
# Out:
# PreparedData(topic_coordinates=               x          y  topics  cluster       Freq
# topic
# 3      32.420952   8.115230       1        1  19.309149
# 2       0.648955  71.707100       2        1  17.389469
# 8      71.019684   9.971006       3        1  17.222696
# 1       3.785981  33.185135       4        1  13.674326
# 7     -42.666500  -9.222070       5        1  13.563951
# 4      -3.621689 -43.526516       6        1  13.406418
# 9      -3.632402  -4.171708       7        1   5.433973
# 5     -36.584400  35.804413       8        1   0.000006
# 6      44.391380  50.615383       9        1   0.000006
# 0      40.235809 -31.591665      10        1   0.000005, topic_info=     Term          Freq         Total Category  logprob  loglift
# 15      ,  3.992667e+07  3.992667e+07  Default  30.0000  30.0000
# 0       '  4.539936e+07  4.539936e+07  Default  29.0000  29.0000
# 1      ''  9.193971e+06  9.193971e+06  Default  28.0000  28.0000
# 18     ``  9.102070e+06  9.102070e+06  Default  27.0000  27.0000
# 27     '/  5.108220e+05  5.108220e+05  Default  26.0000  26.0000
# ...   ...           ...           ...      ...      ...      ...
# 1099   'え  2.040267e-03  7.014071e-01  Topic10  -8.0935  10.8799
# 1022   '𝐝  2.040267e-03  7.008390e-01  Topic10  -8.0935  10.8807
# 1112   '🍇  2.040267e-03  7.008921e-01  Topic10  -8.0935  10.8806
# 1122   'ያ  2.040267e-03  7.008377e-01  Topic10  -8.0935  10.8807
# 1121   'ወ  2.040267e-03  7.008377e-01  Topic10  -8.0935  10.8807
#
# [522 rows x 6 columns], token_table=      Topic      Freq Term
# term
# 0         1  0.192020    '
# 0         2  0.183691    '
# 0         3  0.183458    '
# 0         4  0.129236    '
# 0         5  0.132292    '
# ...     ...       ...  ...
# 47        2  0.771271    “
# 47        3  0.030395    “
# 48        1  0.163833    ”
# 48        2  0.816250    ”
# 48        3  0.019784    ”
#
# [371 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 9, 2, 8, 5, 10, 6, 7, 1])

# %%
pyLDAvis.gensim.prepare(lda_model, corpus, id2word, mds='mmds')
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3      0.172599 -0.108966       1        1  19.309149
# 2      0.171417 -0.107788       2        1  17.389469
# 8      0.170002 -0.105919       3        1  17.222696
# 1      0.175704 -0.104492       4        1  13.674326
# 7      0.171945 -0.113898       5        1  13.563951
# 4      0.172777 -0.111346       6        1  13.406418
# 9      0.182057 -0.062456       7        1   5.433973
# 5     -0.410311  0.230092       8        1   0.000006
# 6     -0.407174  0.235601       9        1   0.000006
# 0     -0.399017  0.249172      10        1   0.000005, topic_info=     Term          Freq         Total Category  logprob  loglift
# 15      ,  3.992667e+07  3.992667e+07  Default  30.0000  30.0000
# 0       '  4.539936e+07  4.539936e+07  Default  29.0000  29.0000
# 1      ''  9.193971e+06  9.193971e+06  Default  28.0000  28.0000
# 18     ``  9.102070e+06  9.102070e+06  Default  27.0000  27.0000
# 27     '/  5.108220e+05  5.108220e+05  Default  26.0000  26.0000
# ...   ...           ...           ...      ...      ...      ...
# 1099   'え  2.040267e-03  7.014071e-01  Topic10  -8.0935  10.8799
# 1022   '𝐝  2.040267e-03  7.008390e-01  Topic10  -8.0935  10.8807
# 1112   '🍇  2.040267e-03  7.008921e-01  Topic10  -8.0935  10.8806
# 1122   'ያ  2.040267e-03  7.008377e-01  Topic10  -8.0935  10.8807
# 1121   'ወ  2.040267e-03  7.008377e-01  Topic10  -8.0935  10.8807
#
# [522 rows x 6 columns], token_table=      Topic      Freq Term
# term
# 0         1  0.192020    '
# 0         2  0.183691    '
# 0         3  0.183458    '
# 0         4  0.129236    '
# 0         5  0.132292    '
# ...     ...       ...  ...
# 47        2  0.771271    “
# 47        3  0.030395    “
# 48        1  0.163833    ”
# 48        2  0.816250    ”
# 48        3  0.019784    ”
#
# [371 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 9, 2, 8, 5, 10, 6, 7, 1])
