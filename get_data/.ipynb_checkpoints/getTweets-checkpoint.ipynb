# %%
import tweepy as tw
import pandas as pd
import os
import csv

# %%
consumer_key = "IQFN7RfvSs3107ZGKq1vDE2Um"
consumer_secret = "JF8rB1ftzNPzNKCUGHTZXtZV22yiCK51bJnl51t1riNnLy4cuJ"
access_token = "1008966897130303488-PNJTNYKhrs5q3YbCIZf2lRGC817JSQ"
access_token_secret = "89xKwZBAZBUHLVqoayE1gDGfuJeJwzLhnkZ7NnXvOJZ6v"

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
tweets_df = pd.read_csv("tweet_ids.csv")
tweets_df.head()
# Out:
#    Unnamed: 0             tweet_id
# 0         0.0  1242693364098580481
# 1         1.0  1242693402971406342
# 2         2.0  1242693578817597442
# 3         3.0  1242693609725575168
# 4         4.0  1242693680143544325

# %%
index_manager_read = open('index_manager.txt', 'r')
indx = index_manager_read.read()
print(indx)
index_manager_read.close()
# Out:
# 1

# %%
twitter_ids = tweets_df["tweet_id"].tolist()
i = 0
indx = int(indx)
ids = twitter_ids[indx:indx + 899]

text = []
id_str = []
entities_hashtags = []
entities_symbols = []
entities = []
user_id = []
user_ion = []
time_zone = []
lang = []
created_at = []

cnt = 0

# %%
for tweet_id in ids:
    
    print("\nCurrent indx: " + str(indx))
    print("Tweets to be processed: " + str(900-cnt))
    cnt += 1 
    indx += 1
    
    try:
        print("Processing tweet. ID = " + str(tweet_id))
        
        tweet = api.get_status(tweet_id, tweet_mode = 'extended', include_entities = True)
        
        text.append(tweet.full_text)
        created_at.append(tweet.created_at)
        id_str.append(tweet.id_str)
        entities.append(tweet.entities)
        user_id.append(tweet.user.id)
        location.append(tweet.user.location)
        lang.append(tweet.lang)
        time_zone.append(tweet.user.time_zone)
        
        if(cnt%100 == 0):
            print("Text: " + str(tweet.full_text))
    except tw.error.TweepError:
      print("Error while accessing tweet. ID: " + str(tweet_id))
      pass
# Out:
# Current indx: 1
# Tweets to be processed: 900
# Processing tweet. ID = 1242693402971406342
#
# Current indx: 2
# Tweets to be processed: 899
# Processing tweet. ID = 1242693578817597442
#
# Current indx: 3
# Tweets to be processed: 898
# Processing tweet. ID = 1242693609725575168
#
# Current indx: 4
# Tweets to be processed: 897
# Processing tweet. ID = 1242693680143544325
#
# Current indx: 5
# Tweets to be processed: 896
# Processing tweet. ID = 1242693745755262977
#
# Current indx: 6
# Tweets to be processed: 895
# Processing tweet. ID = 1242693938533691392
#
# Current indx: 7
# Tweets to be processed: 894
# Processing tweet. ID = 1242693939578023936
#
# Current indx: 8
# Tweets to be processed: 893
# Processing tweet. ID = 1242693972775956480
#
# Current indx: 9
# Tweets to be processed: 892
# Processing tweet. ID = 1242694142242652160
#
# Current indx: 10
# Tweets to be processed: 891
# Processing tweet. ID = 1242694186089893888
#
# Current indx: 11
# Tweets to be processed: 890
# Processing tweet. ID = 1242695145750843392
#
# Current indx: 12
# Tweets to be processed: 889
# Processing tweet. ID = 1242695356560752640
#
# Current indx: 13
# Tweets to be processed: 888
# Processing tweet. ID = 1242695384163442689
#
# Current indx: 14
# Tweets to be processed: 887
# Processing tweet. ID = 1242695451666599937
#
# Current indx: 15
# Tweets to be processed: 886
# Processing tweet. ID = 1242695527981957120
#
# Current indx: 16
# Tweets to be processed: 885
# Processing tweet. ID = 1242695543765123072
#
# Current indx: 17
# Tweets to be processed: 884
# Processing tweet. ID = 1242695600199462913
#
# Current indx: 18
# Tweets to be processed: 883
# Processing tweet. ID = 1242695611247280129
#
# Current indx: 19
# Tweets to be processed: 882
# Processing tweet. ID = 1242695635372998656
#
# Current indx: 20
# Tweets to be processed: 881
# Processing tweet. ID = 1242695689483759616
#
# Current indx: 21
# Tweets to be processed: 880
# Processing tweet. ID = 1242695852923076608
# Error while accessing tweet. ID: 1242695852923076608
#
# Current indx: 22
# Tweets to be processed: 879
# Processing tweet. ID = 1242695854307172352
#
# Current indx: 23
# Tweets to be processed: 878
# Processing tweet. ID = 1242695855326392320
#
# Current indx: 24
# Tweets to be processed: 877
# Processing tweet. ID = 1242695857171910656
#
# Current indx: 25
# Tweets to be processed: 876
# Processing tweet. ID = 1242695871260758016
#
# Current indx: 26
# Tweets to be processed: 875
# Processing tweet. ID = 1242695890621444096
#
# Current indx: 27
# Tweets to be processed: 874
# Processing tweet. ID = 1242695910724780032
#
# Current indx: 28
# Tweets to be processed: 873
# Processing tweet. ID = 1242696085396541440
#
# Current indx: 29
# Tweets to be processed: 872
# Processing tweet. ID = 1242696110159822850
#
# Current indx: 30
# Tweets to be processed: 871
# Processing tweet. ID = 1242696256398462976
#
# Current indx: 31
# Tweets to be processed: 870
# Processing tweet. ID = 1242696293484392448
#
# Current indx: 32
# Tweets to be processed: 869
# Processing tweet. ID = 1242696369107681280
#
# Current indx: 33
# Tweets to be processed: 868
# Processing tweet. ID = 1242696395888431104
#
# Current indx: 34
# Tweets to be processed: 867
# Processing tweet. ID = 1242696591779061760
#
# Current indx: 35
# Tweets to be processed: 866
# Processing tweet. ID = 1242696672745947136
#
# Current indx: 36
# Tweets to be processed: 865
# Processing tweet. ID = 1242696999981334528
#
# Current indx: 37
# Tweets to be processed: 864
# Processing tweet. ID = 1242697026451759104
#
# Current indx: 38
# Tweets to be processed: 863
# Processing tweet. ID = 1242697090469212162
#
# Current indx: 39
# Tweets to be processed: 862
# Processing tweet. ID = 1242697103954120704
#
# Current indx: 40
# Tweets to be processed: 861
# Processing tweet. ID = 1242697317867716615
#
# Current indx: 41
# Tweets to be processed: 860
# Processing tweet. ID = 1242697339728302080
#
# Current indx: 42
# Tweets to be processed: 859
# Processing tweet. ID = 1242697356249882626
#
# Current indx: 43
# Tweets to be processed: 858
# Processing tweet. ID = 1242697489272254464
#
# Current indx: 44
# Tweets to be processed: 857
# Processing tweet. ID = 1242697505814413313
#
# Current indx: 45
# Tweets to be processed: 856
# Processing tweet. ID = 1242697658013085696
#
# Current indx: 46
# Tweets to be processed: 855
# Processing tweet. ID = 1242697733175226369
#
# Current indx: 47
# Tweets to be processed: 854
# Processing tweet. ID = 1242697762103152641
#
# Current indx: 48
# Tweets to be processed: 853
# Processing tweet. ID = 1242698149988368386
#
# Current indx: 49
# Tweets to be processed: 852
# Processing tweet. ID = 1242698164328595457
#
# Current indx: 50
# Tweets to be processed: 851
# Processing tweet. ID = 1242698338194997253
#
# Current indx: 51
# Tweets to be processed: 850
# Processing tweet. ID = 1242698496852914177
# Error while accessing tweet. ID: 1242698496852914177
#
# Current indx: 52
# Tweets to be processed: 849
# Processing tweet. ID = 1242698536891760641
#
# Current indx: 53
# Tweets to be processed: 848
# Processing tweet. ID = 1242698628269068288
#
# Current indx: 54
# Tweets to be processed: 847
# Processing tweet. ID = 1242698630009458688
#
# Current indx: 55
# Tweets to be processed: 846
# Processing tweet. ID = 1242698860117426176
#
# Current indx: 56
# Tweets to be processed: 845
# Processing tweet. ID = 1242698935250169857
#
# Current indx: 57
# Tweets to be processed: 844
# Processing tweet. ID = 1242699005307400192
#
# Current indx: 58
# Tweets to be processed: 843
# Processing tweet. ID = 1242699010613243904
#
# Current indx: 59
# Tweets to be processed: 842
# Processing tweet. ID = 1242699374439706625
#
# Current indx: 60
# Tweets to be processed: 841
# Processing tweet. ID = 1242699399089623040
#
# Current indx: 61
# Tweets to be processed: 840
# Processing tweet. ID = 1242699465036910596
#
# Current indx: 62
# Tweets to be processed: 839
# Processing tweet. ID = 1242700035789180928
#
# Current indx: 63
# Tweets to be processed: 838
# Processing tweet. ID = 1242700064859930624
#
# Current indx: 64
# Tweets to be processed: 837
# Processing tweet. ID = 1242700082069164033
#
# Current indx: 65
# Tweets to be processed: 836
# Processing tweet. ID = 1242700191636975618
#
# Current indx: 66
# Tweets to be processed: 835
# Processing tweet. ID = 1242700206187008000
#
# Current indx: 67
# Tweets to be processed: 834
# Processing tweet. ID = 1242700253440036865
#
# Current indx: 68
# Tweets to be processed: 833
# Processing tweet. ID = 1242700333912129538
#
# Current indx: 69
# Tweets to be processed: 832
# Processing tweet. ID = 1242700368728883202
#
# Current indx: 70
# Tweets to be processed: 831
# Processing tweet. ID = 1242700370389819392
#
# Current indx: 71
# Tweets to be processed: 830
# Processing tweet. ID = 1242700374361788418
# Error while accessing tweet. ID: 1242700374361788418
#
# Current indx: 72
# Tweets to be processed: 829
# Processing tweet. ID = 1242700401368895488
#
# Current indx: 73
# Tweets to be processed: 828
# Processing tweet. ID = 1242700418506846209
#
# Current indx: 74
# Tweets to be processed: 827
# Processing tweet. ID = 1242700457962663938
#
# Current indx: 75
# Tweets to be processed: 826
# Processing tweet. ID = 1242700519883157505
#
# Current indx: 76
# Tweets to be processed: 825
# Processing tweet. ID = 1242700536752701440
#
# Current indx: 77
# Tweets to be processed: 824
# Processing tweet. ID = 1242700622807220224
#
# Current indx: 78
# Tweets to be processed: 823
# Processing tweet. ID = 1242700849731649536
#
# Current indx: 79
# Tweets to be processed: 822
# Processing tweet. ID = 1242700902219145221
#
# Current indx: 80
# Tweets to be processed: 821
# Processing tweet. ID = 1242700950390751232
#
# Current indx: 81
# Tweets to be processed: 820
# Processing tweet. ID = 1242701101188743168
#
# Current indx: 82
# Tweets to be processed: 819
# Processing tweet. ID = 1242701105248649216
#
# Current indx: 83
# Tweets to be processed: 818
# Processing tweet. ID = 1242701232415715329
#
# Current indx: 84
# Tweets to be processed: 817
# Processing tweet. ID = 1242701546808205312
#
# Current indx: 85
# Tweets to be processed: 816
# Processing tweet. ID = 1242701608946774016
#
# Current indx: 86
# Tweets to be processed: 815
# Processing tweet. ID = 1242701623509389312
#
# Current indx: 87
# Tweets to be processed: 814
# Processing tweet. ID = 1242701694921818112
#
# Current indx: 88
# Tweets to be processed: 813
# Processing tweet. ID = 1242701857253982208
#
# Current indx: 89
# Tweets to be processed: 812
# Processing tweet. ID = 1242701923213545472
#
# Current indx: 90
# Tweets to be processed: 811
# Processing tweet. ID = 1242701927827341313
#
# Current indx: 91
# Tweets to be processed: 810
# Processing tweet. ID = 1242701931958734850
#
# Current indx: 92
# Tweets to be processed: 809
# Processing tweet. ID = 1242702023855714305
#
# Current indx: 93
# Tweets to be processed: 808
# Processing tweet. ID = 1242702101806866432
#
# Current indx: 94
# Tweets to be processed: 807
# Processing tweet. ID = 1242702237857492993
#
# Current indx: 95
# Tweets to be processed: 806
# Processing tweet. ID = 1242702332648816640
#
# Current indx: 96
# Tweets to be processed: 805
# Processing tweet. ID = 1242702511246438401
#
# Current indx: 97
# Tweets to be processed: 804
# Processing tweet. ID = 1242702629592920064
#
# Current indx: 98
# Tweets to be processed: 803
# Processing tweet. ID = 1242702823130685441
#
# Current indx: 99
# Tweets to be processed: 802
# Processing tweet. ID = 1242703042224345088
#
# Current indx: 100
# Tweets to be processed: 801
# Processing tweet. ID = 1242703455459966976
# Text: @svatantraBharat Je ha 🌹🌹New year brings happiness &amp; joy , hope this year will bring safety from corona.  #नववर्ष_पर_विश्वशांति_का_संकल्प
#
# https://t.co/kV9DayZHgd
#
# Current indx: 101
# Tweets to be processed: 800
# Processing tweet. ID = 1242703696468889601
#
# Current indx: 102
# Tweets to be processed: 799
# Processing tweet. ID = 1242703881328451584
#
# Current indx: 103
# Tweets to be processed: 798
# Processing tweet. ID = 1242703953189576709
#
# Current indx: 104
# Tweets to be processed: 797
# Processing tweet. ID = 1242704001663033344
#
# Current indx: 105
# Tweets to be processed: 796
# Processing tweet. ID = 1242704015554560001
#
# Current indx: 106
# Tweets to be processed: 795
# Processing tweet. ID = 1242704124925186054
#
# Current indx: 107
# Tweets to be processed: 794
# Processing tweet. ID = 1242704148308475906
#
# Current indx: 108
# Tweets to be processed: 793
# Processing tweet. ID = 1242704155858178048
#
# Current indx: 109
# Tweets to be processed: 792
# Processing tweet. ID = 1242704356710985728
#
# Current indx: 110
# Tweets to be processed: 791
# Processing tweet. ID = 1242704654711939073
#
# Current indx: 111
# Tweets to be processed: 790
# Processing tweet. ID = 1242704700320841730
#
# Current indx: 112
# Tweets to be processed: 789
# Processing tweet. ID = 1242704853907857410
#
# Current indx: 113
# Tweets to be processed: 788
# Processing tweet. ID = 1242705019507314694
#
# Current indx: 114
# Tweets to be processed: 787
# Processing tweet. ID = 1242705167411113984
#
# Current indx: 115
# Tweets to be processed: 786
# Processing tweet. ID = 1242705263775248385
#
# Current indx: 116
# Tweets to be processed: 785
# Processing tweet. ID = 1242705354510569472
#
# Current indx: 117
# Tweets to be processed: 784
# Processing tweet. ID = 1242705413503680512
#
# Current indx: 118
# Tweets to be processed: 783
# Processing tweet. ID = 1242705515907395585
#
# Current indx: 119
# Tweets to be processed: 782
# Processing tweet. ID = 1242705612657442816
#
# Current indx: 120
# Tweets to be processed: 781
# Processing tweet. ID = 1242705650909507584
#
# Current indx: 121
# Tweets to be processed: 780
# Processing tweet. ID = 1242705699429220352
#
# Current indx: 122
# Tweets to be processed: 779
# Processing tweet. ID = 1242705860649816064
#
# Current indx: 123
# Tweets to be processed: 778
# Processing tweet. ID = 1242705979885699073
#
# Current indx: 124
# Tweets to be processed: 777
# Processing tweet. ID = 1242706488558157824
#
# Current indx: 125
# Tweets to be processed: 776
# Processing tweet. ID = 1242706639439855616
#
# Current indx: 126
# Tweets to be processed: 775
# Processing tweet. ID = 1242706742414209024
#
# Current indx: 127
# Tweets to be processed: 774
# Processing tweet. ID = 1242706914565210113
#
# Current indx: 128
# Tweets to be processed: 773
# Processing tweet. ID = 1242706918134525954
#
# Current indx: 129
# Tweets to be processed: 772
# Processing tweet. ID = 1242706921833910275
#
# Current indx: 130
# Tweets to be processed: 771
# Processing tweet. ID = 1242706972861820930
#
# Current indx: 131
# Tweets to be processed: 770
# Processing tweet. ID = 1242706996631126017
#
# Current indx: 132
# Tweets to be processed: 769
# Processing tweet. ID = 1242707191112429568
#
# Current indx: 133
# Tweets to be processed: 768
# Processing tweet. ID = 1242707442661609472
#
# Current indx: 134
# Tweets to be processed: 767
# Processing tweet. ID = 1242707516850614273
#
# Current indx: 135
# Tweets to be processed: 766
# Processing tweet. ID = 1242707803585646592
#
# Current indx: 136
# Tweets to be processed: 765
# Processing tweet. ID = 1242707869449027585
#
# Current indx: 137
# Tweets to be processed: 764
# Processing tweet. ID = 1242707978878218241
#
# Current indx: 138
# Tweets to be processed: 763
# Processing tweet. ID = 1242708035547459584
#
# Current indx: 139
# Tweets to be processed: 762
# Processing tweet. ID = 1242708145748578304
#
# Current indx: 140
# Tweets to be processed: 761
# Processing tweet. ID = 1242708155781410818
#
# Current indx: 141
# Tweets to be processed: 760
# Processing tweet. ID = 1242708165923237889
#
# Current indx: 142
# Tweets to be processed: 759
# Processing tweet. ID = 1242708295715966977
#
# Current indx: 143
# Tweets to be processed: 758
# Processing tweet. ID = 1242708378129850368
#
# Current indx: 144
# Tweets to be processed: 757
# Processing tweet. ID = 1242708800509038592
#
# Current indx: 145
# Tweets to be processed: 756
# Processing tweet. ID = 1242708852308611075
#
# Current indx: 146
# Tweets to be processed: 755
# Processing tweet. ID = 1242708910542331904
#
# Current indx: 147
# Tweets to be processed: 754
# Processing tweet. ID = 1242709052473217024
#
# Current indx: 148
# Tweets to be processed: 753
# Processing tweet. ID = 1242709232907997189
#
# Current indx: 149
# Tweets to be processed: 752
# Processing tweet. ID = 1242709252185047040
#
# Current indx: 150
# Tweets to be processed: 751
# Processing tweet. ID = 1242709451208921088
#
# Current indx: 151
# Tweets to be processed: 750
# Processing tweet. ID = 1242709527243317248
#
# Current indx: 152
# Tweets to be processed: 749
# Processing tweet. ID = 1242709869792301056
#
# Current indx: 153
# Tweets to be processed: 748
# Processing tweet. ID = 1242709901283123200
#
# Current indx: 154
# Tweets to be processed: 747
# Processing tweet. ID = 1242709961848893440
#
# Current indx: 155
# Tweets to be processed: 746
# Processing tweet. ID = 1242710071441645569
#
# Current indx: 156
# Tweets to be processed: 745
# Processing tweet. ID = 1242710236382687232
#
# Current indx: 157
# Tweets to be processed: 744
# Processing tweet. ID = 1242710299762778112
#
# Current indx: 158
# Tweets to be processed: 743
# Processing tweet. ID = 1242710393648078848
#
# Current indx: 159
# Tweets to be processed: 742
# Processing tweet. ID = 1242710552670920704
#
# Current indx: 160
# Tweets to be processed: 741
# Processing tweet. ID = 1242710557402128385
#
# Current indx: 161
# Tweets to be processed: 740
# Processing tweet. ID = 1242710563290931200
#
# Current indx: 162
# Tweets to be processed: 739
# Processing tweet. ID = 1242710564750520321
#
# Current indx: 163
# Tweets to be processed: 738
# Processing tweet. ID = 1242710792140554241
#
# Current indx: 164
# Tweets to be processed: 737
# Processing tweet. ID = 1242710926291337216
#
# Current indx: 165
# Tweets to be processed: 736
# Processing tweet. ID = 1242710952593756160
#
# Current indx: 166
# Tweets to be processed: 735
# Processing tweet. ID = 1242710999632773120
#
# Current indx: 167
# Tweets to be processed: 734
# Processing tweet. ID = 1242711040061628422
#
# Current indx: 168
# Tweets to be processed: 733
# Processing tweet. ID = 1242711075998461952
#
# Current indx: 169
# Tweets to be processed: 732
# Processing tweet. ID = 1242711121926033413
#
# Current indx: 170
# Tweets to be processed: 731
# Processing tweet. ID = 1242711477389152256
#
# Current indx: 171
# Tweets to be processed: 730
# Processing tweet. ID = 1242711605319593984
#
# Current indx: 172
# Tweets to be processed: 729
# Processing tweet. ID = 1242711752422207488
#
# Current indx: 173
# Tweets to be processed: 728
# Processing tweet. ID = 1242711764925468678
#
# Current indx: 174
# Tweets to be processed: 727
# Processing tweet. ID = 1242711772743647232
#
# Current indx: 175
# Tweets to be processed: 726
# Processing tweet. ID = 1242711837398847491
#
# Current indx: 176
# Tweets to be processed: 725
# Processing tweet. ID = 1242711954612862976
#
# Current indx: 177
# Tweets to be processed: 724
# Processing tweet. ID = 1242712102185230337
#
# Current indx: 178
# Tweets to be processed: 723
# Processing tweet. ID = 1242712250768445440
#
# Current indx: 179
# Tweets to be processed: 722
# Processing tweet. ID = 1242712314047893504
#
# Current indx: 180
# Tweets to be processed: 721
# Processing tweet. ID = 1242712321304100864
#
# Current indx: 181
# Tweets to be processed: 720
# Processing tweet. ID = 1242712377432272896
#
# Current indx: 182
# Tweets to be processed: 719
# Processing tweet. ID = 1242713002849124352
#
# Current indx: 183
# Tweets to be processed: 718
# Processing tweet. ID = 1242713056624259072
#
# Current indx: 184
# Tweets to be processed: 717
# Processing tweet. ID = 1242713575971422209
#
# Current indx: 185
# Tweets to be processed: 716
# Processing tweet. ID = 1242713679587676160
#
# Current indx: 186
# Tweets to be processed: 715
# Processing tweet. ID = 1242713694716309504
#
# Current indx: 187
# Tweets to be processed: 714
# Processing tweet. ID = 1242713835426856961
#
# Current indx: 188
# Tweets to be processed: 713
# Processing tweet. ID = 1242713926216761346
#
# Current indx: 189
# Tweets to be processed: 712
# Processing tweet. ID = 1242714011931566080
#
# Current indx: 190
# Tweets to be processed: 711
# Processing tweet. ID = 1242714031581847553
#
# Current indx: 191
# Tweets to be processed: 710
# Processing tweet. ID = 1242714108908068865
#
# Current indx: 192
# Tweets to be processed: 709
# Processing tweet. ID = 1242714147730538496
#
# Current indx: 193
# Tweets to be processed: 708
# Processing tweet. ID = 1242714164105220099
#
# Current indx: 194
# Tweets to be processed: 707
# Processing tweet. ID = 1242714220564635648
#
# Current indx: 195
# Tweets to be processed: 706
# Processing tweet. ID = 1242714296255160321
#
# Current indx: 196
# Tweets to be processed: 705
# Processing tweet. ID = 1242714409358655489
#
# Current indx: 197
# Tweets to be processed: 704
# Processing tweet. ID = 1242714450387447813
#
# Current indx: 198
# Tweets to be processed: 703
# Processing tweet. ID = 1242714474613600257
#
# Current indx: 199
# Tweets to be processed: 702
# Processing tweet. ID = 1242714786627858433
#
# Current indx: 200
# Tweets to be processed: 701
# Processing tweet. ID = 1242714842743500801
# Text: So much of excitement by @TelanganaCMO ; when you do not study full year and try to complete course one night before exams, study whole night to get some sympathy from mummy and papa... https://t.co/aenlM4wNjR
#
# Current indx: 201
# Tweets to be processed: 700
# Processing tweet. ID = 1242714887517683712
#
# Current indx: 202
# Tweets to be processed: 699
# Processing tweet. ID = 1242714967570145280
#
# Current indx: 203
# Tweets to be processed: 698
# Processing tweet. ID = 1242715155861057537
#
# Current indx: 204
# Tweets to be processed: 697
# Processing tweet. ID = 1242715417140813826
#
# Current indx: 205
# Tweets to be processed: 696
# Processing tweet. ID = 1242715523093164032
#
# Current indx: 206
# Tweets to be processed: 695
# Processing tweet. ID = 1242715616751923200
#
# Current indx: 207
# Tweets to be processed: 694
# Processing tweet. ID = 1242715641078923266
#
# Current indx: 208
# Tweets to be processed: 693
# Processing tweet. ID = 1242715689464385536
#
# Current indx: 209
# Tweets to be processed: 692
# Processing tweet. ID = 1242715780048805895
#
# Current indx: 210
# Tweets to be processed: 691
# Processing tweet. ID = 1242715795991359495
#
# Current indx: 211
# Tweets to be processed: 690
# Processing tweet. ID = 1242715856347353091
#
# Current indx: 212
# Tweets to be processed: 689
# Processing tweet. ID = 1242715856896790528
#
# Current indx: 213
# Tweets to be processed: 688
# Processing tweet. ID = 1242715992720998400
#
# Current indx: 214
# Tweets to be processed: 687
# Processing tweet. ID = 1242716314998837250
#
# Current indx: 215
# Tweets to be processed: 686
# Processing tweet. ID = 1242716349446516736
#
# Current indx: 216
# Tweets to be processed: 685
# Processing tweet. ID = 1242716449568768005
#
# Current indx: 217
# Tweets to be processed: 684
# Processing tweet. ID = 1242716535199641601
#
# Current indx: 218
# Tweets to be processed: 683
# Processing tweet. ID = 1242716538311860224
#
# Current indx: 219
# Tweets to be processed: 682
# Processing tweet. ID = 1242716559530811393
#
# Current indx: 220
# Tweets to be processed: 681
# Processing tweet. ID = 1242716709682733057
#
# Current indx: 221
# Tweets to be processed: 680
# Processing tweet. ID = 1242716731950456833
#
# Current indx: 222
# Tweets to be processed: 679
# Processing tweet. ID = 1242716799931568129
#
# Current indx: 223
# Tweets to be processed: 678
# Processing tweet. ID = 1242716903300190208
#
# Current indx: 224
# Tweets to be processed: 677
# Processing tweet. ID = 1242716947617165314
#
# Current indx: 225
# Tweets to be processed: 676
# Processing tweet. ID = 1242716951077584896
#
# Current indx: 226
# Tweets to be processed: 675
# Processing tweet. ID = 1242716995604353024
#
# Current indx: 227
# Tweets to be processed: 674
# Processing tweet. ID = 1242717027162152960
#
# Current indx: 228
# Tweets to be processed: 673
# Processing tweet. ID = 1242717033801773057
#
# Current indx: 229
# Tweets to be processed: 672
# Processing tweet. ID = 1242717038499360768
#
# Current indx: 230
# Tweets to be processed: 671
# Processing tweet. ID = 1242717175846064129
#
# Current indx: 231
# Tweets to be processed: 670
# Processing tweet. ID = 1242717442926735360
#
# Current indx: 232
# Tweets to be processed: 669
# Processing tweet. ID = 1242717541157367808
#
# Current indx: 233
# Tweets to be processed: 668
# Processing tweet. ID = 1242717568785354752
#
# Current indx: 234
# Tweets to be processed: 667
# Processing tweet. ID = 1242717660900519937
#
# Current indx: 235
# Tweets to be processed: 666
# Processing tweet. ID = 1242717777367973888
#
# Current indx: 236
# Tweets to be processed: 665
# Processing tweet. ID = 1242717842681655296
#
# Current indx: 237
# Tweets to be processed: 664
# Processing tweet. ID = 1242718155945861121
#
# Current indx: 238
# Tweets to be processed: 663
# Processing tweet. ID = 1242718323516641280
#
# Current indx: 239
# Tweets to be processed: 662
# Processing tweet. ID = 1242718661242224640
#
# Current indx: 240
# Tweets to be processed: 661
# Processing tweet. ID = 1242719186859646976
#
# Current indx: 241
# Tweets to be processed: 660
# Processing tweet. ID = 1242719205868388353
#
# Current indx: 242
# Tweets to be processed: 659
# Processing tweet. ID = 1242719506125840384
#
# Current indx: 243
# Tweets to be processed: 658
# Processing tweet. ID = 1242719520076099584
#
# Current indx: 244
# Tweets to be processed: 657
# Processing tweet. ID = 1242719608336830465
#
# Current indx: 245
# Tweets to be processed: 656
# Processing tweet. ID = 1242719672295882752
#
# Current indx: 246
# Tweets to be processed: 655
# Processing tweet. ID = 1242719917155037184
#
# Current indx: 247
# Tweets to be processed: 654
# Processing tweet. ID = 1242719989133479936
#
# Current indx: 248
# Tweets to be processed: 653
# Processing tweet. ID = 1242720201075871747
#
# Current indx: 249
# Tweets to be processed: 652
# Processing tweet. ID = 1242720311767789568
#
# Current indx: 250
# Tweets to be processed: 651
# Processing tweet. ID = 1242720325814476802
#
# Current indx: 251
# Tweets to be processed: 650
# Processing tweet. ID = 1242720374577455104
#
# Current indx: 252
# Tweets to be processed: 649
# Processing tweet. ID = 1242720412183588869
#
# Current indx: 253
# Tweets to be processed: 648
# Processing tweet. ID = 1242720456328859650
#
# Current indx: 254
# Tweets to be processed: 647
# Processing tweet. ID = 1242720558514651136
#
# Current indx: 255
# Tweets to be processed: 646
# Processing tweet. ID = 1242720754468184064
#
# Current indx: 256
# Tweets to be processed: 645
# Processing tweet. ID = 1242720971082985474
#
# Current indx: 257
# Tweets to be processed: 644
# Processing tweet. ID = 1242720979895250944
#
# Current indx: 258
# Tweets to be processed: 643
# Processing tweet. ID = 1242721784849448962
#
# Current indx: 259
# Tweets to be processed: 642
# Processing tweet. ID = 1242721802465480704
#
# Current indx: 260
# Tweets to be processed: 641
# Processing tweet. ID = 1242722251943755776
#
# Current indx: 261
# Tweets to be processed: 640
# Processing tweet. ID = 1242722310638858241
#
# Current indx: 262
# Tweets to be processed: 639
# Processing tweet. ID = 1242722410522165248
#
# Current indx: 263
# Tweets to be processed: 638
# Processing tweet. ID = 1242722454847406080
#
# Current indx: 264
# Tweets to be processed: 637
# Processing tweet. ID = 1242722579325976577
#
# Current indx: 265
# Tweets to be processed: 636
# Processing tweet. ID = 1242722595234971648
#
# Current indx: 266
# Tweets to be processed: 635
# Processing tweet. ID = 1242722661593001984
#
# Current indx: 267
# Tweets to be processed: 634
# Processing tweet. ID = 1242722738051010566
#
# Current indx: 268
# Tweets to be processed: 633
# Processing tweet. ID = 1242722758821281792
#
# Current indx: 269
# Tweets to be processed: 632
# Processing tweet. ID = 1242723037595627523
#
# Current indx: 270
# Tweets to be processed: 631
# Processing tweet. ID = 1242723085289025537
#
# Current indx: 271
# Tweets to be processed: 630
# Processing tweet. ID = 1242723174262824961
#
# Current indx: 272
# Tweets to be processed: 629
# Processing tweet. ID = 1242723184106852359
#
# Current indx: 273
# Tweets to be processed: 628
# Processing tweet. ID = 1242723455864168448
#
# Current indx: 274
# Tweets to be processed: 627
# Processing tweet. ID = 1242723562626019330
#
# Current indx: 275
# Tweets to be processed: 626
# Processing tweet. ID = 1242724021243961351
#
# Current indx: 276
# Tweets to be processed: 625
# Processing tweet. ID = 1242724690478546944
#
# Current indx: 277
# Tweets to be processed: 624
# Processing tweet. ID = 1242724758254309376
#
# Current indx: 278
# Tweets to be processed: 623
# Processing tweet. ID = 1242724759193792513
#
# Current indx: 279
# Tweets to be processed: 622
# Processing tweet. ID = 1242724883705942017
#
# Current indx: 280
# Tweets to be processed: 621
# Processing tweet. ID = 1242725082918612992
#
# Current indx: 281
# Tweets to be processed: 620
# Processing tweet. ID = 1242725099075072001
#
# Current indx: 282
# Tweets to be processed: 619
# Processing tweet. ID = 1242725107673464833
#
# Current indx: 283
# Tweets to be processed: 618
# Processing tweet. ID = 1242725112165457920
#
# Current indx: 284
# Tweets to be processed: 617
# Processing tweet. ID = 1242725187952332800
#
# Current indx: 285
# Tweets to be processed: 616
# Processing tweet. ID = 1242725251177279488
#
# Current indx: 286
# Tweets to be processed: 615
# Processing tweet. ID = 1242725538722123776
#
# Current indx: 287
# Tweets to be processed: 614
# Processing tweet. ID = 1242725584884523009
#
# Current indx: 288
# Tweets to be processed: 613
# Processing tweet. ID = 1242725657441959938
#
# Current indx: 289
# Tweets to be processed: 612
# Processing tweet. ID = 1242725680590344192
#
# Current indx: 290
# Tweets to be processed: 611
# Processing tweet. ID = 1242725833409613825
#
# Current indx: 291
# Tweets to be processed: 610
# Processing tweet. ID = 1242725930545471491
#
# Current indx: 292
# Tweets to be processed: 609
# Processing tweet. ID = 1242725984236756992
#
# Current indx: 293
# Tweets to be processed: 608
# Processing tweet. ID = 1242725988099735552
#
# Current indx: 294
# Tweets to be processed: 607
# Processing tweet. ID = 1242725997163597830
#
# Current indx: 295
# Tweets to be processed: 606
# Processing tweet. ID = 1242725999395008512
#
# Current indx: 296
# Tweets to be processed: 605
# Processing tweet. ID = 1242726013496254466
#
# Current indx: 297
# Tweets to be processed: 604
# Processing tweet. ID = 1242726028574732288
#
# Current indx: 298
# Tweets to be processed: 603
# Processing tweet. ID = 1242726060111745024
#
# Current indx: 299
# Tweets to be processed: 602
# Processing tweet. ID = 1242726159189782530
#
# Current indx: 300
# Tweets to be processed: 601
# Processing tweet. ID = 1242726176314888193
# Text: @HathwayBrdband Ha ha . today I got this message from hathaway ...
# Its because of corona then ok...
# Then why my account showing still      Rs  -1767/- ( Why you people asking me to pay more,you could inform me before right . oh because of corona I need to take connection for 6 months ah.) https://t.co/LHvOrn6QWf
#
# Current indx: 301
# Tweets to be processed: 600
# Processing tweet. ID = 1242726244707209216
#
# Current indx: 302
# Tweets to be processed: 599
# Processing tweet. ID = 1242726271316045825
#
# Current indx: 303
# Tweets to be processed: 598
# Processing tweet. ID = 1242726396666896384
#
# Current indx: 304
# Tweets to be processed: 597
# Processing tweet. ID = 1242726652989317120
#
# Current indx: 305
# Tweets to be processed: 596
# Processing tweet. ID = 1242726886544830464
#
# Current indx: 306
# Tweets to be processed: 595
# Processing tweet. ID = 1242727217899040769
#
# Current indx: 307
# Tweets to be processed: 594
# Processing tweet. ID = 1242727357896507392
#
# Current indx: 308
# Tweets to be processed: 593
# Processing tweet. ID = 1242727670481408000
#
# Current indx: 309
# Tweets to be processed: 592
# Processing tweet. ID = 1242727763414401024
#
# Current indx: 310
# Tweets to be processed: 591
# Processing tweet. ID = 1242727898760404992
#
# Current indx: 311
# Tweets to be processed: 590
# Processing tweet. ID = 1242728185256534016
#
# Current indx: 312
# Tweets to be processed: 589
# Processing tweet. ID = 1242728220157329408
#
# Current indx: 313
# Tweets to be processed: 588
# Processing tweet. ID = 1242728369529053184
#
# Current indx: 314
# Tweets to be processed: 587
# Processing tweet. ID = 1242728739261124608
#
# Current indx: 315
# Tweets to be processed: 586
# Processing tweet. ID = 1242728744084738048
#
# Current indx: 316
# Tweets to be processed: 585
# Processing tweet. ID = 1242728862959587329
#
# Current indx: 317
# Tweets to be processed: 584
# Processing tweet. ID = 1242728918118887424
#
# Current indx: 318
# Tweets to be processed: 583
# Processing tweet. ID = 1242729089200304128
#
# Current indx: 319
# Tweets to be processed: 582
# Processing tweet. ID = 1242729138051407872
#
# Current indx: 320
# Tweets to be processed: 581
# Processing tweet. ID = 1242729185165971456
#
# Current indx: 321
# Tweets to be processed: 580
# Processing tweet. ID = 1242729447620349958
#
# Current indx: 322
# Tweets to be processed: 579
# Processing tweet. ID = 1242729593351503872
#
# Current indx: 323
# Tweets to be processed: 578
# Processing tweet. ID = 1242729754668593155
#
# Current indx: 324
# Tweets to be processed: 577
# Processing tweet. ID = 1242729829188788225
#
# Current indx: 325
# Tweets to be processed: 576
# Processing tweet. ID = 1242729975498674176
#
# Current indx: 326
# Tweets to be processed: 575
# Processing tweet. ID = 1242730137247813632
#
# Current indx: 327
# Tweets to be processed: 574
# Processing tweet. ID = 1242730156428419074
#
# Current indx: 328
# Tweets to be processed: 573
# Processing tweet. ID = 1242730164720521216
#
# Current indx: 329
# Tweets to be processed: 572
# Processing tweet. ID = 1242730195427028993
#
# Current indx: 330
# Tweets to be processed: 571
# Processing tweet. ID = 1242730312318119936
#
# Current indx: 331
# Tweets to be processed: 570
# Processing tweet. ID = 1242730802263117825
#
# Current indx: 332
# Tweets to be processed: 569
# Processing tweet. ID = 1242730914615980032
#
# Current indx: 333
# Tweets to be processed: 568
# Processing tweet. ID = 1242730978625245184
#
# Current indx: 334
# Tweets to be processed: 567
# Processing tweet. ID = 1242731003711557638
#
# Current indx: 335
# Tweets to be processed: 566
# Processing tweet. ID = 1242731042823213057
#
# Current indx: 336
# Tweets to be processed: 565
# Processing tweet. ID = 1242731577513136128
#
# Current indx: 337
# Tweets to be processed: 564
# Processing tweet. ID = 1242731580549816320
#
# Current indx: 338
# Tweets to be processed: 563
# Processing tweet. ID = 1242731764851728384
#
# Current indx: 339
# Tweets to be processed: 562
# Processing tweet. ID = 1242731891825889280
#
# Current indx: 340
# Tweets to be processed: 561
# Processing tweet. ID = 1242731900692824065
#
# Current indx: 341
# Tweets to be processed: 560
# Processing tweet. ID = 1242731926806392832
#
# Current indx: 342
# Tweets to be processed: 559
# Processing tweet. ID = 1242731977460989953
#
# Current indx: 343
# Tweets to be processed: 558
# Processing tweet. ID = 1242731978891259904
#
# Current indx: 344
# Tweets to be processed: 557
# Processing tweet. ID = 1242732004258402304
#
# Current indx: 345
# Tweets to be processed: 556
# Processing tweet. ID = 1242732106666532864
#
# Current indx: 346
# Tweets to be processed: 555
# Processing tweet. ID = 1242732264070320129
#
# Current indx: 347
# Tweets to be processed: 554
# Processing tweet. ID = 1242732363781517312
#
# Current indx: 348
# Tweets to be processed: 553
# Processing tweet. ID = 1242732431297245185
#
# Current indx: 349
# Tweets to be processed: 552
# Processing tweet. ID = 1242732607592222720
#
# Current indx: 350
# Tweets to be processed: 551
# Processing tweet. ID = 1242732784059158529
#
# Current indx: 351
# Tweets to be processed: 550
# Processing tweet. ID = 1242732784424124420
#
# Current indx: 352
# Tweets to be processed: 549
# Processing tweet. ID = 1242732840111894533
#
# Current indx: 353
# Tweets to be processed: 548
# Processing tweet. ID = 1242733044634488833
#
# Current indx: 354
# Tweets to be processed: 547
# Processing tweet. ID = 1242733081309507584
#
# Current indx: 355
# Tweets to be processed: 546
# Processing tweet. ID = 1242733160963534848
#
# Current indx: 356
# Tweets to be processed: 545
# Processing tweet. ID = 1242733188360720384
#
# Current indx: 357
# Tweets to be processed: 544
# Processing tweet. ID = 1242733227426459650
#
# Current indx: 358
# Tweets to be processed: 543
# Processing tweet. ID = 1242733843620085760
#
# Current indx: 359
# Tweets to be processed: 542
# Processing tweet. ID = 1242733955083915264
#
# Current indx: 360
# Tweets to be processed: 541
# Processing tweet. ID = 1242733961870073856
#
# Current indx: 361
# Tweets to be processed: 540
# Processing tweet. ID = 1242734175574097920
#
# Current indx: 362
# Tweets to be processed: 539
# Processing tweet. ID = 1242734589644177410
#
# Current indx: 363
# Tweets to be processed: 538
# Processing tweet. ID = 1242734593091887104
#
# Current indx: 364
# Tweets to be processed: 537
# Processing tweet. ID = 1242734903290032130
#
# Current indx: 365
# Tweets to be processed: 536
# Processing tweet. ID = 1242734957836906497
#
# Current indx: 366
# Tweets to be processed: 535
# Processing tweet. ID = 1242735065718755329
#
# Current indx: 367
# Tweets to be processed: 534
# Processing tweet. ID = 1242735492317110273
#
# Current indx: 368
# Tweets to be processed: 533
# Processing tweet. ID = 1242735586009440257
#
# Current indx: 369
# Tweets to be processed: 532
# Processing tweet. ID = 1242735728318185472
#
# Current indx: 370
# Tweets to be processed: 531
# Processing tweet. ID = 1242735948409884678
#
# Current indx: 371
# Tweets to be processed: 530
# Processing tweet. ID = 1242735998871601152
#
# Current indx: 372
# Tweets to be processed: 529
# Processing tweet. ID = 1242736014839304192
#
# Current indx: 373
# Tweets to be processed: 528
# Processing tweet. ID = 1242736083231744000
#
# Current indx: 374
# Tweets to be processed: 527
# Processing tweet. ID = 1242736225099767809
#
# Current indx: 375
# Tweets to be processed: 526
# Processing tweet. ID = 1242736254153707520
#
# Current indx: 376
# Tweets to be processed: 525
# Processing tweet. ID = 1242736262282227713
#
# Current indx: 377
# Tweets to be processed: 524
# Processing tweet. ID = 1242736322172743682
#
# Current indx: 378
# Tweets to be processed: 523
# Processing tweet. ID = 1242736428729028614
#
# Current indx: 379
# Tweets to be processed: 522
# Processing tweet. ID = 1242736541438373888
#
# Current indx: 380
# Tweets to be processed: 521
# Processing tweet. ID = 1242736680152363009
#
# Current indx: 381
# Tweets to be processed: 520
# Processing tweet. ID = 1242736864357806080
#
# Current indx: 382
# Tweets to be processed: 519
# Processing tweet. ID = 1242737008499253248
#
# Current indx: 383
# Tweets to be processed: 518
# Processing tweet. ID = 1242737041797865472
#
# Current indx: 384
# Tweets to be processed: 517
# Processing tweet. ID = 1242737296283070464
#
# Current indx: 385
# Tweets to be processed: 516
# Processing tweet. ID = 1242737515154604033
#
# Current indx: 386
# Tweets to be processed: 515
# Processing tweet. ID = 1242737559039430656
#
# Current indx: 387
# Tweets to be processed: 514
# Processing tweet. ID = 1242737831946182656
#
# Current indx: 388
# Tweets to be processed: 513
# Processing tweet. ID = 1242737838564601857
#
# Current indx: 389
# Tweets to be processed: 512
# Processing tweet. ID = 1242737972333576192
#
# Current indx: 390
# Tweets to be processed: 511
# Processing tweet. ID = 1242737992109707264
#
# Current indx: 391
# Tweets to be processed: 510
# Processing tweet. ID = 1242738200528879616
#
# Current indx: 392
# Tweets to be processed: 509
# Processing tweet. ID = 1242738331588292608
#
# Current indx: 393
# Tweets to be processed: 508
# Processing tweet. ID = 1242738456675008514
#
# Current indx: 394
# Tweets to be processed: 507
# Processing tweet. ID = 1242738673688268800
#
# Current indx: 395
# Tweets to be processed: 506
# Processing tweet. ID = 1242738724594688002
#
# Current indx: 396
# Tweets to be processed: 505
# Processing tweet. ID = 1242738808803606529
#
# Current indx: 397
# Tweets to be processed: 504
# Processing tweet. ID = 1242738944527273985
#
# Current indx: 398
# Tweets to be processed: 503
# Processing tweet. ID = 1242739033832292352
#
# Current indx: 399
# Tweets to be processed: 502
# Processing tweet. ID = 1242739086424711169
#
# Current indx: 400
# Tweets to be processed: 501
# Processing tweet. ID = 1242739673555820545
# Text: . 22 students(14boys/8girls) from #JNV saranga, dkl, Odisha are not able to return #Odisha from Supaul #Bihar due to #lockdownindia kindly help! 🙏 @CMO_Odisha @PIB_Patna @AprajitaSarangi @PandaJay @SarangiSudhansu @DGPOdisha @districtadmndkl @Mahesh5700 @DeoKalikesh https://t.co/vHl9Ru9vaq
#
# Current indx: 401
# Tweets to be processed: 500
# Processing tweet. ID = 1242739693139066880
#
# Current indx: 402
# Tweets to be processed: 499
# Processing tweet. ID = 1242739747065192448
#
# Current indx: 403
# Tweets to be processed: 498
# Processing tweet. ID = 1242739759690190848
#
# Current indx: 404
# Tweets to be processed: 497
# Processing tweet. ID = 1242739769135661062
#
# Current indx: 405
# Tweets to be processed: 496
# Processing tweet. ID = 1242739931123834881
#
# Current indx: 406
# Tweets to be processed: 495
# Processing tweet. ID = 1242739933611085824
#
# Current indx: 407
# Tweets to be processed: 494
# Processing tweet. ID = 1242740041304031232
#
# Current indx: 408
# Tweets to be processed: 493
# Processing tweet. ID = 1242740669019385856
#
# Current indx: 409
# Tweets to be processed: 492
# Processing tweet. ID = 1242740710106775553
#
# Current indx: 410
# Tweets to be processed: 491
# Processing tweet. ID = 1242740754134401024
#
# Current indx: 411
# Tweets to be processed: 490
# Processing tweet. ID = 1242740793498128385
#
# Current indx: 412
# Tweets to be processed: 489
# Processing tweet. ID = 1242740830684606468
#
# Current indx: 413
# Tweets to be processed: 488
# Processing tweet. ID = 1242740985525940226
#
# Current indx: 414
# Tweets to be processed: 487
# Processing tweet. ID = 1242741177025097728
#
# Current indx: 415
# Tweets to be processed: 486
# Processing tweet. ID = 1242741250882703360
#
# Current indx: 416
# Tweets to be processed: 485
# Processing tweet. ID = 1242741301365235712
#
# Current indx: 417
# Tweets to be processed: 484
# Processing tweet. ID = 1242741384806719488
#
# Current indx: 418
# Tweets to be processed: 483
# Processing tweet. ID = 1242741442616807424
#
# Current indx: 419
# Tweets to be processed: 482
# Processing tweet. ID = 1242741481233735681
#
# Current indx: 420
# Tweets to be processed: 481
# Processing tweet. ID = 1242741616747507712
#
# Current indx: 421
# Tweets to be processed: 480
# Processing tweet. ID = 1242741671202189312
#
# Current indx: 422
# Tweets to be processed: 479
# Processing tweet. ID = 1242741782800023552
#
# Current indx: 423
# Tweets to be processed: 478
# Processing tweet. ID = 1242741895169630208
#
# Current indx: 424
# Tweets to be processed: 477
# Processing tweet. ID = 1242741907987378176
#
# Current indx: 425
# Tweets to be processed: 476
# Processing tweet. ID = 1242741926408810496
#
# Current indx: 426
# Tweets to be processed: 475
# Processing tweet. ID = 1242741930762485762
#
# Current indx: 427
# Tweets to be processed: 474
# Processing tweet. ID = 1242742038417649664
#
# Current indx: 428
# Tweets to be processed: 473
# Processing tweet. ID = 1242742065693249538
#
# Current indx: 429
# Tweets to be processed: 472
# Processing tweet. ID = 1242742097033060352
#
# Current indx: 430
# Tweets to be processed: 471
# Processing tweet. ID = 1242742193086959617
#
# Current indx: 431
# Tweets to be processed: 470
# Processing tweet. ID = 1242742275664252929
#
# Current indx: 432
# Tweets to be processed: 469
# Processing tweet. ID = 1242742348133437442
#
# Current indx: 433
# Tweets to be processed: 468
# Processing tweet. ID = 1242742452286455810
#
# Current indx: 434
# Tweets to be processed: 467
# Processing tweet. ID = 1242742515452669953
#
# Current indx: 435
# Tweets to be processed: 466
# Processing tweet. ID = 1242742532213260288
#
# Current indx: 436
# Tweets to be processed: 465
# Processing tweet. ID = 1242742715525345280
#
# Current indx: 437
# Tweets to be processed: 464
# Processing tweet. ID = 1242742785943277568
#
# Current indx: 438
# Tweets to be processed: 463
# Processing tweet. ID = 1242742821217435648
#
# Current indx: 439
# Tweets to be processed: 462
# Processing tweet. ID = 1242742887080529922
#
# Current indx: 440
# Tweets to be processed: 461
# Processing tweet. ID = 1242742930747478016
#
# Current indx: 441
# Tweets to be processed: 460
# Processing tweet. ID = 1242743024544886784
#
# Current indx: 442
# Tweets to be processed: 459
# Processing tweet. ID = 1242743415088898050
#
# Current indx: 443
# Tweets to be processed: 458
# Processing tweet. ID = 1242743425360781312
#
# Current indx: 444
# Tweets to be processed: 457
# Processing tweet. ID = 1242743662498332673
#
# Current indx: 445
# Tweets to be processed: 456
# Processing tweet. ID = 1242743768287047680
#
# Current indx: 446
# Tweets to be processed: 455
# Processing tweet. ID = 1242743903435886592
#
# Current indx: 447
# Tweets to be processed: 454
# Processing tweet. ID = 1242743912957120513
#
# Current indx: 448
# Tweets to be processed: 453
# Processing tweet. ID = 1242743927377022977
#
# Current indx: 449
# Tweets to be processed: 452
# Processing tweet. ID = 1242744027989962752
#
# Current indx: 450
# Tweets to be processed: 451
# Processing tweet. ID = 1242744194906480640
#
# Current indx: 451
# Tweets to be processed: 450
# Processing tweet. ID = 1242744279170072576
#
# Current indx: 452
# Tweets to be processed: 449
# Processing tweet. ID = 1242744295075045376
#
# Current indx: 453
# Tweets to be processed: 448
# Processing tweet. ID = 1242744640484204544
#
# Current indx: 454
# Tweets to be processed: 447
# Processing tweet. ID = 1242744661774499840
#
# Current indx: 455
# Tweets to be processed: 446
# Processing tweet. ID = 1242745490505994241
#
# Current indx: 456
# Tweets to be processed: 445
# Processing tweet. ID = 1242745604276498432
#
# Current indx: 457
# Tweets to be processed: 444
# Processing tweet. ID = 1242745633263493121
#
# Current indx: 458
# Tweets to be processed: 443
# Processing tweet. ID = 1242745857042042880
#
# Current indx: 459
# Tweets to be processed: 442
# Processing tweet. ID = 1242745875631235072
#
# Current indx: 460
# Tweets to be processed: 441
# Processing tweet. ID = 1242745974717444096
#
# Current indx: 461
# Tweets to be processed: 440
# Processing tweet. ID = 1242746088987275265
#
# Current indx: 462
# Tweets to be processed: 439
# Processing tweet. ID = 1242746124781453313
#
# Current indx: 463
# Tweets to be processed: 438
# Processing tweet. ID = 1242746166795616256
#
# Current indx: 464
# Tweets to be processed: 437
# Processing tweet. ID = 1242746195178672128
#
# Current indx: 465
# Tweets to be processed: 436
# Processing tweet. ID = 1242746264002969600
#
# Current indx: 466
# Tweets to be processed: 435
# Processing tweet. ID = 1242746298526203904
#
# Current indx: 467
# Tweets to be processed: 434
# Processing tweet. ID = 1242746303576064002
#
# Current indx: 468
# Tweets to be processed: 433
# Processing tweet. ID = 1242746370534060033
#
# Current indx: 469
# Tweets to be processed: 432
# Processing tweet. ID = 1242746431229878272
#
# Current indx: 470
# Tweets to be processed: 431
# Processing tweet. ID = 1242746482832392194
#
# Current indx: 471
# Tweets to be processed: 430
# Processing tweet. ID = 1242746514776055808
#
# Current indx: 472
# Tweets to be processed: 429
# Processing tweet. ID = 1242746656249921542
#
# Current indx: 473
# Tweets to be processed: 428
# Processing tweet. ID = 1242746684796518402
#
# Current indx: 474
# Tweets to be processed: 427
# Processing tweet. ID = 1242746766052732928
#
# Current indx: 475
# Tweets to be processed: 426
# Processing tweet. ID = 1242746826618437639
#
# Current indx: 476
# Tweets to be processed: 425
# Processing tweet. ID = 1242746923888660482
#
# Current indx: 477
# Tweets to be processed: 424
# Processing tweet. ID = 1242746964283801602
#
# Current indx: 478
# Tweets to be processed: 423
# Processing tweet. ID = 1242746965898788864
#
# Current indx: 479
# Tweets to be processed: 422
# Processing tweet. ID = 1242747045410156544
#
# Current indx: 480
# Tweets to be processed: 421
# Processing tweet. ID = 1242747059913932801
#
# Current indx: 481
# Tweets to be processed: 420
# Processing tweet. ID = 1242747094059843584
#
# Current indx: 482
# Tweets to be processed: 419
# Processing tweet. ID = 1242747292039254016
#
# Current indx: 483
# Tweets to be processed: 418
# Processing tweet. ID = 1242747528501583872
#
# Current indx: 484
# Tweets to be processed: 417
# Processing tweet. ID = 1242747568821399552
#
# Current indx: 485
# Tweets to be processed: 416
# Processing tweet. ID = 1242747689357340672
#
# Current indx: 486
# Tweets to be processed: 415
# Processing tweet. ID = 1242747710240776192
#
# Current indx: 487
# Tweets to be processed: 414
# Processing tweet. ID = 1242747782634418177
#
# Current indx: 488
# Tweets to be processed: 413
# Processing tweet. ID = 1242747786845536256
#
# Current indx: 489
# Tweets to be processed: 412
# Processing tweet. ID = 1242747860489101313
#
# Current indx: 490
# Tweets to be processed: 411
# Processing tweet. ID = 1242748135161487360
#
# Current indx: 491
# Tweets to be processed: 410
# Processing tweet. ID = 1242748237531865090
#
# Current indx: 492
# Tweets to be processed: 409
# Processing tweet. ID = 1242748244611891200
#
# Current indx: 493
# Tweets to be processed: 408
# Processing tweet. ID = 1242748278870921217
#
# Current indx: 494
# Tweets to be processed: 407
# Processing tweet. ID = 1242748372911562752
#
# Current indx: 495
# Tweets to be processed: 406
# Processing tweet. ID = 1242748402636472320
#
# Current indx: 496
# Tweets to be processed: 405
# Processing tweet. ID = 1242748744870670338
#
# Current indx: 497
# Tweets to be processed: 404
# Processing tweet. ID = 1242748760603721728
#
# Current indx: 498
# Tweets to be processed: 403
# Processing tweet. ID = 1242748803540647936
#
# Current indx: 499
# Tweets to be processed: 402
# Processing tweet. ID = 1242748982301884417
#
# Current indx: 500
# Tweets to be processed: 401
# Processing tweet. ID = 1242749041538203649
# Text: @AshramGzb @AshramBlr @ashramgoregaon @AshramSgr @asharamjibapu_ @AmdAshram @LokKalyanSetu @AshramJodhpur @VapiAshram @ashramnashik May this New Year bring positive changes in the world . May corona get defeated by humanity.
#  #नववर्ष_पर_विश्वशांति_का_संकल्प
#  https://t.co/G1Z6DjbEkz
# https://t.co/kE1HehaYHy
#
# Current indx: 501
# Tweets to be processed: 400
# Processing tweet. ID = 1242749139068366848
#
# Current indx: 502
# Tweets to be processed: 399
# Processing tweet. ID = 1242749257595011074
#
# Current indx: 503
# Tweets to be processed: 398
# Processing tweet. ID = 1242749266545664000
#
# Current indx: 504
# Tweets to be processed: 397
# Processing tweet. ID = 1242749452047138816
#
# Current indx: 505
# Tweets to be processed: 396
# Processing tweet. ID = 1242749589469286401
#
# Current indx: 506
# Tweets to be processed: 395
# Processing tweet. ID = 1242749620251328513
#
# Current indx: 507
# Tweets to be processed: 394
# Processing tweet. ID = 1242749658520150017
#
# Current indx: 508
# Tweets to be processed: 393
# Processing tweet. ID = 1242749775075627010
#
# Current indx: 509
# Tweets to be processed: 392
# Processing tweet. ID = 1242749779945254912
#
# Current indx: 510
# Tweets to be processed: 391
# Processing tweet. ID = 1242750246670569472
#
# Current indx: 511
# Tweets to be processed: 390
# Processing tweet. ID = 1242750453600751616
#
# Current indx: 512
# Tweets to be processed: 389
# Processing tweet. ID = 1242750603744313347
#
# Current indx: 513
# Tweets to be processed: 388
# Processing tweet. ID = 1242750650124922881
#
# Current indx: 514
# Tweets to be processed: 387
# Processing tweet. ID = 1242750669519556608
#
# Current indx: 515
# Tweets to be processed: 386
# Processing tweet. ID = 1242750675789860865
#
# Current indx: 516
# Tweets to be processed: 385
# Processing tweet. ID = 1242750871076659201
#
# Current indx: 517
# Tweets to be processed: 384
# Processing tweet. ID = 1242750988412284929
#
# Current indx: 518
# Tweets to be processed: 383
# Processing tweet. ID = 1242751197477552128
#
# ...
# Processing tweet. ID = 1242776497074475008
#
# Current indx: 723
# Tweets to be processed: 178
# Processing tweet. ID = 1242776752713125888
#
# Current indx: 724
# Tweets to be processed: 177
# Processing tweet. ID = 1242776854638911488
#
# Current indx: 725
# Tweets to be processed: 176
# Processing tweet. ID = 1242776995064197121
#
# Current indx: 726
# Tweets to be processed: 175
# Processing tweet. ID = 1242777050894589952
#
# Current indx: 727
# Tweets to be processed: 174
# Processing tweet. ID = 1242777135216918528
#
# Current indx: 728
# Tweets to be processed: 173
# Processing tweet. ID = 1242777440025362432
#
# Current indx: 729
# Tweets to be processed: 172
# Processing tweet. ID = 1242777611459149824
#
# Current indx: 730
# Tweets to be processed: 171
# Processing tweet. ID = 1242777807651926016
#
# Current indx: 731
# Tweets to be processed: 170
# Processing tweet. ID = 1242777843228016641
#
# Current indx: 732
# Tweets to be processed: 169
# Processing tweet. ID = 1242777942238715905
#
# Current indx: 733
# Tweets to be processed: 168
# Processing tweet. ID = 1242778181393842176
#
# Current indx: 734
# Tweets to be processed: 167
# Processing tweet. ID = 1242778197797883906
#
# Current indx: 735
# Tweets to be processed: 166
# Processing tweet. ID = 1242778266315804673
#
# Current indx: 736
# Tweets to be processed: 165
# Processing tweet. ID = 1242778269612720129
#
# Current indx: 737
# Tweets to be processed: 164
# Processing tweet. ID = 1242778306249814019
#
# Current indx: 738
# Tweets to be processed: 163
# Processing tweet. ID = 1242778557077651456
#
# Current indx: 739
# Tweets to be processed: 162
# Processing tweet. ID = 1242778743203966978
#
# Current indx: 740
# Tweets to be processed: 161
# Processing tweet. ID = 1242779017234624515
#
# Current indx: 741
# Tweets to be processed: 160
# Processing tweet. ID = 1242779102500749312
#
# Current indx: 742
# Tweets to be processed: 159
# Processing tweet. ID = 1242779150970171398
#
# Current indx: 743
# Tweets to be processed: 158
# Processing tweet. ID = 1242779258923040769
#
# Current indx: 744
# Tweets to be processed: 157
# Processing tweet. ID = 1242779457531703297
#
# Current indx: 745
# Tweets to be processed: 156
# Processing tweet. ID = 1242779458936786944
#
# Current indx: 746
# Tweets to be processed: 155
# Processing tweet. ID = 1242779468529160197
#
# Current indx: 747
# Tweets to be processed: 154
# Processing tweet. ID = 1242779499730624512
#
# Current indx: 748
# Tweets to be processed: 153
# Processing tweet. ID = 1242779678173249536
#
# Current indx: 749
# Tweets to be processed: 152
# Processing tweet. ID = 1242779694610644995
#
# Current indx: 750
# Tweets to be processed: 151
# Processing tweet. ID = 1242779707386585091
#
# Current indx: 751
# Tweets to be processed: 150
# Processing tweet. ID = 1242779860797276160
#
# Current indx: 752
# Tweets to be processed: 149
# Processing tweet. ID = 1242780012601683968
#
# Current indx: 753
# Tweets to be processed: 148
# Processing tweet. ID = 1242780079169531905
#
# Current indx: 754
# Tweets to be processed: 147
# Processing tweet. ID = 1242780135192838144
#
# Current indx: 755
# Tweets to be processed: 146
# Processing tweet. ID = 1242780314616737792
#
# Current indx: 756
# Tweets to be processed: 145
# Processing tweet. ID = 1242780376893763585
#
# Current indx: 757
# Tweets to be processed: 144
# Processing tweet. ID = 1242780378898640896
#
# Current indx: 758
# Tweets to be processed: 143
# Processing tweet. ID = 1242780733095047170
#
# Current indx: 759
# Tweets to be processed: 142
# Processing tweet. ID = 1242780848199352321
#
# Current indx: 760
# Tweets to be processed: 141
# Processing tweet. ID = 1242780876267638784
#
# Current indx: 761
# Tweets to be processed: 140
# Processing tweet. ID = 1242780881816653824
#
# Current indx: 762
# Tweets to be processed: 139
# Processing tweet. ID = 1242780960858361856
#
# Current indx: 763
# Tweets to be processed: 138
# Processing tweet. ID = 1242781208578273282
#
# Current indx: 764
# Tweets to be processed: 137
# Processing tweet. ID = 1242781384831168512
#
# Current indx: 765
# Tweets to be processed: 136
# Processing tweet. ID = 1242781632026664962
#
# Current indx: 766
# Tweets to be processed: 135
# Processing tweet. ID = 1242781899757481984
#
# Current indx: 767
# Tweets to be processed: 134
# Processing tweet. ID = 1242781933408374784
#
# Current indx: 768
# Tweets to be processed: 133
# Processing tweet. ID = 1242782108071780352
#
# Current indx: 769
# Tweets to be processed: 132
# Processing tweet. ID = 1242782129282371587
#
# Current indx: 770
# Tweets to be processed: 131
# Processing tweet. ID = 1242782240586616835
#
# Current indx: 771
# Tweets to be processed: 130
# Processing tweet. ID = 1242782468505100291
#
# Current indx: 772
# Tweets to be processed: 129
# Processing tweet. ID = 1242782560247136258
#
# Current indx: 773
# Tweets to be processed: 128
# Processing tweet. ID = 1242782596813082624
#
# Current indx: 774
# Tweets to be processed: 127
# Processing tweet. ID = 1242782638688985088
#
# Current indx: 775
# Tweets to be processed: 126
# Processing tweet. ID = 1242782681420582913
#
# Current indx: 776
# Tweets to be processed: 125
# Processing tweet. ID = 1242782740216311809
#
# Current indx: 777
# Tweets to be processed: 124
# Processing tweet. ID = 1242782750404304898
#
# Current indx: 778
# Tweets to be processed: 123
# Processing tweet. ID = 1242782750953873409
#
# Current indx: 779
# Tweets to be processed: 122
# Processing tweet. ID = 1242782785607098369
#
# Current indx: 780
# Tweets to be processed: 121
# Processing tweet. ID = 1242782795908255745
#
# Current indx: 781
# Tweets to be processed: 120
# Processing tweet. ID = 1242782841357787136
#
# Current indx: 782
# Tweets to be processed: 119
# Processing tweet. ID = 1242782885116964864
#
# Current indx: 783
# Tweets to be processed: 118
# Processing tweet. ID = 1242783330308784130
#
# Current indx: 784
# Tweets to be processed: 117
# Processing tweet. ID = 1242783443848556544
#
# Current indx: 785
# Tweets to be processed: 116
# Processing tweet. ID = 1242783499028819968
#
# Current indx: 786
# Tweets to be processed: 115
# Processing tweet. ID = 1242783513109098497
#
# Current indx: 787
# Tweets to be processed: 114
# Processing tweet. ID = 1242783538572718085
#
# Current indx: 788
# Tweets to be processed: 113
# Processing tweet. ID = 1242783568050282498
#
# Current indx: 789
# Tweets to be processed: 112
# Processing tweet. ID = 1242783658894716928
#
# Current indx: 790
# Tweets to be processed: 111
# Processing tweet. ID = 1242783844073213952
#
# Current indx: 791
# Tweets to be processed: 110
# Processing tweet. ID = 1242783844081651718
#
# Current indx: 792
# Tweets to be processed: 109
# Processing tweet. ID = 1242783884040744961
#
# Current indx: 793
# Tweets to be processed: 108
# Processing tweet. ID = 1242783911161126913
#
# Current indx: 794
# Tweets to be processed: 107
# Processing tweet. ID = 1242783917704282117
#
# Current indx: 795
# Tweets to be processed: 106
# Processing tweet. ID = 1242783922984894465
#
# Current indx: 796
# Tweets to be processed: 105
# Processing tweet. ID = 1242784291903262720
#
# Current indx: 797
# Tweets to be processed: 104
# Processing tweet. ID = 1242784330717360128
#
# Current indx: 798
# Tweets to be processed: 103
# Processing tweet. ID = 1242784378687639553
#
# Current indx: 799
# Tweets to be processed: 102
# Processing tweet. ID = 1242784447969329154
#
# Current indx: 800
# Tweets to be processed: 101
# Processing tweet. ID = 1242784677930258432
# Text: @UN @UNHumanRights @lawinforce Sikhs all over the world should protest.@SikhPA @WorldSikhOrg https://t.co/FX8OYxuglU
#
# Current indx: 801
# Tweets to be processed: 100
# Processing tweet. ID = 1242784679893192704
#
# Current indx: 802
# Tweets to be processed: 99
# Processing tweet. ID = 1242784730589720578
#
# Current indx: 803
# Tweets to be processed: 98
# Processing tweet. ID = 1242784749598326785
#
# Current indx: 804
# Tweets to be processed: 97
# Processing tweet. ID = 1242784852417449984
#
# Current indx: 805
# Tweets to be processed: 96
# Processing tweet. ID = 1242784864564203521
#
# Current indx: 806
# Tweets to be processed: 95
# Processing tweet. ID = 1242785105896038401
#
# Current indx: 807
# Tweets to be processed: 94
# Processing tweet. ID = 1242785119414321154
#
# Current indx: 808
# Tweets to be processed: 93
# Processing tweet. ID = 1242785150888378369
#
# Current indx: 809
# Tweets to be processed: 92
# Processing tweet. ID = 1242785195993882625
#
# Current indx: 810
# Tweets to be processed: 91
# Processing tweet. ID = 1242785211764490240
#
# Current indx: 811
# Tweets to be processed: 90
# Processing tweet. ID = 1242785573317705728
#
# Current indx: 812
# Tweets to be processed: 89
# Processing tweet. ID = 1242785737658925062
#
# Current indx: 813
# Tweets to be processed: 88
# Processing tweet. ID = 1242785797356449792
#
# Current indx: 814
# Tweets to be processed: 87
# Processing tweet. ID = 1242785940524789760
#
# Current indx: 815
# Tweets to be processed: 86
# Processing tweet. ID = 1242786354565533696
#
# Current indx: 816
# Tweets to be processed: 85
# Processing tweet. ID = 1242786540583030787
#
# Current indx: 817
# Tweets to be processed: 84
# Processing tweet. ID = 1242786607981158400
#
# Current indx: 818
# Tweets to be processed: 83
# Processing tweet. ID = 1242786912382803968
#
# Current indx: 819
# Tweets to be processed: 82
# Processing tweet. ID = 1242786915364954112
#
# Current indx: 820
# Tweets to be processed: 81
# Processing tweet. ID = 1242786968301260800
#
# Current indx: 821
# Tweets to be processed: 80
# Processing tweet. ID = 1242787019895472130
#
# Current indx: 822
# Tweets to be processed: 79
# Processing tweet. ID = 1242787082243690497
#
# Current indx: 823
# Tweets to be processed: 78
# Processing tweet. ID = 1242787111566073857
#
# Current indx: 824
# Tweets to be processed: 77
# Processing tweet. ID = 1242787154176233475
#
# Current indx: 825
# Tweets to be processed: 76
# Processing tweet. ID = 1242787332975099910
#
# Current indx: 826
# Tweets to be processed: 75
# Processing tweet. ID = 1242787477796110336
#
# Current indx: 827
# Tweets to be processed: 74
# Processing tweet. ID = 1242787545890476032
#
# Current indx: 828
# Tweets to be processed: 73
# Processing tweet. ID = 1242787549677940736
#
# Current indx: 829
# Tweets to be processed: 72
# Processing tweet. ID = 1242787601163026432
#
# Current indx: 830
# Tweets to be processed: 71
# Processing tweet. ID = 1242787663993655296
#
# Current indx: 831
# Tweets to be processed: 70
# Processing tweet. ID = 1242788126407266306
#
# Current indx: 832
# Tweets to be processed: 69
# Processing tweet. ID = 1242788264769015809
#
# Current indx: 833
# Tweets to be processed: 68
# Processing tweet. ID = 1242788317768253442
#
# Current indx: 834
# Tweets to be processed: 67
# Processing tweet. ID = 1242788400828157953
#
# Current indx: 835
# Tweets to be processed: 66
# Processing tweet. ID = 1242788449683308544
#
# Current indx: 836
# Tweets to be processed: 65
# Processing tweet. ID = 1242788487688007680
#
# Current indx: 837
# Tweets to be processed: 64
# Processing tweet. ID = 1242788571032903680
#
# Current indx: 838
# Tweets to be processed: 63
# Processing tweet. ID = 1242788882355126272
#
# Current indx: 839
# Tweets to be processed: 62
# Processing tweet. ID = 1242788910276546566
#
# Current indx: 840
# Tweets to be processed: 61
# Processing tweet. ID = 1242788934641315840
#
# Current indx: 841
# Tweets to be processed: 60
# Processing tweet. ID = 1242789064215949313
#
# Current indx: 842
# Tweets to be processed: 59
# Processing tweet. ID = 1242789174903635974
#
# Current indx: 843
# Tweets to be processed: 58
# Processing tweet. ID = 1242789251621597185
#
# Current indx: 844
# Tweets to be processed: 57
# Processing tweet. ID = 1242789478260932608
#
# Current indx: 845
# Tweets to be processed: 56
# Processing tweet. ID = 1242789486775250945
#
# Current indx: 846
# Tweets to be processed: 55
# Processing tweet. ID = 1242789590416711681
#
# Current indx: 847
# Tweets to be processed: 54
# Processing tweet. ID = 1242789639783473152
#
# Current indx: 848
# Tweets to be processed: 53
# Processing tweet. ID = 1242789743030448130
#
# Current indx: 849
# Tweets to be processed: 52
# Processing tweet. ID = 1242789873502679040
#
# Current indx: 850
# Tweets to be processed: 51
# Processing tweet. ID = 1242789875293831169
#
# Current indx: 851
# Tweets to be processed: 50
# Processing tweet. ID = 1242789903131435008
#
# Current indx: 852
# Tweets to be processed: 49
# Processing tweet. ID = 1242789932810133504
#
# Current indx: 853
# Tweets to be processed: 48
# Processing tweet. ID = 1242789961860030464
#
# Current indx: 854
# Tweets to be processed: 47
# Processing tweet. ID = 1242790007678447616
#
# Current indx: 855
# Tweets to be processed: 46
# Processing tweet. ID = 1242790014804770816
#
# Current indx: 856
# Tweets to be processed: 45
# Processing tweet. ID = 1242790021251223552
#
# Current indx: 857
# Tweets to be processed: 44
# Processing tweet. ID = 1242790057716543489
#
# Current indx: 858
# Tweets to be processed: 43
# Processing tweet. ID = 1242790082261610501
#
# Current indx: 859
# Tweets to be processed: 42
# Processing tweet. ID = 1242790091279327233
#
# Current indx: 860
# Tweets to be processed: 41
# Processing tweet. ID = 1242790104575299584
#
# Current indx: 861
# Tweets to be processed: 40
# Processing tweet. ID = 1242790135067856896
#
# Current indx: 862
# Tweets to be processed: 39
# Processing tweet. ID = 1242790344506232832
#
# Current indx: 863
# Tweets to be processed: 38
# Processing tweet. ID = 1242790362051207168
#
# Current indx: 864
# Tweets to be processed: 37
# Processing tweet. ID = 1242790364068466688
#
# Current indx: 865
# Tweets to be processed: 36
# Processing tweet. ID = 1242790458767462401
#
# Current indx: 866
# Tweets to be processed: 35
# Processing tweet. ID = 1242790532125843457
#
# Current indx: 867
# Tweets to be processed: 34
# Processing tweet. ID = 1242790660320768000
#
# Current indx: 868
# Tweets to be processed: 33
# Processing tweet. ID = 1242790726053670912
#
# Current indx: 869
# Tweets to be processed: 32
# Processing tweet. ID = 1242790798040748032
#
# Current indx: 870
# Tweets to be processed: 31
# Processing tweet. ID = 1242790818118660096
#
# Current indx: 871
# Tweets to be processed: 30
# Processing tweet. ID = 1242790978739556352
#
# Current indx: 872
# Tweets to be processed: 29
# Processing tweet. ID = 1242791102056247298
#
# Current indx: 873
# Tweets to be processed: 28
# Processing tweet. ID = 1242791119408119808
#
# Current indx: 874
# Tweets to be processed: 27
# Processing tweet. ID = 1242791252329816064
#
# Current indx: 875
# Tweets to be processed: 26
# Processing tweet. ID = 1242791402712354816
#
# Current indx: 876
# Tweets to be processed: 25
# Processing tweet. ID = 1242791484098629633
#
# Current indx: 877
# Tweets to be processed: 24
# Processing tweet. ID = 1242791579254804480
#
# Current indx: 878
# Tweets to be processed: 23
# Processing tweet. ID = 1242791610259144706
#
# Current indx: 879
# Tweets to be processed: 22
# Processing tweet. ID = 1242791651401072640
#
# Current indx: 880
# Tweets to be processed: 21
# Processing tweet. ID = 1242791776601042951
#
# Current indx: 881
# Tweets to be processed: 20
# Processing tweet. ID = 1242791782460444673
#
# Current indx: 882
# Tweets to be processed: 19
# Processing tweet. ID = 1242792032633942017
#
# Current indx: 883
# Tweets to be processed: 18
# Processing tweet. ID = 1242792136065589248
#
# Current indx: 884
# Tweets to be processed: 17
# Processing tweet. ID = 1242792231674626048
#
# Current indx: 885
# Tweets to be processed: 16
# Processing tweet. ID = 1242792249873666048
#
# Current indx: 886
# Tweets to be processed: 15
# Processing tweet. ID = 1242792289866354692
#
# Current indx: 887
# Tweets to be processed: 14
# Processing tweet. ID = 1242792342655922177
#
# Current indx: 888
# Tweets to be processed: 13
# Processing tweet. ID = 1242792348267900928
#
# Current indx: 889
# Tweets to be processed: 12
# Processing tweet. ID = 1242792377305067524
#
# Current indx: 890
# Tweets to be processed: 11
# Processing tweet. ID = 1242792404760981506
#
# Current indx: 891
# Tweets to be processed: 10
# Processing tweet. ID = 1242792433034776576
#
# Current indx: 892
# Tweets to be processed: 9
# Processing tweet. ID = 1242792443214471176
#
# Current indx: 893
# Tweets to be processed: 8
# Processing tweet. ID = 1242792510163791872
#
# Current indx: 894
# Tweets to be processed: 7
# Processing tweet. ID = 1242792774979604482
#
# Current indx: 895
# Tweets to be processed: 6
# Processing tweet. ID = 1242792918387060736
#
# Current indx: 896
# Tweets to be processed: 5
# Processing tweet. ID = 1242793054446051328
#
# Current indx: 897
# Tweets to be processed: 4
# Processing tweet. ID = 1242793057755336705
#
# Current indx: 898
# Tweets to be processed: 3
# Processing tweet. ID = 1242793132699181056
#
# Current indx: 899
# Tweets to be processed: 2
# Processing tweet. ID = 1242793137598115840

# %%
indx_manager_write = open('index_manager.txt', 'w')
indx_manager_write.write(str(indx))
indx_manager_write.close()
print(str(indx))
# Out:
# 900

# %%
text_2 = text
for ttext in text:
    ttext = ttext.strip("\n")

# %%
#         text.append(tweet.full_text)
#         created_at.append(tweet.created_at)
#         id_str.append(tweet.id_str)
#         entities.append(tweet.entities)
#         user_id.append(tweet.user.id)
#         location.append(tweet.user.location)
#         lang.append(tweet.lang)
#         time_zone.append(tweet.user.time_zone)

for loc in location[:10]:
    print(loc)
# Out:
# India
#
# India
# India
# Brunswick, Germany
#
# Narayanpet, India
# Kolkata
# New Delhi,Mumbai,India,Dubai..

# %%
import pandas as pd

# df = pd.DataFrame(columns=['id_str', 'user_id', 'text', 'created_at', 'entities', 'location', 'lang', 'time_zone'])
df = pd.DataFrame(columns=['id_str', 'user_id', 'text', 'created_at', 'entities', 'lang', 'time_zone'])
df.head()

df['id_str'] = id_str
df['user_id'] = user_id
df['text'] = text
df['created_at'] = created_at
df['entities'] = entities
# df['location'] = location
df['lang'] = lang
df['time_zone'] = time_zone

# %%
df.head()
# Out:
#                 id_str              user_id  \
# 0  1242693402971406342  1211110380249858049
# 1  1242693578817597442           2558507150
# 2  1242693609725575168  1242691555628060672
# 3  1242693680143544325   787255787961872388
# 4  1242693745755262977  1230923356519555072
#
#                                                 text          created_at  \
# 0  CORONA 19 UPDATE \n---------------------------... 2020-03-25 06:02:50
# 1  Anti Corona T-shirt collection is online for s... 2020-03-25 06:03:31
# 2  The matter is serious. Take full care not to b... 2020-03-25 06:03:39
# 3  All Mosque committee members headed by Syed Ga... 2020-03-25 06:03:56
# 4  @aajtak If these Indians are already infected ... 2020-03-25 06:04:11
#
#                                             entities lang time_zone
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...   en      None
# 1  {'hashtags': [{'text': '21daysLockdown', 'indi...   en      None
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...   en      None
# 3  {'hashtags': [{'text': 'Narayanpet', 'indices'...   en      None
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...   en      None

# %%
# file_new = open('file_manager.txt', 'r')
# file_indx = file_new.read()
# file_new.close()
# filename = 'final_tweets_' + file_indx + '.csv'
filename = 'final_tweets_1.csv'
print(filename)
# Out:
# final_tweets_1.csv

# %%
df.to_csv(filename)

# %%
file_indx = int(file_indx)
file_indx += 1

file_write = open('file_manager.txt', 'w')
file_write.write(str(file_indx))
file_write.close()

# %%
print(file_indx)
# Out:
# 2

# %%
######## DO NOT RUN #################


# print("writing to dataset")
# with open("tweets.txt", "w+") as f:
#     for tweet in tweets:
#         print("writing to txt file. tweet: " + str(tweet))
#         f.write("%s\n" % str(tweet))
        
# print("writing to dataset")
# with open("dates.txt", "w+") as f:
#     for date in dates:
#         print("writing to txt file. tweet: " + str(date))
#         f.write("%s\n" % str(date))

# %%
id_t = tweets_df['tweet_id'].tolist()[1]
tweet_2 = api.get_status(id_t, tweet_mode = 'extended')
print(tweet_2.full_text)
# Out:
# CORONA 19 UPDATE
# ----------------------------------------------------------
# Total effected : 420000
# Recovered : 107000
# Fatality : 18500
# Under Treatment : ( 420000-107000) = 313000
# Fatality Rate = 18500/420000×100=  4.4 %
# UT Rate = 74.52%
#
# GLOBAL FIGURE
