# %%
import tweepy as tw
import pandas as pd
import os
import csv

# %%
consumer_key = "IQFN7RfvSs3107ZGKq1vDE2Um"
consumer_secret = "JF8rB1ftzNPzNKCUGHTZXtZV22yiCK51bJnl51t1riNnLy4cuJ"
access_token = "1008966897130303488-PNJTNYKhrs5q3YbCIZf2lRGC817JSQ"
access_token_secret = "89xKwZBAZBUHLVqoayE1gDGfuJeJwzLhnkZ7NnXvOJZ6v"

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
tweets_df = pd.read_csv("tweet_ids.csv")
tweets_df.head()
# Out:
#    Unnamed: 0             tweet_id
# 0         0.0  1242693364098580481
# 1         1.0  1242693402971406342
# 2         2.0  1242693578817597442
# 3         3.0  1242693609725575168
# 4         4.0  1242693680143544325

# %%
index_manager_read = open('index_manager.txt', 'r')
indx = index_manager_read.read()
print(indx)
index_manager_read.close()
# Out:
# 1799

# %%
twitter_ids = tweets_df["tweet_id"].tolist()
i = 0
indx = int(indx)
ids = twitter_ids[indx:indx + 899]

text = []
id_str = []
entities_hashtags = []
entities_symbols = []
entities = []
user_id = []
user_ion = []
time_zone = []
lang = []
created_at = []

cnt = 0

# %%
for tweet_id in ids:
    
    print("\nCurrent indx: " + str(indx))
    print("Tweets to be processed: " + str(900-cnt))
    cnt += 1 
    indx += 1
    
    try:
        print("Processing tweet. ID = " + str(tweet_id))
        
        tweet = api.get_status(tweet_id, tweet_mode = 'extended', include_entities = True)
        
        text.append(tweet.full_text)
        created_at.append(tweet.created_at)
        id_str.append(tweet.id_str)
        entities.append(tweet.entities)
        user_id.append(tweet.user.id)
        lang.append(tweet.lang)
        time_zone.append(tweet.user.time_zone)
        
        if(cnt%100 == 0):
            print("Text: " + str(tweet.full_text))
    except tw.error.TweepError:
      print("Error while accessing tweet. ID: " + str(tweet_id))
      pass
# Out:
# Current indx: 1799
# Tweets to be processed: 900
# Processing tweet. ID = 1242874670736695297
#
# Current indx: 1800
# Tweets to be processed: 899
# Processing tweet. ID = 1242874722791993344
#
# Current indx: 1801
# Tweets to be processed: 898
# Processing tweet. ID = 1242874757332086784
#
# Current indx: 1802
# Tweets to be processed: 897
# Processing tweet. ID = 1242874803599491073
#
# Current indx: 1803
# Tweets to be processed: 896
# Processing tweet. ID = 1242874896885006337
#
# Current indx: 1804
# Tweets to be processed: 895
# Processing tweet. ID = 1242874965298311168
#
# Current indx: 1805
# Tweets to be processed: 894
# Processing tweet. ID = 1242876098641145856
#
# Current indx: 1806
# Tweets to be processed: 893
# Processing tweet. ID = 1242876103892459520
#
# Current indx: 1807
# Tweets to be processed: 892
# Processing tweet. ID = 1242876211140804613
#
# Current indx: 1808
# Tweets to be processed: 891
# Processing tweet. ID = 1242876302677266432
#
# Current indx: 1809
# Tweets to be processed: 890
# Processing tweet. ID = 1242876986181083136
#
# Current indx: 1810
# Tweets to be processed: 889
# Processing tweet. ID = 1242877112379248640
#
# Current indx: 1811
# Tweets to be processed: 888
# Processing tweet. ID = 1242877152178999296
#
# Current indx: 1812
# Tweets to be processed: 887
# Processing tweet. ID = 1242877190187798528
#
# Current indx: 1813
# Tweets to be processed: 886
# Processing tweet. ID = 1242877239835766786
#
# Current indx: 1814
# Tweets to be processed: 885
# Processing tweet. ID = 1242877562696527873
#
# Current indx: 1815
# Tweets to be processed: 884
# Processing tweet. ID = 1242877717982273536
#
# Current indx: 1816
# Tweets to be processed: 883
# Processing tweet. ID = 1242877806905679872
#
# Current indx: 1817
# Tweets to be processed: 882
# Processing tweet. ID = 1242877874664767495
#
# Current indx: 1818
# Tweets to be processed: 881
# Processing tweet. ID = 1242878546978033665
#
# Current indx: 1819
# Tweets to be processed: 880
# Processing tweet. ID = 1242878770219868161
#
# Current indx: 1820
# Tweets to be processed: 879
# Processing tweet. ID = 1242878991465209856
#
# Current indx: 1821
# Tweets to be processed: 878
# Processing tweet. ID = 1242879039540527105
#
# Current indx: 1822
# Tweets to be processed: 877
# Processing tweet. ID = 1242879238304182272
#
# Current indx: 1823
# Tweets to be processed: 876
# Processing tweet. ID = 1242879294830858246
#
# Current indx: 1824
# Tweets to be processed: 875
# Processing tweet. ID = 1242879973938966528
#
# Current indx: 1825
# Tweets to be processed: 874
# Processing tweet. ID = 1242879976350728192
#
# Current indx: 1826
# Tweets to be processed: 873
# Processing tweet. ID = 1242880168680517632
#
# Current indx: 1827
# Tweets to be processed: 872
# Processing tweet. ID = 1242880275241037825
#
# Current indx: 1828
# Tweets to be processed: 871
# Processing tweet. ID = 1242880705249476608
#
# Current indx: 1829
# Tweets to be processed: 870
# Processing tweet. ID = 1242880759393701888
#
# Current indx: 1830
# Tweets to be processed: 869
# Processing tweet. ID = 1242880780889718790
#
# Current indx: 1831
# Tweets to be processed: 868
# Processing tweet. ID = 1242880982111236096
#
# Current indx: 1832
# Tweets to be processed: 867
# Processing tweet. ID = 1242881147895332864
#
# Current indx: 1833
# Tweets to be processed: 866
# Processing tweet. ID = 1242881170162868225
#
# Current indx: 1834
# Tweets to be processed: 865
# Processing tweet. ID = 1242881320214118400
#
# Current indx: 1835
# Tweets to be processed: 864
# Processing tweet. ID = 1242881390712143872
#
# Current indx: 1836
# Tweets to be processed: 863
# Processing tweet. ID = 1242881640197533702
#
# Current indx: 1837
# Tweets to be processed: 862
# Processing tweet. ID = 1242881766966185984
#
# Current indx: 1838
# Tweets to be processed: 861
# Processing tweet. ID = 1242881798754820101
#
# Current indx: 1839
# Tweets to be processed: 860
# Processing tweet. ID = 1242881836243550208
#
# Current indx: 1840
# Tweets to be processed: 859
# Processing tweet. ID = 1242882170332405760
#
# Current indx: 1841
# Tweets to be processed: 858
# Processing tweet. ID = 1242882334300364800
#
# Current indx: 1842
# Tweets to be processed: 857
# Processing tweet. ID = 1242882508741423104
#
# Current indx: 1843
# Tweets to be processed: 856
# Processing tweet. ID = 1242882513829269508
#
# Current indx: 1844
# Tweets to be processed: 855
# Processing tweet. ID = 1242882606187728896
#
# Current indx: 1845
# Tweets to be processed: 854
# Processing tweet. ID = 1242882619756253184
#
# Current indx: 1846
# Tweets to be processed: 853
# Processing tweet. ID = 1242882628711100416
#
# Current indx: 1847
# Tweets to be processed: 852
# Processing tweet. ID = 1242883073630298112
#
# Current indx: 1848
# Tweets to be processed: 851
# Processing tweet. ID = 1242883170195746816
#
# Current indx: 1849
# Tweets to be processed: 850
# Processing tweet. ID = 1242883189015633921
#
# Current indx: 1850
# Tweets to be processed: 849
# Processing tweet. ID = 1242883344435539969
#
# Current indx: 1851
# Tweets to be processed: 848
# Processing tweet. ID = 1242883349745561602
#
# Current indx: 1852
# Tweets to be processed: 847
# Processing tweet. ID = 1242883380317802497
#
# Current indx: 1853
# Tweets to be processed: 846
# Processing tweet. ID = 1242883423640797184
#
# Current indx: 1854
# Tweets to be processed: 845
# Processing tweet. ID = 1242883478221230083
#
# Current indx: 1855
# Tweets to be processed: 844
# Processing tweet. ID = 1242883494478376962
#
# Current indx: 1856
# Tweets to be processed: 843
# Processing tweet. ID = 1242883758400794624
#
# Current indx: 1857
# Tweets to be processed: 842
# Processing tweet. ID = 1242883861505134592
#
# Current indx: 1858
# Tweets to be processed: 841
# Processing tweet. ID = 1242883949321285632
#
# Current indx: 1859
# Tweets to be processed: 840
# Processing tweet. ID = 1242884076626821122
#
# Current indx: 1860
# Tweets to be processed: 839
# Processing tweet. ID = 1242884370253283331
#
# Current indx: 1861
# Tweets to be processed: 838
# Processing tweet. ID = 1242884396354396160
#
# Current indx: 1862
# Tweets to be processed: 837
# Processing tweet. ID = 1242884536385425408
#
# Current indx: 1863
# Tweets to be processed: 836
# Processing tweet. ID = 1242884857916604416
#
# Current indx: 1864
# Tweets to be processed: 835
# Processing tweet. ID = 1242884902548148225
#
# Current indx: 1865
# Tweets to be processed: 834
# Processing tweet. ID = 1242884942792667137
#
# Current indx: 1866
# Tweets to be processed: 833
# Processing tweet. ID = 1242885467067969536
#
# Current indx: 1867
# Tweets to be processed: 832
# Processing tweet. ID = 1242885654725292032
#
# Current indx: 1868
# Tweets to be processed: 831
# Processing tweet. ID = 1242885665802670083
#
# Current indx: 1869
# Tweets to be processed: 830
# Processing tweet. ID = 1242885817506205696
#
# Current indx: 1870
# Tweets to be processed: 829
# Processing tweet. ID = 1242886029486387202
#
# Current indx: 1871
# Tweets to be processed: 828
# Processing tweet. ID = 1242886094405812224
#
# Current indx: 1872
# Tweets to be processed: 827
# Processing tweet. ID = 1242886193802428416
#
# Current indx: 1873
# Tweets to be processed: 826
# Processing tweet. ID = 1242886281291599873
#
# Current indx: 1874
# Tweets to be processed: 825
# Processing tweet. ID = 1242886291781332992
#
# Current indx: 1875
# Tweets to be processed: 824
# Processing tweet. ID = 1242886547361468417
#
# Current indx: 1876
# Tweets to be processed: 823
# Processing tweet. ID = 1242886639757606912
#
# Current indx: 1877
# Tweets to be processed: 822
# Processing tweet. ID = 1242886792782565376
#
# Current indx: 1878
# Tweets to be processed: 821
# Processing tweet. ID = 1242886816304230401
#
# Current indx: 1879
# Tweets to be processed: 820
# Processing tweet. ID = 1242887061150896128
#
# Current indx: 1880
# Tweets to be processed: 819
# Processing tweet. ID = 1242887089932234754
#
# Current indx: 1881
# Tweets to be processed: 818
# Processing tweet. ID = 1242887168810311680
#
# Current indx: 1882
# Tweets to be processed: 817
# Processing tweet. ID = 1242887184438476801
#
# Current indx: 1883
# Tweets to be processed: 816
# Processing tweet. ID = 1242887203119751168
#
# Current indx: 1884
# Tweets to be processed: 815
# Processing tweet. ID = 1242887471035068417
#
# Current indx: 1885
# Tweets to be processed: 814
# Processing tweet. ID = 1242887478249287680
#
# Current indx: 1886
# Tweets to be processed: 813
# Processing tweet. ID = 1242887658554048512
#
# Current indx: 1887
# Tweets to be processed: 812
# Processing tweet. ID = 1242887858412650498
#
# Current indx: 1888
# Tweets to be processed: 811
# Processing tweet. ID = 1242887895939080192
#
# Current indx: 1889
# Tweets to be processed: 810
# Processing tweet. ID = 1242887921683718144
#
# Current indx: 1890
# Tweets to be processed: 809
# Processing tweet. ID = 1242887976528429056
#
# Current indx: 1891
# Tweets to be processed: 808
# Processing tweet. ID = 1242888047915483136
#
# Current indx: 1892
# Tweets to be processed: 807
# Processing tweet. ID = 1242888050171990016
#
# Current indx: 1893
# Tweets to be processed: 806
# Processing tweet. ID = 1242888297627688963
#
# Current indx: 1894
# Tweets to be processed: 805
# Processing tweet. ID = 1242888302577016837
#
# Current indx: 1895
# Tweets to be processed: 804
# Processing tweet. ID = 1242888352065437697
#
# Current indx: 1896
# Tweets to be processed: 803
# Processing tweet. ID = 1242888368242843649
#
# Current indx: 1897
# Tweets to be processed: 802
# Processing tweet. ID = 1242888433615372288
#
# Current indx: 1898
# Tweets to be processed: 801
# Processing tweet. ID = 1242888455522111495
# Text: Chat About #Corona https://t.co/CnE8aGRnDV via @YouTube @nishjamvwal #StopTheSpreadOfCorona #COVID2019
#
# Current indx: 1899
# Tweets to be processed: 800
# Processing tweet. ID = 1242888574917173248
#
# Current indx: 1900
# Tweets to be processed: 799
# Processing tweet. ID = 1242888614746271744
#
# Current indx: 1901
# Tweets to be processed: 798
# Processing tweet. ID = 1242888918422319105
#
# Current indx: 1902
# Tweets to be processed: 797
# Processing tweet. ID = 1242889171095547904
#
# Current indx: 1903
# Tweets to be processed: 796
# Processing tweet. ID = 1242889225046917120
#
# Current indx: 1904
# Tweets to be processed: 795
# Processing tweet. ID = 1242889359826673664
#
# Current indx: 1905
# Tweets to be processed: 794
# Processing tweet. ID = 1242889674063933441
#
# Current indx: 1906
# Tweets to be processed: 793
# Processing tweet. ID = 1242889762056204288
# Error while accessing tweet. ID: 1242889762056204288
#
# Current indx: 1907
# Tweets to be processed: 792
# Processing tweet. ID = 1242889792796286977
#
# Current indx: 1908
# Tweets to be processed: 791
# Processing tweet. ID = 1242890294741405696
#
# Current indx: 1909
# Tweets to be processed: 790
# Processing tweet. ID = 1242890316996206593
#
# Current indx: 1910
# Tweets to be processed: 789
# Processing tweet. ID = 1242890343692959745
#
# Current indx: 1911
# Tweets to be processed: 788
# Processing tweet. ID = 1242890633125048320
#
# Current indx: 1912
# Tweets to be processed: 787
# Processing tweet. ID = 1242890834271277056
#
# Current indx: 1913
# Tweets to be processed: 786
# Processing tweet. ID = 1242890972658192386
#
# Current indx: 1914
# Tweets to be processed: 785
# Processing tweet. ID = 1242890972662394880
#
# Current indx: 1915
# Tweets to be processed: 784
# Processing tweet. ID = 1242891159262736384
#
# Current indx: 1916
# Tweets to be processed: 783
# Processing tweet. ID = 1242891237251624960
#
# Current indx: 1917
# Tweets to be processed: 782
# Processing tweet. ID = 1242891306566709248
#
# Current indx: 1918
# Tweets to be processed: 781
# Processing tweet. ID = 1242891352750227456
#
# Current indx: 1919
# Tweets to be processed: 780
# Processing tweet. ID = 1242891372949983232
#
# Current indx: 1920
# Tweets to be processed: 779
# Processing tweet. ID = 1242891386170433536
#
# Current indx: 1921
# Tweets to be processed: 778
# Processing tweet. ID = 1242891516105777152
#
# Current indx: 1922
# Tweets to be processed: 777
# Processing tweet. ID = 1242891845522227200
#
# Current indx: 1923
# Tweets to be processed: 776
# Processing tweet. ID = 1242892189375639553
#
# Current indx: 1924
# Tweets to be processed: 775
# Processing tweet. ID = 1242892383844331520
#
# Current indx: 1925
# Tweets to be processed: 774
# Processing tweet. ID = 1242892552115609607
#
# Current indx: 1926
# Tweets to be processed: 773
# Processing tweet. ID = 1242892647783686147
#
# Current indx: 1927
# Tweets to be processed: 772
# Processing tweet. ID = 1242893185132576768
#
# Current indx: 1928
# Tweets to be processed: 771
# Processing tweet. ID = 1242893222776418304
#
# Current indx: 1929
# Tweets to be processed: 770
# Processing tweet. ID = 1242893302065586176
#
# Current indx: 1930
# Tweets to be processed: 769
# Processing tweet. ID = 1242893437969387521
#
# Current indx: 1931
# Tweets to be processed: 768
# Processing tweet. ID = 1242893623391219712
#
# Current indx: 1932
# Tweets to be processed: 767
# Processing tweet. ID = 1242893729301557248
#
# Current indx: 1933
# Tweets to be processed: 766
# Processing tweet. ID = 1242893820905185280
#
# Current indx: 1934
# Tweets to be processed: 765
# Processing tweet. ID = 1242893847039860736
#
# Current indx: 1935
# Tweets to be processed: 764
# Processing tweet. ID = 1242894176728973313
#
# Current indx: 1936
# Tweets to be processed: 763
# Processing tweet. ID = 1242894271818141697
#
# Current indx: 1937
# Tweets to be processed: 762
# Processing tweet. ID = 1242894347369992192
#
# Current indx: 1938
# Tweets to be processed: 761
# Processing tweet. ID = 1242894972967215105
#
# Current indx: 1939
# Tweets to be processed: 760
# Processing tweet. ID = 1242895252173623296
#
# Current indx: 1940
# Tweets to be processed: 759
# Processing tweet. ID = 1242895365755375616
#
# Current indx: 1941
# Tweets to be processed: 758
# Processing tweet. ID = 1242896199423643648
#
# Current indx: 1942
# Tweets to be processed: 757
# Processing tweet. ID = 1242896743471222793
#
# Current indx: 1943
# Tweets to be processed: 756
# Processing tweet. ID = 1242897025101787136
#
# Current indx: 1944
# Tweets to be processed: 755
# Processing tweet. ID = 1242897120744501249
#
# Current indx: 1945
# Tweets to be processed: 754
# Processing tweet. ID = 1242897204223696896
#
# Current indx: 1946
# Tweets to be processed: 753
# Processing tweet. ID = 1242897406036975618
#
# Current indx: 1947
# Tweets to be processed: 752
# Processing tweet. ID = 1242897704809664512
#
# Current indx: 1948
# Tweets to be processed: 751
# Processing tweet. ID = 1242897740641660928
#
# Current indx: 1949
# Tweets to be processed: 750
# Processing tweet. ID = 1242898330339799040
#
# Current indx: 1950
# Tweets to be processed: 749
# Processing tweet. ID = 1242898374002528256
#
# Current indx: 1951
# Tweets to be processed: 748
# Processing tweet. ID = 1242898582534942721
#
# Current indx: 1952
# Tweets to be processed: 747
# Processing tweet. ID = 1242898766639894528
#
# Current indx: 1953
# Tweets to be processed: 746
# Processing tweet. ID = 1242898797073559552
#
# Current indx: 1954
# Tweets to be processed: 745
# Processing tweet. ID = 1242898912001826817
#
# Current indx: 1955
# Tweets to be processed: 744
# Processing tweet. ID = 1242898972252880896
#
# Current indx: 1956
# Tweets to be processed: 743
# Processing tweet. ID = 1242899209826656256
#
# Current indx: 1957
# Tweets to be processed: 742
# Processing tweet. ID = 1242899329079074816
#
# Current indx: 1958
# Tweets to be processed: 741
# Processing tweet. ID = 1242899823197450241
#
# Current indx: 1959
# Tweets to be processed: 740
# Processing tweet. ID = 1242899856521232384
#
# Current indx: 1960
# Tweets to be processed: 739
# Processing tweet. ID = 1242900258222272512
#
# Current indx: 1961
# Tweets to be processed: 738
# Processing tweet. ID = 1242900828882644998
#
# Current indx: 1962
# Tweets to be processed: 737
# Processing tweet. ID = 1242900909841137665
#
# Current indx: 1963
# Tweets to be processed: 736
# Processing tweet. ID = 1242901030913708032
#
# Current indx: 1964
# Tweets to be processed: 735
# Processing tweet. ID = 1242901288267833344
# Error while accessing tweet. ID: 1242901288267833344
#
# Current indx: 1965
# Tweets to be processed: 734
# Processing tweet. ID = 1242901523539070978
#
# Current indx: 1966
# Tweets to be processed: 733
# Processing tweet. ID = 1242901725553422336
#
# Current indx: 1967
# Tweets to be processed: 732
# Processing tweet. ID = 1242902009381916672
#
# Current indx: 1968
# Tweets to be processed: 731
# Processing tweet. ID = 1242902136691871750
#
# Current indx: 1969
# Tweets to be processed: 730
# Processing tweet. ID = 1242902171739250690
# Error while accessing tweet. ID: 1242902171739250690
#
# Current indx: 1970
# Tweets to be processed: 729
# Processing tweet. ID = 1242902357244907520
#
# Current indx: 1971
# Tweets to be processed: 728
# Processing tweet. ID = 1242902748015685632
#
# Current indx: 1972
# Tweets to be processed: 727
# Processing tweet. ID = 1242902758228811776
#
# Current indx: 1973
# Tweets to be processed: 726
# Processing tweet. ID = 1242903149729497088
#
# Current indx: 1974
# Tweets to be processed: 725
# Processing tweet. ID = 1242903253198626817
#
# Current indx: 1975
# Tweets to be processed: 724
# Processing tweet. ID = 1242903264191860736
#
# Current indx: 1976
# Tweets to be processed: 723
# Processing tweet. ID = 1242903598792503298
#
# Current indx: 1977
# Tweets to be processed: 722
# Processing tweet. ID = 1242903711669571584
#
# Current indx: 1978
# Tweets to be processed: 721
# Processing tweet. ID = 1242903728501317632
#
# Current indx: 1979
# Tweets to be processed: 720
# Processing tweet. ID = 1242904327351463937
#
# Current indx: 1980
# Tweets to be processed: 719
# Processing tweet. ID = 1242905016228179968
#
# Current indx: 1981
# Tweets to be processed: 718
# Processing tweet. ID = 1242905114093834241
#
# Current indx: 1982
# Tweets to be processed: 717
# Processing tweet. ID = 1242905678571655168
#
# Current indx: 1983
# Tweets to be processed: 716
# Processing tweet. ID = 1242906493747249152
#
# Current indx: 1984
# Tweets to be processed: 715
# Processing tweet. ID = 1242906674626793474
#
# Current indx: 1985
# Tweets to be processed: 714
# Processing tweet. ID = 1242907530705154050
#
# Current indx: 1986
# Tweets to be processed: 713
# Processing tweet. ID = 1242907644051898368
#
# Current indx: 1987
# Tweets to be processed: 712
# Processing tweet. ID = 1242907690289905664
#
# Current indx: 1988
# Tweets to be processed: 711
# Processing tweet. ID = 1242907898063159296
#
# Current indx: 1989
# Tweets to be processed: 710
# Processing tweet. ID = 1242908062731493377
#
# Current indx: 1990
# Tweets to be processed: 709
# Processing tweet. ID = 1242908382807244802
#
# Current indx: 1991
# Tweets to be processed: 708
# Processing tweet. ID = 1242908652299681792
#
# Current indx: 1992
# Tweets to be processed: 707
# Processing tweet. ID = 1242908733161627648
#
# Current indx: 1993
# Tweets to be processed: 706
# Processing tweet. ID = 1242909010199818241
#
# Current indx: 1994
# Tweets to be processed: 705
# Processing tweet. ID = 1242909867347591169
#
# Current indx: 1995
# Tweets to be processed: 704
# Processing tweet. ID = 1242910438636941313
#
# Current indx: 1996
# Tweets to be processed: 703
# Processing tweet. ID = 1242910966817280000
#
# Current indx: 1997
# Tweets to be processed: 702
# Processing tweet. ID = 1242911723427946497
#
# Current indx: 1998
# Tweets to be processed: 701
# Processing tweet. ID = 1242911853711446016
# Text: @myogioffice please start with this https://t.co/tIvYUMXo9b
#
# Current indx: 1999
# Tweets to be processed: 700
# Processing tweet. ID = 1242912432030285824
#
# Current indx: 2000
# Tweets to be processed: 699
# Processing tweet. ID = 1242913592329900032
#
# Current indx: 2001
# Tweets to be processed: 698
# Processing tweet. ID = 1242914495833366529
#
# Current indx: 2002
# Tweets to be processed: 697
# Processing tweet. ID = 1242916404841476096
#
# Current indx: 2003
# Tweets to be processed: 696
# Processing tweet. ID = 1242917158427881472
#
# Current indx: 2004
# Tweets to be processed: 695
# Processing tweet. ID = 1242917452087840770
#
# Current indx: 2005
# Tweets to be processed: 694
# Processing tweet. ID = 1242917482790338560
#
# Current indx: 2006
# Tweets to be processed: 693
# Processing tweet. ID = 1242918449204072451
#
# Current indx: 2007
# Tweets to be processed: 692
# Processing tweet. ID = 1242918764686929920
#
# Current indx: 2008
# Tweets to be processed: 691
# Processing tweet. ID = 1242918925580611584
#
# Current indx: 2009
# Tweets to be processed: 690
# Processing tweet. ID = 1242919064525082624
#
# Current indx: 2010
# Tweets to be processed: 689
# Processing tweet. ID = 1242919093553987586
#
# Current indx: 2011
# Tweets to be processed: 688
# Processing tweet. ID = 1242920774026932224
#
# Current indx: 2012
# Tweets to be processed: 687
# Processing tweet. ID = 1242923171663056897
#
# Current indx: 2013
# Tweets to be processed: 686
# Processing tweet. ID = 1242924386325114881
#
# Current indx: 2014
# Tweets to be processed: 685
# Processing tweet. ID = 1242924704244961280
#
# Current indx: 2015
# Tweets to be processed: 684
# Processing tweet. ID = 1242926843902275587
#
# Current indx: 2016
# Tweets to be processed: 683
# Processing tweet. ID = 1242927044628889602
#
# Current indx: 2017
# Tweets to be processed: 682
# Processing tweet. ID = 1242927574055030784
#
# Current indx: 2018
# Tweets to be processed: 681
# Processing tweet. ID = 1242927643671982080
#
# Current indx: 2019
# Tweets to be processed: 680
# Processing tweet. ID = 1242927808051064840
#
# Current indx: 2020
# Tweets to be processed: 679
# Processing tweet. ID = 1242928277699719168
#
# Current indx: 2021
# Tweets to be processed: 678
# Processing tweet. ID = 1242928389859741696
#
# Current indx: 2022
# Tweets to be processed: 677
# Processing tweet. ID = 1242928547448205314
#
# Current indx: 2023
# Tweets to be processed: 676
# Processing tweet. ID = 1242928614326317056
#
# Current indx: 2024
# Tweets to be processed: 675
# Processing tweet. ID = 1242928707737657344
#
# Current indx: 2025
# Tweets to be processed: 674
# Processing tweet. ID = 1242928888042254336
#
# Current indx: 2026
# Tweets to be processed: 673
# Processing tweet. ID = 1242928986973446144
#
# Current indx: 2027
# Tweets to be processed: 672
# Processing tweet. ID = 1242929256780480517
#
# Current indx: 2028
# Tweets to be processed: 671
# Processing tweet. ID = 1242929325894230017
#
# Current indx: 2029
# Tweets to be processed: 670
# Processing tweet. ID = 1242929696708259840
#
# Current indx: 2030
# Tweets to be processed: 669
# Processing tweet. ID = 1242929753872429056
#
# Current indx: 2031
# Tweets to be processed: 668
# Processing tweet. ID = 1242930078612258816
#
# Current indx: 2032
# Tweets to be processed: 667
# Processing tweet. ID = 1242932193745178624
#
# Current indx: 2033
# Tweets to be processed: 666
# Processing tweet. ID = 1242932261680369664
#
# Current indx: 2034
# Tweets to be processed: 665
# Processing tweet. ID = 1242933007113007104
#
# Current indx: 2035
# Tweets to be processed: 664
# Processing tweet. ID = 1242934058243330048
#
# Current indx: 2036
# Tweets to be processed: 663
# Processing tweet. ID = 1242934472556699648
#
# Current indx: 2037
# Tweets to be processed: 662
# Processing tweet. ID = 1242937003928195073
#
# Current indx: 2038
# Tweets to be processed: 661
# Processing tweet. ID = 1242937537858957312
#
# Current indx: 2039
# Tweets to be processed: 660
# Processing tweet. ID = 1242939257230163968
#
# Current indx: 2040
# Tweets to be processed: 659
# Processing tweet. ID = 1242942054705094664
#
# Current indx: 2041
# Tweets to be processed: 658
# Processing tweet. ID = 1242942647561359360
#
# Current indx: 2042
# Tweets to be processed: 657
# Processing tweet. ID = 1242942895889338369
#
# Current indx: 2043
# Tweets to be processed: 656
# Processing tweet. ID = 1242944413963190272
#
# Current indx: 2044
# Tweets to be processed: 655
# Processing tweet. ID = 1242944937139699712
#
# Current indx: 2045
# Tweets to be processed: 654
# Processing tweet. ID = 1242945191062822913
#
# Current indx: 2046
# Tweets to be processed: 653
# Processing tweet. ID = 1242946393183944705
#
# Current indx: 2047
# Tweets to be processed: 652
# Processing tweet. ID = 1242946447646941185
#
# Current indx: 2048
# Tweets to be processed: 651
# Processing tweet. ID = 1242946838488944640
#
# Current indx: 2049
# Tweets to be processed: 650
# Processing tweet. ID = 1242947266320580609
#
# Current indx: 2050
# Tweets to be processed: 649
# Processing tweet. ID = 1242947754411749376
#
# Current indx: 2051
# Tweets to be processed: 648
# Processing tweet. ID = 1242948118561165313
#
# Current indx: 2052
# Tweets to be processed: 647
# Processing tweet. ID = 1242950445292638209
#
# Current indx: 2053
# Tweets to be processed: 646
# Processing tweet. ID = 1242953296731463681
#
# Current indx: 2054
# Tweets to be processed: 645
# Processing tweet. ID = 1242953648679747584
#
# Current indx: 2055
# Tweets to be processed: 644
# Processing tweet. ID = 1242955641955680256
#
# Current indx: 2056
# Tweets to be processed: 643
# Processing tweet. ID = 1242956228898082819
#
# Current indx: 2057
# Tweets to be processed: 642
# Processing tweet. ID = 1242956680507187200
#
# Current indx: 2058
# Tweets to be processed: 641
# Processing tweet. ID = 1242961774673977345
#
# Current indx: 2059
# Tweets to be processed: 640
# Processing tweet. ID = 1242962643255582720
#
# Current indx: 2060
# Tweets to be processed: 639
# Processing tweet. ID = 1242965478546366467
#
# Current indx: 2061
# Tweets to be processed: 638
# Processing tweet. ID = 1242965843698278400
#
# Current indx: 2062
# Tweets to be processed: 637
# Processing tweet. ID = 1242967873376542720
#
# Current indx: 2063
# Tweets to be processed: 636
# Processing tweet. ID = 1242968432678588417
#
# Current indx: 2064
# Tweets to be processed: 635
# Processing tweet. ID = 1242973319000801280
#
# Current indx: 2065
# Tweets to be processed: 634
# Processing tweet. ID = 1242973859306852352
#
# Current indx: 2066
# Tweets to be processed: 633
# Processing tweet. ID = 1242974636792569856
#
# Current indx: 2067
# Tweets to be processed: 632
# Processing tweet. ID = 1242975346779029505
#
# Current indx: 2068
# Tweets to be processed: 631
# Processing tweet. ID = 1242975678162538496
#
# Current indx: 2069
# Tweets to be processed: 630
# Processing tweet. ID = 1242975841115496448
#
# Current indx: 2070
# Tweets to be processed: 629
# Processing tweet. ID = 1242975997462339584
#
# Current indx: 2071
# Tweets to be processed: 628
# Processing tweet. ID = 1242977268491677697
#
# Current indx: 2072
# Tweets to be processed: 627
# Processing tweet. ID = 1242977633534488576
#
# Current indx: 2073
# Tweets to be processed: 626
# Processing tweet. ID = 1242977967136845824
#
# Current indx: 2074
# Tweets to be processed: 625
# Processing tweet. ID = 1242979201986093056
#
# Current indx: 2075
# Tweets to be processed: 624
# Processing tweet. ID = 1242979649103089664
#
# Current indx: 2076
# Tweets to be processed: 623
# Processing tweet. ID = 1242980012069969920
#
# Current indx: 2077
# Tweets to be processed: 622
# Processing tweet. ID = 1242980205573976064
#
# Current indx: 2078
# Tweets to be processed: 621
# Processing tweet. ID = 1242980305096462337
#
# Current indx: 2079
# Tweets to be processed: 620
# Processing tweet. ID = 1242980796505493505
#
# Current indx: 2080
# Tweets to be processed: 619
# Processing tweet. ID = 1242981934117998593
#
# Current indx: 2081
# Tweets to be processed: 618
# Processing tweet. ID = 1242982021623734272
#
# Current indx: 2082
# Tweets to be processed: 617
# Processing tweet. ID = 1242982187776929793
#
# Current indx: 2083
# Tweets to be processed: 616
# Processing tweet. ID = 1242982643756486656
#
# Current indx: 2084
# Tweets to be processed: 615
# Processing tweet. ID = 1242982732197548032
#
# Current indx: 2085
# Tweets to be processed: 614
# Processing tweet. ID = 1242982966470549504
#
# Current indx: 2086
# Tweets to be processed: 613
# Processing tweet. ID = 1242983811354226688
#
# Current indx: 2087
# Tweets to be processed: 612
# Processing tweet. ID = 1242983907538034688
#
# Current indx: 2088
# Tweets to be processed: 611
# Processing tweet. ID = 1242984163042443264
#
# Current indx: 2089
# Tweets to be processed: 610
# Processing tweet. ID = 1242984230788820992
#
# Current indx: 2090
# Tweets to be processed: 609
# Processing tweet. ID = 1242984364222238725
#
# Current indx: 2091
# Tweets to be processed: 608
# Processing tweet. ID = 1242984449027067904
#
# Current indx: 2092
# Tweets to be processed: 607
# Processing tweet. ID = 1242984508124573696
#
# Current indx: 2093
# Tweets to be processed: 606
# Processing tweet. ID = 1242984515963781120
#
# Current indx: 2094
# Tweets to be processed: 605
# Processing tweet. ID = 1242984684725792770
#
# Current indx: 2095
# Tweets to be processed: 604
# Processing tweet. ID = 1242984758105128961
#
# Current indx: 2096
# Tweets to be processed: 603
# Processing tweet. ID = 1242985153212772352
#
# Current indx: 2097
# Tweets to be processed: 602
# Processing tweet. ID = 1242985397442867201
#
# Current indx: 2098
# Tweets to be processed: 601
# Processing tweet. ID = 1242985782287020032
# Text: Please suspend Mohalla clinics in the area of Corona EFFECTED areas of Delhi @ArvindKejriwal deploy staff to other places https://t.co/cWuMxmGgQz
#
# Current indx: 2099
# Tweets to be processed: 600
# Processing tweet. ID = 1242985833776308224
#
# Current indx: 2100
# Tweets to be processed: 599
# Processing tweet. ID = 1242986153248272392
#
# Current indx: 2101
# Tweets to be processed: 598
# Processing tweet. ID = 1242986503745048577
#
# Current indx: 2102
# Tweets to be processed: 597
# Processing tweet. ID = 1242986981023338497
# Error while accessing tweet. ID: 1242986981023338497
#
# Current indx: 2103
# Tweets to be processed: 596
# Processing tweet. ID = 1242986990905090049
#
# Current indx: 2104
# Tweets to be processed: 595
# Processing tweet. ID = 1242987193611587584
#
# Current indx: 2105
# Tweets to be processed: 594
# Processing tweet. ID = 1242987221830926337
#
# Current indx: 2106
# Tweets to be processed: 593
# Processing tweet. ID = 1242987352437469184
#
# Current indx: 2107
# Tweets to be processed: 592
# Processing tweet. ID = 1242988843009261569
#
# Current indx: 2108
# Tweets to be processed: 591
# Processing tweet. ID = 1242989267531399168
#
# Current indx: 2109
# Tweets to be processed: 590
# Processing tweet. ID = 1242989346719821824
#
# Current indx: 2110
# Tweets to be processed: 589
# Processing tweet. ID = 1242989561216548867
#
# Current indx: 2111
# Tweets to be processed: 588
# Processing tweet. ID = 1242989735787679744
#
# Current indx: 2112
# Tweets to be processed: 587
# Processing tweet. ID = 1242989890708459520
#
# Current indx: 2113
# Tweets to be processed: 586
# Processing tweet. ID = 1242989908534259713
#
# Current indx: 2114
# Tweets to be processed: 585
# Processing tweet. ID = 1242990359568773120
#
# Current indx: 2115
# Tweets to be processed: 584
# Processing tweet. ID = 1242990457120010242
#
# Current indx: 2116
# Tweets to be processed: 583
# Processing tweet. ID = 1242990809256869888
#
# Current indx: 2117
# Tweets to be processed: 582
# Processing tweet. ID = 1242990824452849665
#
# Current indx: 2118
# Tweets to be processed: 581
# Processing tweet. ID = 1242990833558679552
#
# Current indx: 2119
# Tweets to be processed: 580
# Processing tweet. ID = 1242990871307378694
#
# Current indx: 2120
# Tweets to be processed: 579
# Processing tweet. ID = 1242991135863140352
#
# Current indx: 2121
# Tweets to be processed: 578
# Processing tweet. ID = 1242991147384999937
#
# Current indx: 2122
# Tweets to be processed: 577
# Processing tweet. ID = 1242991170621296641
#
# Current indx: 2123
# Tweets to be processed: 576
# Processing tweet. ID = 1242991208252600323
#
# Current indx: 2124
# Tweets to be processed: 575
# Processing tweet. ID = 1242991471352930305
#
# Current indx: 2125
# Tweets to be processed: 574
# Processing tweet. ID = 1242991607277740032
#
# Current indx: 2126
# Tweets to be processed: 573
# Processing tweet. ID = 1242991639460827137
#
# Current indx: 2127
# Tweets to be processed: 572
# Processing tweet. ID = 1242992152331739136
#
# Current indx: 2128
# Tweets to be processed: 571
# Processing tweet. ID = 1242992450370596864
#
# Current indx: 2129
# Tweets to be processed: 570
# Processing tweet. ID = 1242992474001256448
#
# Current indx: 2130
# Tweets to be processed: 569
# Processing tweet. ID = 1242993912559489024
#
# Current indx: 2131
# Tweets to be processed: 568
# Processing tweet. ID = 1242994149910966272
#
# Current indx: 2132
# Tweets to be processed: 567
# Processing tweet. ID = 1242994213458870272
#
# Current indx: 2133
# Tweets to be processed: 566
# Processing tweet. ID = 1242994578463965186
#
# Current indx: 2134
# Tweets to be processed: 565
# Processing tweet. ID = 1242994631408680960
#
# Current indx: 2135
# Tweets to be processed: 564
# Processing tweet. ID = 1242994745493917704
#
# Current indx: 2136
# Tweets to be processed: 563
# Processing tweet. ID = 1242995517656682497
#
# Current indx: 2137
# Tweets to be processed: 562
# Processing tweet. ID = 1242995562883891201
#
# Current indx: 2138
# Tweets to be processed: 561
# Processing tweet. ID = 1242995642449809408
#
# Current indx: 2139
# Tweets to be processed: 560
# Processing tweet. ID = 1242995688998187008
#
# Current indx: 2140
# Tweets to be processed: 559
# Processing tweet. ID = 1242995727292194817
#
# Current indx: 2141
# Tweets to be processed: 558
# Processing tweet. ID = 1242996361496166400
#
# Current indx: 2142
# Tweets to be processed: 557
# Processing tweet. ID = 1242996650609528832
#
# Current indx: 2143
# Tweets to be processed: 556
# Processing tweet. ID = 1242996657291051008
#
# Current indx: 2144
# Tweets to be processed: 555
# Processing tweet. ID = 1242996830587125762
#
# Current indx: 2145
# Tweets to be processed: 554
# Processing tweet. ID = 1242996866473549825
#
# Current indx: 2146
# Tweets to be processed: 553
# Processing tweet. ID = 1242997178995363840
#
# Current indx: 2147
# Tweets to be processed: 552
# Processing tweet. ID = 1242997189439348736
#
# Current indx: 2148
# Tweets to be processed: 551
# Processing tweet. ID = 1242997271823712256
#
# Current indx: 2149
# Tweets to be processed: 550
# Processing tweet. ID = 1242997564275748864
#
# Current indx: 2150
# Tweets to be processed: 549
# Processing tweet. ID = 1242997909550796800
#
# Current indx: 2151
# Tweets to be processed: 548
# Processing tweet. ID = 1242998215781175296
#
# Current indx: 2152
# Tweets to be processed: 547
# Processing tweet. ID = 1242998230490570752
#
# Current indx: 2153
# Tweets to be processed: 546
# Processing tweet. ID = 1242998376498475009
#
# Current indx: 2154
# Tweets to be processed: 545
# Processing tweet. ID = 1242998582401089537
#
# Current indx: 2155
# Tweets to be processed: 544
# Processing tweet. ID = 1242999137664217088
#
# Current indx: 2156
# Tweets to be processed: 543
# Processing tweet. ID = 1242999582428221440
#
# Current indx: 2157
# Tweets to be processed: 542
# Processing tweet. ID = 1242999603076780032
#
# Current indx: 2158
# Tweets to be processed: 541
# Processing tweet. ID = 1242999997169164288
#
# Current indx: 2159
# Tweets to be processed: 540
# Processing tweet. ID = 1243000073983684610
#
# Current indx: 2160
# Tweets to be processed: 539
# Processing tweet. ID = 1243000183585042432
#
# Current indx: 2161
# Tweets to be processed: 538
# Processing tweet. ID = 1243000384924176385
#
# Current indx: 2162
# Tweets to be processed: 537
# Processing tweet. ID = 1243000473533026304
#
# Current indx: 2163
# Tweets to be processed: 536
# Processing tweet. ID = 1243000547013095427
#
# Current indx: 2164
# Tweets to be processed: 535
# Processing tweet. ID = 1243000582786482177
#
# Current indx: 2165
# Tweets to be processed: 534
# Processing tweet. ID = 1243001014979981319
#
# Current indx: 2166
# Tweets to be processed: 533
# Processing tweet. ID = 1243001169774968832
#
# Current indx: 2167
# Tweets to be processed: 532
# Processing tweet. ID = 1243001362884882432
#
# Current indx: 2168
# Tweets to be processed: 531
# Processing tweet. ID = 1243001505361223682
#
# Current indx: 2169
# Tweets to be processed: 530
# Processing tweet. ID = 1243001955347136513
#
# Current indx: 2170
# Tweets to be processed: 529
# Processing tweet. ID = 1243002094543671303
#
# Current indx: 2171
# Tweets to be processed: 528
# Processing tweet. ID = 1243002119138840576
#
# Current indx: 2172
# Tweets to be processed: 527
# Processing tweet. ID = 1243002512086614018
#
# Current indx: 2173
# Tweets to be processed: 526
# Processing tweet. ID = 1243002542327398400
#
# Current indx: 2174
# Tweets to be processed: 525
# Processing tweet. ID = 1243002606118526976
#
# Current indx: 2175
# Tweets to be processed: 524
# Processing tweet. ID = 1243002656680902656
#
# Current indx: 2176
# Tweets to be processed: 523
# Processing tweet. ID = 1243002687429328896
#
# Current indx: 2177
# Tweets to be processed: 522
# Processing tweet. ID = 1243002694098235393
#
# Current indx: 2178
# Tweets to be processed: 521
# Processing tweet. ID = 1243002810620211200
#
# Current indx: 2179
# Tweets to be processed: 520
# Processing tweet. ID = 1243002963624218625
#
# Current indx: 2180
# Tweets to be processed: 519
# Processing tweet. ID = 1243002971098505218
#
# Current indx: 2181
# Tweets to be processed: 518
# Processing tweet. ID = 1243003312749723648
#
# Current indx: 2182
# Tweets to be processed: 517
# Processing tweet. ID = 1243003339140485120
#
# Current indx: 2183
# Tweets to be processed: 516
# Processing tweet. ID = 1243003500575035392
#
# Current indx: 2184
# Tweets to be processed: 515
# Processing tweet. ID = 1243003614508896256
#
# Current indx: 2185
# Tweets to be processed: 514
# Processing tweet. ID = 1243003840141512704
#
# Current indx: 2186
# Tweets to be processed: 513
# Processing tweet. ID = 1243004035306676224
#
# Current indx: 2187
# Tweets to be processed: 512
# Processing tweet. ID = 1243004412852871173
#
# Current indx: 2188
# Tweets to be processed: 511
# Processing tweet. ID = 1243004515651145729
#
# Current indx: 2189
# Tweets to be processed: 510
# Processing tweet. ID = 1243004698572931073
#
# Current indx: 2190
# Tweets to be processed: 509
# Processing tweet. ID = 1243005052177924096
#
# Current indx: 2191
# Tweets to be processed: 508
# Processing tweet. ID = 1243005148021977089
#
# Current indx: 2192
# Tweets to be processed: 507
# Processing tweet. ID = 1243005216183726080
#
# Current indx: 2193
# Tweets to be processed: 506
# Processing tweet. ID = 1243005338883780608
#
# Current indx: 2194
# Tweets to be processed: 505
# Processing tweet. ID = 1243005408165236737
#
# Current indx: 2195
# Tweets to be processed: 504
# Processing tweet. ID = 1243005601636069378
#
# Current indx: 2196
# Tweets to be processed: 503
# Processing tweet. ID = 1243005605012328448
#
# Current indx: 2197
# Tweets to be processed: 502
# Processing tweet. ID = 1243005620158001152
#
# Current indx: 2198
# Tweets to be processed: 501
# Processing tweet. ID = 1243006317326774272
# Text: Time to Return to #OurGloriousSanatanSanskriti roots, Culture, Traditions &amp; Lifestyle! Wash hands regularly, adopt Namaste, Pranayama, early Rising, Oil Bath, use Copper Vessels, Turmeric/Ginger, adopt Vegetarianism, &amp; win this war against Corona.
#
# Current indx: 2199
# Tweets to be processed: 500
# Processing tweet. ID = 1243006473266802689
#
# Current indx: 2200
# Tweets to be processed: 499
# Processing tweet. ID = 1243006508331237376
#
# Current indx: 2201
# Tweets to be processed: 498
# Processing tweet. ID = 1243006599997698049
#
# Current indx: 2202
# Tweets to be processed: 497
# Processing tweet. ID = 1243006696890359810
#
# Current indx: 2203
# Tweets to be processed: 496
# Processing tweet. ID = 1243006979133472768
#
# Current indx: 2204
# Tweets to be processed: 495
# Processing tweet. ID = 1243007137095151617
#
# Current indx: 2205
# Tweets to be processed: 494
# Processing tweet. ID = 1243007239587164162
#
# Current indx: 2206
# Tweets to be processed: 493
# Processing tweet. ID = 1243007272520839169
#
# Current indx: 2207
# Tweets to be processed: 492
# Processing tweet. ID = 1243007448375595009
#
# Current indx: 2208
# Tweets to be processed: 491
# Processing tweet. ID = 1243007555070124032
#
# Current indx: 2209
# Tweets to be processed: 490
# Processing tweet. ID = 1243007719025438720
#
# Current indx: 2210
# Tweets to be processed: 489
# Processing tweet. ID = 1243007863833976833
#
# Current indx: 2211
# Tweets to be processed: 488
# Processing tweet. ID = 1243007898692677632
#
# Current indx: 2212
# Tweets to be processed: 487
# Processing tweet. ID = 1243007984612962305
#
# Current indx: 2213
# Tweets to be processed: 486
# Processing tweet. ID = 1243007986903027714
#
# Current indx: 2214
# Tweets to be processed: 485
# Processing tweet. ID = 1243008114393145344
#
# Current indx: 2215
# Tweets to be processed: 484
# Processing tweet. ID = 1243008146819301382
#
# Current indx: 2216
# Tweets to be processed: 483
# Processing tweet. ID = 1243008376960733185
#
# Current indx: 2217
# Tweets to be processed: 482
# Processing tweet. ID = 1243008414344568833
#
# Current indx: 2218
# Tweets to be processed: 481
# Processing tweet. ID = 1243008538911236097
#
# Current indx: 2219
# Tweets to be processed: 480
# Processing tweet. ID = 1243008540932837376
#
# Current indx: 2220
# Tweets to be processed: 479
# Processing tweet. ID = 1243008553318662145
#
# Current indx: 2221
# Tweets to be processed: 478
# Processing tweet. ID = 1243008557584273409
#
# Current indx: 2222
# Tweets to be processed: 477
# Processing tweet. ID = 1243008849583448064
#
# Current indx: 2223
# Tweets to be processed: 476
# Processing tweet. ID = 1243008869543981056
#
# Current indx: 2224
# Tweets to be processed: 475
# Processing tweet. ID = 1243008874233266179
#
# Current indx: 2225
# Tweets to be processed: 474
# Processing tweet. ID = 1243009031439933440
#
# Current indx: 2226
# Tweets to be processed: 473
# Processing tweet. ID = 1243009237619335168
#
# Current indx: 2227
# Tweets to be processed: 472
# Processing tweet. ID = 1243009266912395264
#
# Current indx: 2228
# Tweets to be processed: 471
# Processing tweet. ID = 1243009511306039296
#
# Current indx: 2229
# Tweets to be processed: 470
# Processing tweet. ID = 1243009759009067008
#
# Current indx: 2230
# Tweets to be processed: 469
# Processing tweet. ID = 1243009969114337280
#
# Current indx: 2231
# Tweets to be processed: 468
# Processing tweet. ID = 1243010170055086080
#
# Current indx: 2232
# Tweets to be processed: 467
# Processing tweet. ID = 1243010202179260416
#
# Current indx: 2233
# Tweets to be processed: 466
# Processing tweet. ID = 1243010720716828673
#
# Current indx: 2234
# Tweets to be processed: 465
# Processing tweet. ID = 1243010981099237376
#
# Current indx: 2235
# Tweets to be processed: 464
# Processing tweet. ID = 1243011034161369088
#
# Current indx: 2236
# Tweets to be processed: 463
# Processing tweet. ID = 1243011060032065536
#
# Current indx: 2237
# Tweets to be processed: 462
# Processing tweet. ID = 1243011106391461889
#
# Current indx: 2238
# Tweets to be processed: 461
# Processing tweet. ID = 1243011185114415104
#
# Current indx: 2239
# Tweets to be processed: 460
# Processing tweet. ID = 1243011276474732544
#
# Current indx: 2240
# Tweets to be processed: 459
# Processing tweet. ID = 1243011469047771136
#
# Current indx: 2241
# Tweets to be processed: 458
# Processing tweet. ID = 1243011486433206272
#
# Current indx: 2242
# Tweets to be processed: 457
# Processing tweet. ID = 1243011488245100545
#
# Current indx: 2243
# Tweets to be processed: 456
# Processing tweet. ID = 1243011753870389248
#
# Current indx: 2244
# Tweets to be processed: 455
# Processing tweet. ID = 1243011800846585857
#
# Current indx: 2245
# Tweets to be processed: 454
# Processing tweet. ID = 1243011819993575424
#
# Current indx: 2246
# Tweets to be processed: 453
# Processing tweet. ID = 1243012072033550337
#
# Current indx: 2247
# Tweets to be processed: 452
# Processing tweet. ID = 1243012092220694535
#
# Current indx: 2248
# Tweets to be processed: 451
# Processing tweet. ID = 1243012229454159872
#
# Current indx: 2249
# Tweets to be processed: 450
# Processing tweet. ID = 1243012381141135360
#
# Current indx: 2250
# Tweets to be processed: 449
# Processing tweet. ID = 1243012586653634562
#
# Current indx: 2251
# Tweets to be processed: 448
# Processing tweet. ID = 1243012706044534791
#
# Current indx: 2252
# Tweets to be processed: 447
# Processing tweet. ID = 1243012857987354624
#
# Current indx: 2253
# Tweets to be processed: 446
# Processing tweet. ID = 1243012936836120576
#
# Current indx: 2254
# Tweets to be processed: 445
# Processing tweet. ID = 1243012957828767756
#
# Current indx: 2255
# Tweets to be processed: 444
# Processing tweet. ID = 1243013026158014467
#
# Current indx: 2256
# Tweets to be processed: 443
# Processing tweet. ID = 1243013056692547584
#
# Current indx: 2257
# Tweets to be processed: 442
# Processing tweet. ID = 1243013129967034369
#
# Current indx: 2258
# Tweets to be processed: 441
# Processing tweet. ID = 1243013163685216256
#
# Current indx: 2259
# Tweets to be processed: 440
# Processing tweet. ID = 1243013341691310084
#
# Current indx: 2260
# Tweets to be processed: 439
# Processing tweet. ID = 1243013368644067328
#
# Current indx: 2261
# Tweets to be processed: 438
# Processing tweet. ID = 1243013484863844355
#
# Current indx: 2262
# Tweets to be processed: 437
# Processing tweet. ID = 1243013594033217536
#
# Current indx: 2263
# Tweets to be processed: 436
# Processing tweet. ID = 1243013639482687488
#
# Current indx: 2264
# Tweets to be processed: 435
# Processing tweet. ID = 1243013646319357953
#
# Current indx: 2265
# Tweets to be processed: 434
# Processing tweet. ID = 1243013802356064256
#
# Current indx: 2266
# Tweets to be processed: 433
# Processing tweet. ID = 1243014246738178049
#
# Current indx: 2267
# Tweets to be processed: 432
# Processing tweet. ID = 1243014400774041600
#
# Current indx: 2268
# Tweets to be processed: 431
# Processing tweet. ID = 1243014578880954368
#
# Current indx: 2269
# Tweets to be processed: 430
# Processing tweet. ID = 1243014771223351296
#
# Current indx: 2270
# Tweets to be processed: 429
# Processing tweet. ID = 1243014848755027969
#
# Current indx: 2271
# Tweets to be processed: 428
# Processing tweet. ID = 1243014994754539520
#
# Current indx: 2272
# Tweets to be processed: 427
# Processing tweet. ID = 1243015268231565313
#
# Current indx: 2273
# Tweets to be processed: 426
# Processing tweet. ID = 1243015332664508416
#
# Current indx: 2274
# Tweets to be processed: 425
# Processing tweet. ID = 1243015591511740417
#
# Current indx: 2275
# Tweets to be processed: 424
# Processing tweet. ID = 1243015691982106624
#
# Current indx: 2276
# Tweets to be processed: 423
# Processing tweet. ID = 1243015704690847744
#
# Current indx: 2277
# Tweets to be processed: 422
# Processing tweet. ID = 1243015762475974657
#
# Current indx: 2278
# Tweets to be processed: 421
# Processing tweet. ID = 1243015782767808512
#
# Current indx: 2279
# Tweets to be processed: 420
# Processing tweet. ID = 1243015824236933120
#
# Current indx: 2280
# Tweets to be processed: 419
# Processing tweet. ID = 1243016037022535680
#
# Current indx: 2281
# Tweets to be processed: 418
# Processing tweet. ID = 1243016054130917377
#
# Current indx: 2282
# Tweets to be processed: 417
# Processing tweet. ID = 1243016121696923649
#
# Current indx: 2283
# Tweets to be processed: 416
# Processing tweet. ID = 1243016919575408643
#
# Current indx: 2284
# Tweets to be processed: 415
# Processing tweet. ID = 1243017149574078467
#
# Current indx: 2285
# Tweets to be processed: 414
# Processing tweet. ID = 1243017302431485953
#
# Current indx: 2286
# Tweets to be processed: 413
# Processing tweet. ID = 1243017390343901187
#
# Current indx: 2287
# Tweets to be processed: 412
# Processing tweet. ID = 1243017604148547584
#
# Current indx: 2288
# Tweets to be processed: 411
# Processing tweet. ID = 1243017696469495813
#
# Current indx: 2289
# Tweets to be processed: 410
# Processing tweet. ID = 1243017727704305664
#
# Current indx: 2290
# Tweets to be processed: 409
# Processing tweet. ID = 1243017774424719360
#
# Current indx: 2291
# Tweets to be processed: 408
# Processing tweet. ID = 1243017849611759618
#
# Current indx: 2292
# Tweets to be processed: 407
# Processing tweet. ID = 1243017928808599552
#
# Current indx: 2293
# Tweets to be processed: 406
# Processing tweet. ID = 1243018000426389504
#
# Current indx: 2294
# Tweets to be processed: 405
# Processing tweet. ID = 1243018247215046656
#
# Current indx: 2295
# Tweets to be processed: 404
# Processing tweet. ID = 1243018327296839680
#
# Current indx: 2296
# Tweets to be processed: 403
# Processing tweet. ID = 1243018608659189760
#
# Current indx: 2297
# Tweets to be processed: 402
# Processing tweet. ID = 1243018659368337410
#
# Current indx: 2298
# Tweets to be processed: 401
# Processing tweet. ID = 1243018706717790208
# Text: Demi god🙏🙏🙏 https://t.co/pTnBZZt29W
#
# Current indx: 2299
# Tweets to be processed: 400
# Processing tweet. ID = 1243018909030072320
#
# Current indx: 2300
# Tweets to be processed: 399
# Processing tweet. ID = 1243018933789028352
#
# Current indx: 2301
# Tweets to be processed: 398
# Processing tweet. ID = 1243019006237425670
#
# Current indx: 2302
# Tweets to be processed: 397
# Processing tweet. ID = 1243019104203628546
#
# Current indx: 2303
# Tweets to be processed: 396
# Processing tweet. ID = 1243019117327577088
#
# Current indx: 2304
# Tweets to be processed: 395
# Processing tweet. ID = 1243019135551852544
#
# Current indx: 2305
# Tweets to be processed: 394
# Processing tweet. ID = 1243019178014961665
#
# Current indx: 2306
# Tweets to be processed: 393
# Processing tweet. ID = 1243019202027544576
#
# Current indx: 2307
# Tweets to be processed: 392
# Processing tweet. ID = 1243019345459941377
#
# Current indx: 2308
# Tweets to be processed: 391
# Processing tweet. ID = 1243019433423110147
#
# Current indx: 2309
# Tweets to be processed: 390
# Processing tweet. ID = 1243019494131458049
#
# Current indx: 2310
# Tweets to be processed: 389
# Processing tweet. ID = 1243019643029041152
#
# Current indx: 2311
# Tweets to be processed: 388
# Processing tweet. ID = 1243019741934964736
#
# Current indx: 2312
# Tweets to be processed: 387
# Processing tweet. ID = 1243019756556312576
#
# Current indx: 2313
# Tweets to be processed: 386
# Processing tweet. ID = 1243019941189537792
#
# Current indx: 2314
# Tweets to be processed: 385
# Processing tweet. ID = 1243019998995582981
#
# Current indx: 2315
# Tweets to be processed: 384
# Processing tweet. ID = 1243020107309133825
#
# Current indx: 2316
# Tweets to be processed: 383
# Processing tweet. ID = 1243020401271132160
#
# Current indx: 2317
# ...
# Processing tweet. ID = 1243040544445452288
#
# Current indx: 2523
# Tweets to be processed: 176
# Processing tweet. ID = 1243040877838127104
#
# Current indx: 2524
# Tweets to be processed: 175
# Processing tweet. ID = 1243040930187235329
#
# Current indx: 2525
# Tweets to be processed: 174
# Processing tweet. ID = 1243040981127069700
#
# Current indx: 2526
# Tweets to be processed: 173
# Processing tweet. ID = 1243041059262697473
#
# Current indx: 2527
# Tweets to be processed: 172
# Processing tweet. ID = 1243041061318115328
#
# Current indx: 2528
# Tweets to be processed: 171
# Processing tweet. ID = 1243041238527295488
#
# Current indx: 2529
# Tweets to be processed: 170
# Processing tweet. ID = 1243041394463084544
#
# Current indx: 2530
# Tweets to be processed: 169
# Processing tweet. ID = 1243041397646807041
#
# Current indx: 2531
# Tweets to be processed: 168
# Processing tweet. ID = 1243041518996209664
#
# Current indx: 2532
# Tweets to be processed: 167
# Processing tweet. ID = 1243041880994009088
#
# Current indx: 2533
# Tweets to be processed: 166
# Processing tweet. ID = 1243041984022900738
#
# Current indx: 2534
# Tweets to be processed: 165
# Processing tweet. ID = 1243042089337679872
#
# Current indx: 2535
# Tweets to be processed: 164
# Processing tweet. ID = 1243042255989956608
#
# Current indx: 2536
# Tweets to be processed: 163
# Processing tweet. ID = 1243042867590750209
#
# Current indx: 2537
# Tweets to be processed: 162
# Processing tweet. ID = 1243042879330603008
#
# Current indx: 2538
# Tweets to be processed: 161
# Processing tweet. ID = 1243042931038134273
#
# Current indx: 2539
# Tweets to be processed: 160
# Processing tweet. ID = 1243043074600775680
#
# Current indx: 2540
# Tweets to be processed: 159
# Processing tweet. ID = 1243043372371247105
#
# Current indx: 2541
# Tweets to be processed: 158
# Processing tweet. ID = 1243043556337614848
#
# Current indx: 2542
# Tweets to be processed: 157
# Processing tweet. ID = 1243043717352546305
#
# Current indx: 2543
# Tweets to be processed: 156
# Processing tweet. ID = 1243043770444025856
#
# Current indx: 2544
# Tweets to be processed: 155
# Processing tweet. ID = 1243043822319202304
#
# Current indx: 2545
# Tweets to be processed: 154
# Processing tweet. ID = 1243043876618682368
#
# Current indx: 2546
# Tweets to be processed: 153
# Processing tweet. ID = 1243043943417184256
#
# Current indx: 2547
# Tweets to be processed: 152
# Processing tweet. ID = 1243044041618423808
#
# Current indx: 2548
# Tweets to be processed: 151
# Processing tweet. ID = 1243044046601211906
#
# Current indx: 2549
# Tweets to be processed: 150
# Processing tweet. ID = 1243044162728898565
#
# Current indx: 2550
# Tweets to be processed: 149
# Processing tweet. ID = 1243044347349798913
#
# Current indx: 2551
# Tweets to be processed: 148
# Processing tweet. ID = 1243044443235561472
#
# Current indx: 2552
# Tweets to be processed: 147
# Processing tweet. ID = 1243044488345341952
#
# Current indx: 2553
# Tweets to be processed: 146
# Processing tweet. ID = 1243044515486691328
#
# Current indx: 2554
# Tweets to be processed: 145
# Processing tweet. ID = 1243044598898810880
#
# Current indx: 2555
# Tweets to be processed: 144
# Processing tweet. ID = 1243044686085775367
#
# Current indx: 2556
# Tweets to be processed: 143
# Processing tweet. ID = 1243044743275307014
#
# Current indx: 2557
# Tweets to be processed: 142
# Processing tweet. ID = 1243044798711259141
#
# Current indx: 2558
# Tweets to be processed: 141
# Processing tweet. ID = 1243044836522856448
#
# Current indx: 2559
# Tweets to be processed: 140
# Processing tweet. ID = 1243044860350742530
#
# Current indx: 2560
# Tweets to be processed: 139
# Processing tweet. ID = 1243044878767894529
#
# Current indx: 2561
# Tweets to be processed: 138
# Processing tweet. ID = 1243044890994302976
#
# Current indx: 2562
# Tweets to be processed: 137
# Processing tweet. ID = 1243045495393513472
#
# Current indx: 2563
# Tweets to be processed: 136
# Processing tweet. ID = 1243045537147834369
#
# Current indx: 2564
# Tweets to be processed: 135
# Processing tweet. ID = 1243045572895846400
#
# Current indx: 2565
# Tweets to be processed: 134
# Processing tweet. ID = 1243045767419326465
#
# Current indx: 2566
# Tweets to be processed: 133
# Processing tweet. ID = 1243045819009224705
#
# Current indx: 2567
# Tweets to be processed: 132
# Processing tweet. ID = 1243045900286480389
#
# Current indx: 2568
# Tweets to be processed: 131
# Processing tweet. ID = 1243045987171438593
#
# Current indx: 2569
# Tweets to be processed: 130
# Processing tweet. ID = 1243046128448204801
#
# Current indx: 2570
# Tweets to be processed: 129
# Processing tweet. ID = 1243046157607030785
#
# Current indx: 2571
# Tweets to be processed: 128
# Processing tweet. ID = 1243046203417186304
#
# Current indx: 2572
# Tweets to be processed: 127
# Processing tweet. ID = 1243046397395361792
#
# Current indx: 2573
# Tweets to be processed: 126
# Processing tweet. ID = 1243046651054284806
#
# Current indx: 2574
# Tweets to be processed: 125
# Processing tweet. ID = 1243046904931299330
#
# Current indx: 2575
# Tweets to be processed: 124
# Processing tweet. ID = 1243046932991242240
#
# Current indx: 2576
# Tweets to be processed: 123
# Processing tweet. ID = 1243047016847966208
#
# Current indx: 2577
# Tweets to be processed: 122
# Processing tweet. ID = 1243047269928038401
#
# Current indx: 2578
# Tweets to be processed: 121
# Processing tweet. ID = 1243047454259339265
#
# Current indx: 2579
# Tweets to be processed: 120
# Processing tweet. ID = 1243047805175939074
#
# Current indx: 2580
# Tweets to be processed: 119
# Processing tweet. ID = 1243047822045388800
#
# Current indx: 2581
# Tweets to be processed: 118
# Processing tweet. ID = 1243047858174963713
#
# Current indx: 2582
# Tweets to be processed: 117
# Processing tweet. ID = 1243047906485002245
#
# Current indx: 2583
# Tweets to be processed: 116
# Processing tweet. ID = 1243048169614778376
#
# Current indx: 2584
# Tweets to be processed: 115
# Processing tweet. ID = 1243048185825611776
#
# Current indx: 2585
# Tweets to be processed: 114
# Processing tweet. ID = 1243048190791700481
#
# Current indx: 2586
# Tweets to be processed: 113
# Processing tweet. ID = 1243048239168811008
#
# Current indx: 2587
# Tweets to be processed: 112
# Processing tweet. ID = 1243048366767886336
#
# Current indx: 2588
# Tweets to be processed: 111
# Processing tweet. ID = 1243048466647048192
#
# Current indx: 2589
# Tweets to be processed: 110
# Processing tweet. ID = 1243048510896746497
#
# Current indx: 2590
# Tweets to be processed: 109
# Processing tweet. ID = 1243048530039595010
#
# Current indx: 2591
# Tweets to be processed: 108
# Processing tweet. ID = 1243048902690922497
#
# Current indx: 2592
# Tweets to be processed: 107
# Processing tweet. ID = 1243048907757649920
#
# Current indx: 2593
# Tweets to be processed: 106
# Processing tweet. ID = 1243049010362896385
#
# Current indx: 2594
# Tweets to be processed: 105
# Processing tweet. ID = 1243049044315762688
#
# Current indx: 2595
# Tweets to be processed: 104
# Processing tweet. ID = 1243049190847967232
#
# Current indx: 2596
# Tweets to be processed: 103
# Processing tweet. ID = 1243049251162058752
#
# Current indx: 2597
# Tweets to be processed: 102
# Processing tweet. ID = 1243049271110168576
#
# Current indx: 2598
# Tweets to be processed: 101
# Processing tweet. ID = 1243049304316448768
# Text: Can Elite Journos contribute something???? https://t.co/ygDLqIERgU
#
# Current indx: 2599
# Tweets to be processed: 100
# Processing tweet. ID = 1243049347308064769
#
# Current indx: 2600
# Tweets to be processed: 99
# Processing tweet. ID = 1243049464396419077
#
# Current indx: 2601
# Tweets to be processed: 98
# Processing tweet. ID = 1243049539998629893
#
# Current indx: 2602
# Tweets to be processed: 97
# Processing tweet. ID = 1243049695200464898
#
# Current indx: 2603
# Tweets to be processed: 96
# Processing tweet. ID = 1243049703224168448
#
# Current indx: 2604
# Tweets to be processed: 95
# Processing tweet. ID = 1243049711759581184
#
# Current indx: 2605
# Tweets to be processed: 94
# Processing tweet. ID = 1243049772757352448
#
# Current indx: 2606
# Tweets to be processed: 93
# Processing tweet. ID = 1243049827056758784
#
# Current indx: 2607
# Tweets to be processed: 92
# Processing tweet. ID = 1243049879988875266
#
# Current indx: 2608
# Tweets to be processed: 91
# Processing tweet. ID = 1243050085308493830
#
# Current indx: 2609
# Tweets to be processed: 90
# Processing tweet. ID = 1243050188282839041
#
# Current indx: 2610
# Tweets to be processed: 89
# Processing tweet. ID = 1243050205320294400
#
# Current indx: 2611
# Tweets to be processed: 88
# Processing tweet. ID = 1243050269081923587
#
# Current indx: 2612
# Tweets to be processed: 87
# Processing tweet. ID = 1243050301424160768
#
# Current indx: 2613
# Tweets to be processed: 86
# Processing tweet. ID = 1243050322831929344
#
# Current indx: 2614
# Tweets to be processed: 85
# Processing tweet. ID = 1243050329152741378
#
# Current indx: 2615
# Tweets to be processed: 84
# Processing tweet. ID = 1243050412850049025
#
# Current indx: 2616
# Tweets to be processed: 83
# Processing tweet. ID = 1243050484425883648
#
# Current indx: 2617
# Tweets to be processed: 82
# Processing tweet. ID = 1243050588981452800
#
# Current indx: 2618
# Tweets to be processed: 81
# Processing tweet. ID = 1243050695030263808
#
# Current indx: 2619
# Tweets to be processed: 80
# Processing tweet. ID = 1243050832477802502
#
# Current indx: 2620
# Tweets to be processed: 79
# Processing tweet. ID = 1243050880565260288
#
# Current indx: 2621
# Tweets to be processed: 78
# Processing tweet. ID = 1243050918385291266
#
# Current indx: 2622
# Tweets to be processed: 77
# Processing tweet. ID = 1243051120424931328
#
# Current indx: 2623
# Tweets to be processed: 76
# Processing tweet. ID = 1243051122996031490
#
# Current indx: 2624
# Tweets to be processed: 75
# Processing tweet. ID = 1243051450353106944
#
# Current indx: 2625
# Tweets to be processed: 74
# Processing tweet. ID = 1243051464680857600
#
# Current indx: 2626
# Tweets to be processed: 73
# Processing tweet. ID = 1243051482657611777
#
# Current indx: 2627
# Tweets to be processed: 72
# Processing tweet. ID = 1243051504971296768
#
# Current indx: 2628
# Tweets to be processed: 71
# Processing tweet. ID = 1243051558972968960
#
# Current indx: 2629
# Tweets to be processed: 70
# Processing tweet. ID = 1243051626438377472
#
# Current indx: 2630
# Tweets to be processed: 69
# Processing tweet. ID = 1243051632805335040
#
# Current indx: 2631
# Tweets to be processed: 68
# Processing tweet. ID = 1243051655689457665
#
# Current indx: 2632
# Tweets to be processed: 67
# Processing tweet. ID = 1243051813101654016
#
# Current indx: 2633
# Tweets to be processed: 66
# Processing tweet. ID = 1243051823881216001
#
# Current indx: 2634
# Tweets to be processed: 65
# Processing tweet. ID = 1243052106128351232
#
# Current indx: 2635
# Tweets to be processed: 64
# Processing tweet. ID = 1243052308650512386
#
# Current indx: 2636
# Tweets to be processed: 63
# Processing tweet. ID = 1243052449524416513
#
# Current indx: 2637
# Tweets to be processed: 62
# Processing tweet. ID = 1243052739396960259
#
# Current indx: 2638
# Tweets to be processed: 61
# Processing tweet. ID = 1243052811752857607
#
# Current indx: 2639
# Tweets to be processed: 60
# Processing tweet. ID = 1243052817591472128
#
# Current indx: 2640
# Tweets to be processed: 59
# Processing tweet. ID = 1243052910482731008
#
# Current indx: 2641
# Tweets to be processed: 58
# Processing tweet. ID = 1243052910558076928
#
# Current indx: 2642
# Tweets to be processed: 57
# Processing tweet. ID = 1243052939356155905
#
# Current indx: 2643
# Tweets to be processed: 56
# Processing tweet. ID = 1243053086832095232
#
# Current indx: 2644
# Tweets to be processed: 55
# Processing tweet. ID = 1243053152896561153
#
# Current indx: 2645
# Tweets to be processed: 54
# Processing tweet. ID = 1243053170256797696
#
# Current indx: 2646
# Tweets to be processed: 53
# Processing tweet. ID = 1243053617365397504
#
# Current indx: 2647
# Tweets to be processed: 52
# Processing tweet. ID = 1243053800681857024
#
# Current indx: 2648
# Tweets to be processed: 51
# Processing tweet. ID = 1243053854184226818
#
# Current indx: 2649
# Tweets to be processed: 50
# Processing tweet. ID = 1243053889793843200
#
# Current indx: 2650
# Tweets to be processed: 49
# Processing tweet. ID = 1243054341637828608
#
# Current indx: 2651
# Tweets to be processed: 48
# Processing tweet. ID = 1243054381282418688
#
# Current indx: 2652
# Tweets to be processed: 47
# Processing tweet. ID = 1243054399837986816
#
# Current indx: 2653
# Tweets to be processed: 46
# Processing tweet. ID = 1243054444729618433
#
# Current indx: 2654
# Tweets to be processed: 45
# Processing tweet. ID = 1243054490900668418
#
# Current indx: 2655
# Tweets to be processed: 44
# Processing tweet. ID = 1243054538937913347
#
# Current indx: 2656
# Tweets to be processed: 43
# Processing tweet. ID = 1243054553617989632
#
# Current indx: 2657
# Tweets to be processed: 42
# Processing tweet. ID = 1243054690708774912
#
# Current indx: 2658
# Tweets to be processed: 41
# Processing tweet. ID = 1243054703031668736
#
# Current indx: 2659
# Tweets to be processed: 40
# Processing tweet. ID = 1243054758983634944
#
# Current indx: 2660
# Tweets to be processed: 39
# Processing tweet. ID = 1243054889216790528
#
# Current indx: 2661
# Tweets to be processed: 38
# Processing tweet. ID = 1243054890970050560
#
# Current indx: 2662
# Tweets to be processed: 37
# Processing tweet. ID = 1243054990878359552
#
# Current indx: 2663
# Tweets to be processed: 36
# Processing tweet. ID = 1243055123611258883
#
# Current indx: 2664
# Tweets to be processed: 35
# Processing tweet. ID = 1243055140497547264
#
# Current indx: 2665
# Tweets to be processed: 34
# Processing tweet. ID = 1243055268239273990
#
# Current indx: 2666
# Tweets to be processed: 33
# Processing tweet. ID = 1243055341572505600
#
# Current indx: 2667
# Tweets to be processed: 32
# Processing tweet. ID = 1243055343069827072
#
# Current indx: 2668
# Tweets to be processed: 31
# Processing tweet. ID = 1243055387743412230
#
# Current indx: 2669
# Tweets to be processed: 30
# Processing tweet. ID = 1243055792036679685
#
# Current indx: 2670
# Tweets to be processed: 29
# Processing tweet. ID = 1243055869203320832
#
# Current indx: 2671
# Tweets to be processed: 28
# Processing tweet. ID = 1243055900975382529
#
# Current indx: 2672
# Tweets to be processed: 27
# Processing tweet. ID = 1243055917593051136
#
# Current indx: 2673
# Tweets to be processed: 26
# Processing tweet. ID = 1243055922424860672
#
# Current indx: 2674
# Tweets to be processed: 25
# Processing tweet. ID = 1243056057884110850
#
# Current indx: 2675
# Tweets to be processed: 24
# Processing tweet. ID = 1243056074527105024
#
# Current indx: 2676
# Tweets to be processed: 23
# Processing tweet. ID = 1243056192970088450
#
# Current indx: 2677
# Tweets to be processed: 22
# Processing tweet. ID = 1243056244937515013
#
# Current indx: 2678
# Tweets to be processed: 21
# Processing tweet. ID = 1243056380199628800
#
# Current indx: 2679
# Tweets to be processed: 20
# Processing tweet. ID = 1243056398256050177
#
# Current indx: 2680
# Tweets to be processed: 19
# Processing tweet. ID = 1243056571493437440
#
# Current indx: 2681
# Tweets to be processed: 18
# Processing tweet. ID = 1243056677835821057
#
# Current indx: 2682
# Tweets to be processed: 17
# Processing tweet. ID = 1243056740960055296
#
# Current indx: 2683
# Tweets to be processed: 16
# Processing tweet. ID = 1243056743573155840
#
# Current indx: 2684
# Tweets to be processed: 15
# Processing tweet. ID = 1243056753450704896
#
# Current indx: 2685
# Tweets to be processed: 14
# Processing tweet. ID = 1243056945701027840
#
# Current indx: 2686
# Tweets to be processed: 13
# Processing tweet. ID = 1243057022108446722
#
# Current indx: 2687
# Tweets to be processed: 12
# Processing tweet. ID = 1243057130120171521
#
# Current indx: 2688
# Tweets to be processed: 11
# Processing tweet. ID = 1243057177792860160
#
# Current indx: 2689
# Tweets to be processed: 10
# Processing tweet. ID = 1243057329311903746
#
# Current indx: 2690
# Tweets to be processed: 9
# Processing tweet. ID = 1243057403135852544
#
# Current indx: 2691
# Tweets to be processed: 8
# Processing tweet. ID = 1243057439466872832
#
# Current indx: 2692
# Tweets to be processed: 7
# Processing tweet. ID = 1243057646233673730
#
# Current indx: 2693
# Tweets to be processed: 6
# Processing tweet. ID = 1243057677296521216
#
# Current indx: 2694
# Tweets to be processed: 5
# Processing tweet. ID = 1243057731558236161
# Error while accessing tweet. ID: 1243057731558236161
#
# Current indx: 2695
# Tweets to be processed: 4
# Processing tweet. ID = 1243057834381565955
#
# Current indx: 2696
# Tweets to be processed: 3
# Processing tweet. ID = 1243058084022378497
#
# Current indx: 2697
# Tweets to be processed: 2
# Processing tweet. ID = 1243058117874573319

# %%
indx_manager_write = open('index_manager.txt', 'w')
indx_manager_write.write(str(indx))
indx_manager_write.close()
print(str(indx))
# Out:
# 2698

# %%
text_2 = text
for ttext in text:
    ttext = ttext.strip("\n")

# %%
#         text.append(tweet.full_text)
#         created_at.append(tweet.created_at)
#         id_str.append(tweet.id_str)
#         entities.append(tweet.entities)
#         user_id.append(tweet.user.id)
#         location.append(tweet.user.location)
#         lang.append(tweet.lang)
#         time_zone.append(tweet.user.time_zone)

# for loc in location[:10]:
#     print(loc)

# %%
import pandas as pd

# df = pd.DataFrame(columns=['id_str', 'user_id', 'text', 'created_at', 'entities', 'location', 'lang', 'time_zone'])
df = pd.DataFrame(columns=['id_str', 'user_id', 'text', 'created_at', 'entities', 'lang', 'time_zone'])
df.head()

df['id_str'] = id_str
df['user_id'] = user_id
df['text'] = text
df['created_at'] = created_at
df['entities'] = entities
# df['location'] = location
df['lang'] = lang
df['time_zone'] = time_zone

# %%
df.head()
# Out:
#                 id_str              user_id  \
# 0  1242874670736695297            550183597
# 1  1242874722791993344   960522644079640576
# 2  1242874757332086784  1182005217459490817
# 3  1242874803599491073           2257381975
# 4  1242874896885006337             79539419
#
#                                                 text          created_at  \
# 0  21days #lockdown today is getting to over so w... 2020-03-25 18:03:07
# 1  Food, money running out, Delhi’s daily wagers ... 2020-03-25 18:03:20
# 2  our one step in favour of 21 lock down make in... 2020-03-25 18:03:28
# 3  INDIA PLEASE SEE THIS AND START RESPECTING OUR... 2020-03-25 18:03:39
# 4  Corona deaths globally cross 20k #StopTheSprea... 2020-03-25 18:04:01
#
#                                             entities lang time_zone
# 0  {'hashtags': [{'text': 'lockdown', 'indices': ...   en      None
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...   en      None
# 2  {'hashtags': [{'text': '21daylockdown', 'indic...   en      None
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...   en      None
# 4  {'hashtags': [{'text': 'StopTheSpreadOfCorona'...   en      None

# %%
file_new = open('file_manager.txt', 'r')
file_indx = file_new.read()
file_new.close()
filename = 'final_tweets_' + file_indx + '.csv'
# filename = 'final_tweets_1.csv'
print(filename)
# Out:
# final_tweets_3.csv

# %%
df.to_csv(filename)

# %%
file_indx = int(file_indx)
file_indx += 1

file_write = open('file_manager.txt', 'w')
file_write.write(str(file_indx))
file_write.close()

# %%
print(file_indx)
# Out:
# 2

# %%
######## DO NOT RUN #################


# print("writing to dataset")
# with open("tweets.txt", "w+") as f:
#     for tweet in tweets:
#         print("writing to txt file. tweet: " + str(tweet))
#         f.write("%s\n" % str(tweet))
        
# print("writing to dataset")
# with open("dates.txt", "w+") as f:
#     for date in dates:
#         print("writing to txt file. tweet: " + str(date))
#         f.write("%s\n" % str(date))

# %%
id_t = tweets_df['tweet_id'].tolist()[1]
tweet_2 = api.get_status(id_t, tweet_mode = 'extended')
print(tweet_2.full_text)
# Out:
# CORONA 19 UPDATE
# ----------------------------------------------------------
# Total effected : 420000
# Recovered : 107000
# Fatality : 18500
# Under Treatment : ( 420000-107000) = 313000
# Fatality Rate = 18500/420000×100=  4.4 %
# UT Rate = 74.52%
#
# GLOBAL FIGURE
