# %%
import tweepy as tw
import pandas as pd
import os
import csv

# %%
consumer_key = "IQFN7RfvSs3107ZGKq1vDE2Um"
consumer_secret = "JF8rB1ftzNPzNKCUGHTZXtZV22yiCK51bJnl51t1riNnLy4cuJ"
access_token = "1008966897130303488-PNJTNYKhrs5q3YbCIZf2lRGC817JSQ"
access_token_secret = "89xKwZBAZBUHLVqoayE1gDGfuJeJwzLhnkZ7NnXvOJZ6v"

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
tweets_df = pd.read_csv("tweet_ids.csv")
tweets_df.head()
# Out:
#    Unnamed: 0             tweet_id
# 0         0.0  1242693364098580481
# 1         1.0  1242693402971406342
# 2         2.0  1242693578817597442
# 3         3.0  1242693609725575168
# 4         4.0  1242693680143544325

# %%
index_manager_read = open('index_manager.txt', 'r')
indx = index_manager_read.read()
print(indx)
index_manager_read.close()
# Out:
# 900

# %%
twitter_ids = tweets_df["tweet_id"].tolist()
i = 0
indx = int(indx)
ids = twitter_ids[indx:indx + 899]

text = []
id_str = []
entities_hashtags = []
entities_symbols = []
entities = []
user_id = []
user_ion = []
time_zone = []
lang = []
created_at = []

cnt = 0

# %%
for tweet_id in ids:
    
    print("\nCurrent indx: " + str(indx))
    print("Tweets to be processed: " + str(900-cnt))
    cnt += 1 
    indx += 1
    
    try:
        print("Processing tweet. ID = " + str(tweet_id))
        
        tweet = api.get_status(tweet_id, tweet_mode = 'extended', include_entities = True)
        
        text.append(tweet.full_text)
        created_at.append(tweet.created_at)
        id_str.append(tweet.id_str)
        entities.append(tweet.entities)
        user_id.append(tweet.user.id)
        lang.append(tweet.lang)
        time_zone.append(tweet.user.time_zone)
        
        if(cnt%100 == 0):
            print("Text: " + str(tweet.full_text))
    except tw.error.TweepError:
      print("Error while accessing tweet. ID: " + str(tweet_id))
      pass
# Out:
# Current indx: 900
# Tweets to be processed: 900
# Processing tweet. ID = 1242793182099722241
#
# Current indx: 901
# Tweets to be processed: 899
# Processing tweet. ID = 1242793226886475781
#
# Current indx: 902
# Tweets to be processed: 898
# Processing tweet. ID = 1242793254044626944
#
# Current indx: 903
# Tweets to be processed: 897
# Processing tweet. ID = 1242793310990802944
#
# Current indx: 904
# Tweets to be processed: 896
# Processing tweet. ID = 1242793331425337344
#
# Current indx: 905
# Tweets to be processed: 895
# Processing tweet. ID = 1242793411343572992
#
# Current indx: 906
# Tweets to be processed: 894
# Processing tweet. ID = 1242793445254516737
#
# Current indx: 907
# Tweets to be processed: 893
# Processing tweet. ID = 1242793499436564480
#
# Current indx: 908
# Tweets to be processed: 892
# Processing tweet. ID = 1242793635663327236
#
# Current indx: 909
# Tweets to be processed: 891
# Processing tweet. ID = 1242793821525557248
#
# Current indx: 910
# Tweets to be processed: 890
# Processing tweet. ID = 1242793987603226629
#
# Current indx: 911
# Tweets to be processed: 889
# Processing tweet. ID = 1242794118721331201
#
# Current indx: 912
# Tweets to be processed: 888
# Processing tweet. ID = 1242794216511508481
#
# Current indx: 913
# Tweets to be processed: 887
# Processing tweet. ID = 1242794233578340353
#
# Current indx: 914
# Tweets to be processed: 886
# Processing tweet. ID = 1242794413828370432
#
# Current indx: 915
# Tweets to be processed: 885
# Processing tweet. ID = 1242794566597488640
#
# Current indx: 916
# Tweets to be processed: 884
# Processing tweet. ID = 1242794872811159557
#
# Current indx: 917
# Tweets to be processed: 883
# Processing tweet. ID = 1242794986959073281
#
# Current indx: 918
# Tweets to be processed: 882
# Processing tweet. ID = 1242795111777308672
#
# Current indx: 919
# Tweets to be processed: 881
# Processing tweet. ID = 1242795112318390273
#
# Current indx: 920
# Tweets to be processed: 880
# Processing tweet. ID = 1242795187744567297
#
# Current indx: 921
# Tweets to be processed: 879
# Processing tweet. ID = 1242795263112040448
#
# Current indx: 922
# Tweets to be processed: 878
# Processing tweet. ID = 1242795280497426433
#
# Current indx: 923
# Tweets to be processed: 877
# Processing tweet. ID = 1242795291050303489
#
# Current indx: 924
# Tweets to be processed: 876
# Processing tweet. ID = 1242795341411467264
#
# Current indx: 925
# Tweets to be processed: 875
# Processing tweet. ID = 1242795346196975617
#
# Current indx: 926
# Tweets to be processed: 874
# Processing tweet. ID = 1242795675139502082
#
# Current indx: 927
# Tweets to be processed: 873
# Processing tweet. ID = 1242795710023532544
#
# Current indx: 928
# Tweets to be processed: 872
# Processing tweet. ID = 1242795711042686977
#
# Current indx: 929
# Tweets to be processed: 871
# Processing tweet. ID = 1242795820857962498
#
# Current indx: 930
# Tweets to be processed: 870
# Processing tweet. ID = 1242795964051546113
#
# Current indx: 931
# Tweets to be processed: 869
# Processing tweet. ID = 1242795969218883584
#
# Current indx: 932
# Tweets to be processed: 868
# Processing tweet. ID = 1242796004103069698
#
# Current indx: 933
# Tweets to be processed: 867
# Processing tweet. ID = 1242796150358290432
#
# Current indx: 934
# Tweets to be processed: 866
# Processing tweet. ID = 1242796205815586816
#
# Current indx: 935
# Tweets to be processed: 865
# Processing tweet. ID = 1242796275000459264
#
# Current indx: 936
# Tweets to be processed: 864
# Processing tweet. ID = 1242796492982640644
#
# Current indx: 937
# Tweets to be processed: 863
# Processing tweet. ID = 1242796499504783360
#
# Current indx: 938
# Tweets to be processed: 862
# Processing tweet. ID = 1242796717218476032
#
# Current indx: 939
# Tweets to be processed: 861
# Processing tweet. ID = 1242796741230915585
#
# Current indx: 940
# Tweets to be processed: 860
# Processing tweet. ID = 1242796965777125376
#
# Current indx: 941
# Tweets to be processed: 859
# Processing tweet. ID = 1242797047184388096
#
# Current indx: 942
# Tweets to be processed: 858
# Processing tweet. ID = 1242797116004548609
#
# Current indx: 943
# Tweets to be processed: 857
# Processing tweet. ID = 1242797292194652161
#
# Current indx: 944
# Tweets to be processed: 856
# Processing tweet. ID = 1242797319193366528
#
# Current indx: 945
# Tweets to be processed: 855
# Processing tweet. ID = 1242797403637346307
#
# Current indx: 946
# Tweets to be processed: 854
# Processing tweet. ID = 1242797508796899328
#
# Current indx: 947
# Tweets to be processed: 853
# Processing tweet. ID = 1242797542150033409
#
# Current indx: 948
# Tweets to be processed: 852
# Processing tweet. ID = 1242797587960188929
#
# Current indx: 949
# Tweets to be processed: 851
# Processing tweet. ID = 1242797627114209287
#
# Current indx: 950
# Tweets to be processed: 850
# Processing tweet. ID = 1242797626476511239
# Error while accessing tweet. ID: 1242797626476511239
#
# Current indx: 951
# Tweets to be processed: 849
# Processing tweet. ID = 1242797635628482560
#
# Current indx: 952
# Tweets to be processed: 848
# Processing tweet. ID = 1242797710865915909
#
# Current indx: 953
# Tweets to be processed: 847
# Processing tweet. ID = 1242797718071803905
#
# Current indx: 954
# Tweets to be processed: 846
# Processing tweet. ID = 1242797827522060288
#
# Current indx: 955
# Tweets to be processed: 845
# Processing tweet. ID = 1242797838418862081
#
# Current indx: 956
# Tweets to be processed: 844
# Processing tweet. ID = 1242798037023350784
#
# Current indx: 957
# Tweets to be processed: 843
# Processing tweet. ID = 1242798046385025024
#
# Current indx: 958
# Tweets to be processed: 842
# Processing tweet. ID = 1242798062373875716
#
# Current indx: 959
# Tweets to be processed: 841
# Processing tweet. ID = 1242798084343513089
#
# Current indx: 960
# Tweets to be processed: 840
# Processing tweet. ID = 1242798092954431488
# Error while accessing tweet. ID: 1242798092954431488
#
# Current indx: 961
# Tweets to be processed: 839
# Processing tweet. ID = 1242798180950888450
#
# Current indx: 962
# Tweets to be processed: 838
# Processing tweet. ID = 1242798206536151045
#
# Current indx: 963
# Tweets to be processed: 837
# Processing tweet. ID = 1242798304624173056
#
# Current indx: 964
# Tweets to be processed: 836
# Processing tweet. ID = 1242798315801960448
#
# Current indx: 965
# Tweets to be processed: 835
# Processing tweet. ID = 1242798452448194560
#
# Current indx: 966
# Tweets to be processed: 834
# Processing tweet. ID = 1242798615564709895
#
# Current indx: 967
# Tweets to be processed: 833
# Processing tweet. ID = 1242798684657430528
#
# Current indx: 968
# Tweets to be processed: 832
# Processing tweet. ID = 1242798744283701253
#
# Current indx: 969
# Tweets to be processed: 831
# Processing tweet. ID = 1242798988274720768
#
# Current indx: 970
# Tweets to be processed: 830
# Processing tweet. ID = 1242799024056545281
#
# Current indx: 971
# Tweets to be processed: 829
# Processing tweet. ID = 1242799085821652993
#
# Current indx: 972
# Tweets to be processed: 828
# Processing tweet. ID = 1242799158412455936
#
# Current indx: 973
# Tweets to be processed: 827
# Processing tweet. ID = 1242799362998071296
#
# Current indx: 974
# Tweets to be processed: 826
# Processing tweet. ID = 1242799442744332292
#
# Current indx: 975
# Tweets to be processed: 825
# Processing tweet. ID = 1242799464949006336
#
# Current indx: 976
# Tweets to be processed: 824
# Processing tweet. ID = 1242799558637178880
#
# Current indx: 977
# Tweets to be processed: 823
# Processing tweet. ID = 1242799683837128704
#
# Current indx: 978
# Tweets to be processed: 822
# Processing tweet. ID = 1242799835603857408
#
# Current indx: 979
# Tweets to be processed: 821
# Processing tweet. ID = 1242799992533704707
#
# Current indx: 980
# Tweets to be processed: 820
# Processing tweet. ID = 1242800012729495563
#
# Current indx: 981
# Tweets to be processed: 819
# Processing tweet. ID = 1242800020056764416
#
# Current indx: 982
# Tweets to be processed: 818
# Processing tweet. ID = 1242800103955415044
#
# Current indx: 983
# Tweets to be processed: 817
# Processing tweet. ID = 1242800112423731200
#
# Current indx: 984
# Tweets to be processed: 816
# Processing tweet. ID = 1242800267927498752
#
# Current indx: 985
# Tweets to be processed: 815
# Processing tweet. ID = 1242800361548574722
#
# Current indx: 986
# Tweets to be processed: 814
# Processing tweet. ID = 1242800400404602881
#
# Current indx: 987
# Tweets to be processed: 813
# Processing tweet. ID = 1242800542197268480
#
# Current indx: 988
# Tweets to be processed: 812
# Processing tweet. ID = 1242800594064224256
#
# Current indx: 989
# Tweets to be processed: 811
# Processing tweet. ID = 1242800753250430976
#
# Current indx: 990
# Tweets to be processed: 810
# Processing tweet. ID = 1242800863485153280
#
# Current indx: 991
# Tweets to be processed: 809
# Processing tweet. ID = 1242800959136251904
#
# Current indx: 992
# Tweets to be processed: 808
# Processing tweet. ID = 1242801009627402242
#
# Current indx: 993
# Tweets to be processed: 807
# Processing tweet. ID = 1242801131354345472
#
# Current indx: 994
# Tweets to be processed: 806
# Processing tweet. ID = 1242801165391273990
#
# Current indx: 995
# Tweets to be processed: 805
# Processing tweet. ID = 1242801202032599047
#
# Current indx: 996
# Tweets to be processed: 804
# Processing tweet. ID = 1242801235532460033
#
# Current indx: 997
# Tweets to be processed: 803
# Processing tweet. ID = 1242801285998374912
#
# Current indx: 998
# Tweets to be processed: 802
# Processing tweet. ID = 1242801286229053441
#
# Current indx: 999
# Tweets to be processed: 801
# Processing tweet. ID = 1242801320429408256
# Text: Finally people are following their New Years resolution of working out thanks to corona!
# #QuarantineWorkout #QuarantineLife #WorkoutFromHome
#
# Current indx: 1000
# Tweets to be processed: 800
# Processing tweet. ID = 1242801347499442176
#
# Current indx: 1001
# Tweets to be processed: 799
# Processing tweet. ID = 1242801408111333376
#
# Current indx: 1002
# Tweets to be processed: 798
# Processing tweet. ID = 1242801732272480258
#
# Current indx: 1003
# Tweets to be processed: 797
# Processing tweet. ID = 1242801849360515072
#
# Current indx: 1004
# Tweets to be processed: 796
# Processing tweet. ID = 1242801850945916929
#
# Current indx: 1005
# Tweets to be processed: 795
# Processing tweet. ID = 1242801903076913156
#
# Current indx: 1006
# Tweets to be processed: 794
# Processing tweet. ID = 1242801920428761088
#
# Current indx: 1007
# Tweets to be processed: 793
# Processing tweet. ID = 1242801974346543105
#
# Current indx: 1008
# Tweets to be processed: 792
# Processing tweet. ID = 1242801985830584320
#
# Current indx: 1009
# Tweets to be processed: 791
# Processing tweet. ID = 1242802173466968069
#
# Current indx: 1010
# Tweets to be processed: 790
# Processing tweet. ID = 1242802238092804096
#
# Current indx: 1011
# Tweets to be processed: 789
# Processing tweet. ID = 1242802246137466880
#
# Current indx: 1012
# Tweets to be processed: 788
# Processing tweet. ID = 1242802293512318977
#
# Current indx: 1013
# Tweets to be processed: 787
# Processing tweet. ID = 1242802426769338369
#
# Current indx: 1014
# Tweets to be processed: 786
# Processing tweet. ID = 1242802458662973440
#
# Current indx: 1015
# Tweets to be processed: 785
# Processing tweet. ID = 1242802796014866432
#
# Current indx: 1016
# Tweets to be processed: 784
# Processing tweet. ID = 1242802852382142465
#
# Current indx: 1017
# Tweets to be processed: 783
# Processing tweet. ID = 1242803081131085824
#
# Current indx: 1018
# Tweets to be processed: 782
# Processing tweet. ID = 1242803123153821696
#
# Current indx: 1019
# Tweets to be processed: 781
# Processing tweet. ID = 1242803153533165569
#
# Current indx: 1020
# Tweets to be processed: 780
# Processing tweet. ID = 1242803284219293698
#
# Current indx: 1021
# Tweets to be processed: 779
# Processing tweet. ID = 1242803396966400000
#
# Current indx: 1022
# Tweets to be processed: 778
# Processing tweet. ID = 1242803564700811264
#
# Current indx: 1023
# Tweets to be processed: 777
# Processing tweet. ID = 1242803581155147778
#
# Current indx: 1024
# Tweets to be processed: 776
# Processing tweet. ID = 1242803708179542016
#
# Current indx: 1025
# Tweets to be processed: 775
# Processing tweet. ID = 1242803833144655872
#
# Current indx: 1026
# Tweets to be processed: 774
# Processing tweet. ID = 1242804017723404289
#
# Current indx: 1027
# Tweets to be processed: 773
# Processing tweet. ID = 1242804171956355072
#
# Current indx: 1028
# Tweets to be processed: 772
# Processing tweet. ID = 1242804189345939456
#
# Current indx: 1029
# Tweets to be processed: 771
# Processing tweet. ID = 1242804272003047424
#
# Current indx: 1030
# Tweets to be processed: 770
# Processing tweet. ID = 1242804395005231107
#
# Current indx: 1031
# Tweets to be processed: 769
# Processing tweet. ID = 1242804446154850304
#
# Current indx: 1032
# Tweets to be processed: 768
# Processing tweet. ID = 1242804465171914758
#
# Current indx: 1033
# Tweets to be processed: 767
# Processing tweet. ID = 1242804497337815040
#
# Current indx: 1034
# Tweets to be processed: 766
# Processing tweet. ID = 1242804587645431815
#
# Current indx: 1035
# Tweets to be processed: 765
# Processing tweet. ID = 1242804657971269633
#
# Current indx: 1036
# Tweets to be processed: 764
# Processing tweet. ID = 1242804817782685697
#
# Current indx: 1037
# Tweets to be processed: 763
# Processing tweet. ID = 1242804855443464194
#
# Current indx: 1038
# Tweets to be processed: 762
# Processing tweet. ID = 1242804895935123458
#
# Current indx: 1039
# Tweets to be processed: 761
# Processing tweet. ID = 1242804968412688384
#
# Current indx: 1040
# Tweets to be processed: 760
# Processing tweet. ID = 1242805024264040448
#
# Current indx: 1041
# Tweets to be processed: 759
# Processing tweet. ID = 1242805390305189888
#
# Current indx: 1042
# Tweets to be processed: 758
# Processing tweet. ID = 1242805542721994753
#
# Current indx: 1043
# Tweets to be processed: 757
# Processing tweet. ID = 1242805651765522432
#
# Current indx: 1044
# Tweets to be processed: 756
# Processing tweet. ID = 1242805916124082181
#
# Current indx: 1045
# Tweets to be processed: 755
# Processing tweet. ID = 1242806012257566720
#
# Current indx: 1046
# Tweets to be processed: 754
# Processing tweet. ID = 1242806389883285504
#
# Current indx: 1047
# Tweets to be processed: 753
# Processing tweet. ID = 1242806406220148738
#
# Current indx: 1048
# Tweets to be processed: 752
# Processing tweet. ID = 1242806412465426432
#
# Current indx: 1049
# Tweets to be processed: 751
# Processing tweet. ID = 1242806711439609857
#
# Current indx: 1050
# Tweets to be processed: 750
# Processing tweet. ID = 1242806737356423168
#
# Current indx: 1051
# Tweets to be processed: 749
# Processing tweet. ID = 1242806791660068866
#
# Current indx: 1052
# Tweets to be processed: 748
# Processing tweet. ID = 1242806845443469314
#
# Current indx: 1053
# Tweets to be processed: 747
# Processing tweet. ID = 1242807213837582338
#
# Current indx: 1054
# Tweets to be processed: 746
# Processing tweet. ID = 1242807360059396096
#
# Current indx: 1055
# Tweets to be processed: 745
# Processing tweet. ID = 1242807457501442048
#
# Current indx: 1056
# Tweets to be processed: 744
# Processing tweet. ID = 1242807487390076929
#
# Current indx: 1057
# Tweets to be processed: 743
# Processing tweet. ID = 1242807573155209218
#
# Current indx: 1058
# Tweets to be processed: 742
# Processing tweet. ID = 1242807618596270080
#
# Current indx: 1059
# Tweets to be processed: 741
# Processing tweet. ID = 1242807717569282049
#
# Current indx: 1060
# Tweets to be processed: 740
# Processing tweet. ID = 1242807721008619520
#
# Current indx: 1061
# Tweets to be processed: 739
# Processing tweet. ID = 1242808059379855360
#
# Current indx: 1062
# Tweets to be processed: 738
# Processing tweet. ID = 1242808080745693184
#
# Current indx: 1063
# Tweets to be processed: 737
# Processing tweet. ID = 1242808390918627330
#
# Current indx: 1064
# Tweets to be processed: 736
# Processing tweet. ID = 1242808518777794566
#
# Current indx: 1065
# Tweets to be processed: 735
# Processing tweet. ID = 1242808596565393408
#
# Current indx: 1066
# Tweets to be processed: 734
# Processing tweet. ID = 1242808674860404737
#
# Current indx: 1067
# Tweets to be processed: 733
# Processing tweet. ID = 1242808700726693895
#
# Current indx: 1068
# Tweets to be processed: 732
# Processing tweet. ID = 1242808862119362562
#
# Current indx: 1069
# Tweets to be processed: 731
# Processing tweet. ID = 1242808886433681409
#
# Current indx: 1070
# Tweets to be processed: 730
# Processing tweet. ID = 1242808952980754433
#
# Current indx: 1071
# Tweets to be processed: 729
# Processing tweet. ID = 1242808971695517706
#
# Current indx: 1072
# Tweets to be processed: 728
# Processing tweet. ID = 1242808980277096448
#
# Current indx: 1073
# Tweets to be processed: 727
# Processing tweet. ID = 1242809103015002114
#
# Current indx: 1074
# Tweets to be processed: 726
# Processing tweet. ID = 1242809203355299840
#
# Current indx: 1075
# Tweets to be processed: 725
# Processing tweet. ID = 1242809210699743234
#
# Current indx: 1076
# Tweets to be processed: 724
# Processing tweet. ID = 1242809330581131265
#
# Current indx: 1077
# Tweets to be processed: 723
# Processing tweet. ID = 1242809571288264704
#
# Current indx: 1078
# Tweets to be processed: 722
# Processing tweet. ID = 1242809787319873537
#
# Current indx: 1079
# Tweets to be processed: 721
# Processing tweet. ID = 1242809819662127104
#
# Current indx: 1080
# Tweets to be processed: 720
# Processing tweet. ID = 1242809969965236224
#
# Current indx: 1081
# Tweets to be processed: 719
# Processing tweet. ID = 1242809995135193089
#
# Current indx: 1082
# Tweets to be processed: 718
# Processing tweet. ID = 1242810052701900800
#
# Current indx: 1083
# Tweets to be processed: 717
# Processing tweet. ID = 1242810070863208455
#
# Current indx: 1084
# Tweets to be processed: 716
# Processing tweet. ID = 1242810223682879488
#
# Current indx: 1085
# Tweets to be processed: 715
# Processing tweet. ID = 1242810351881801735
#
# Current indx: 1086
# Tweets to be processed: 714
# Processing tweet. ID = 1242810501442109446
#
# Current indx: 1087
# Tweets to be processed: 713
# Processing tweet. ID = 1242810733253079042
#
# Current indx: 1088
# Tweets to be processed: 712
# Processing tweet. ID = 1242810751540015108
#
# Current indx: 1089
# Tweets to be processed: 711
# Processing tweet. ID = 1242810800156229633
#
# Current indx: 1090
# Tweets to be processed: 710
# Processing tweet. ID = 1242810868015828994
#
# Current indx: 1091
# Tweets to be processed: 709
# Processing tweet. ID = 1242810955689381888
#
# Current indx: 1092
# Tweets to be processed: 708
# Processing tweet. ID = 1242811034445864960
#
# Current indx: 1093
# Tweets to be processed: 707
# Processing tweet. ID = 1242811244547096576
#
# Current indx: 1094
# Tweets to be processed: 706
# Processing tweet. ID = 1242811519466905601
#
# Current indx: 1095
# Tweets to be processed: 705
# Processing tweet. ID = 1242811614149001223
#
# Current indx: 1096
# Tweets to be processed: 704
# Processing tweet. ID = 1242811697284419584
#
# Current indx: 1097
# Tweets to be processed: 703
# Processing tweet. ID = 1242811714573238273
#
# Current indx: 1098
# Tweets to be processed: 702
# Processing tweet. ID = 1242811872950157317
#
# Current indx: 1099
# Tweets to be processed: 701
# Processing tweet. ID = 1242811885704998913
# Text: @PMOIndia @narendramodi The Prime Minister Narendra Modi Ji. I request to you, our India is going through painful condition by pandemic Corona Virus. It is spreading very quickly and peoples are dieing and also morbid. If you will refuge in Saint Rampal Ji Maharaj. So, India will safe.
#
# Current indx: 1100
# Tweets to be processed: 700
# Processing tweet. ID = 1242811889228189696
#
# Current indx: 1101
# Tweets to be processed: 699
# Processing tweet. ID = 1242812126311395330
#
# Current indx: 1102
# Tweets to be processed: 698
# Processing tweet. ID = 1242812173799153665
#
# Current indx: 1103
# Tweets to be processed: 697
# Processing tweet. ID = 1242812216732053506
#
# Current indx: 1104
# Tweets to be processed: 696
# Processing tweet. ID = 1242812227121344512
#
# Current indx: 1105
# Tweets to be processed: 695
# Processing tweet. ID = 1242812352287797249
#
# Current indx: 1106
# Tweets to be processed: 694
# Processing tweet. ID = 1242812373116706817
#
# Current indx: 1107
# Tweets to be processed: 693
# Processing tweet. ID = 1242812553102647298
#
# Current indx: 1108
# Tweets to be processed: 692
# Processing tweet. ID = 1242812557598941186
#
# Current indx: 1109
# Tweets to be processed: 691
# Processing tweet. ID = 1242812774830362624
#
# Current indx: 1110
# Tweets to be processed: 690
# Processing tweet. ID = 1242812808678346752
#
# Current indx: 1111
# Tweets to be processed: 689
# Processing tweet. ID = 1242812842329415683
#
# Current indx: 1112
# Tweets to be processed: 688
# Processing tweet. ID = 1242812863837659136
#
# Current indx: 1113
# Tweets to be processed: 687
# Processing tweet. ID = 1242812917516361728
#
# Current indx: 1114
# Tweets to be processed: 686
# Processing tweet. ID = 1242812941277073410
#
# Current indx: 1115
# Tweets to be processed: 685
# Processing tweet. ID = 1242813037901307905
#
# Current indx: 1116
# Tweets to be processed: 684
# Processing tweet. ID = 1242813113797210112
#
# Current indx: 1117
# Tweets to be processed: 683
# Processing tweet. ID = 1242813114812256258
#
# Current indx: 1118
# Tweets to be processed: 682
# Processing tweet. ID = 1242813139848015872
#
# Current indx: 1119
# Tweets to be processed: 681
# Processing tweet. ID = 1242813200254382083
#
# Current indx: 1120
# Tweets to be processed: 680
# Processing tweet. ID = 1242813349433237504
#
# Current indx: 1121
# Tweets to be processed: 679
# Processing tweet. ID = 1242813425106989063
#
# Current indx: 1122
# Tweets to be processed: 678
# Processing tweet. ID = 1242813497450217472
#
# Current indx: 1123
# Tweets to be processed: 677
# Processing tweet. ID = 1242813514223255554
#
# Current indx: 1124
# Tweets to be processed: 676
# Processing tweet. ID = 1242813580652625920
#
# Current indx: 1125
# Tweets to be processed: 675
# Processing tweet. ID = 1242813628543164416
#
# Current indx: 1126
# Tweets to be processed: 674
# Processing tweet. ID = 1242813769664704518
#
# Current indx: 1127
# Tweets to be processed: 673
# Processing tweet. ID = 1242813868163780608
#
# Current indx: 1128
# Tweets to be processed: 672
# Processing tweet. ID = 1242813932542119936
#
# Current indx: 1129
# Tweets to be processed: 671
# Processing tweet. ID = 1242813997889413120
#
# Current indx: 1130
# Tweets to be processed: 670
# Processing tweet. ID = 1242814035185164291
#
# Current indx: 1131
# Tweets to be processed: 669
# Processing tweet. ID = 1242814071415570432
#
# Current indx: 1132
# Tweets to be processed: 668
# Processing tweet. ID = 1242814145340125184
#
# Current indx: 1133
# Tweets to be processed: 667
# Processing tweet. ID = 1242814180354166785
#
# Current indx: 1134
# Tweets to be processed: 666
# Processing tweet. ID = 1242814187354513409
#
# Current indx: 1135
# Tweets to be processed: 665
# Processing tweet. ID = 1242814254534676483
#
# Current indx: 1136
# Tweets to be processed: 664
# Processing tweet. ID = 1242814255306403840
#
# Current indx: 1137
# Tweets to be processed: 663
# Processing tweet. ID = 1242814363217440770
#
# Current indx: 1138
# Tweets to be processed: 662
# Processing tweet. ID = 1242814374139424770
#
# Current indx: 1139
# Tweets to be processed: 661
# Processing tweet. ID = 1242814489747001345
#
# Current indx: 1140
# Tweets to be processed: 660
# Processing tweet. ID = 1242814585880469507
#
# Current indx: 1141
# Tweets to be processed: 659
# Processing tweet. ID = 1242814708110913538
#
# Current indx: 1142
# Tweets to be processed: 658
# Processing tweet. ID = 1242814718030409730
#
# Current indx: 1143
# Tweets to be processed: 657
# Processing tweet. ID = 1242814759981858816
#
# Current indx: 1144
# Tweets to be processed: 656
# Processing tweet. ID = 1242814855339487232
#
# Current indx: 1145
# Tweets to be processed: 655
# Processing tweet. ID = 1242814957781221382
#
# Current indx: 1146
# Tweets to be processed: 654
# Processing tweet. ID = 1242815061611229185
#
# Current indx: 1147
# Tweets to be processed: 653
# Processing tweet. ID = 1242815126924750850
#
# Current indx: 1148
# Tweets to be processed: 652
# Processing tweet. ID = 1242815139130286081
#
# Current indx: 1149
# Tweets to be processed: 651
# Processing tweet. ID = 1242815182268542978
#
# Current indx: 1150
# Tweets to be processed: 650
# Processing tweet. ID = 1242815321536262145
#
# Current indx: 1151
# Tweets to be processed: 649
# Processing tweet. ID = 1242815424007299072
#
# Current indx: 1152
# Tweets to be processed: 648
# Processing tweet. ID = 1242815431724937216
#
# Current indx: 1153
# Tweets to be processed: 647
# Processing tweet. ID = 1242815529712144385
#
# Current indx: 1154
# Tweets to be processed: 646
# Processing tweet. ID = 1242815664189886468
#
# Current indx: 1155
# Tweets to be processed: 645
# Processing tweet. ID = 1242815820217987077
#
# Current indx: 1156
# Tweets to be processed: 644
# Processing tweet. ID = 1242815836768747520
#
# Current indx: 1157
# Tweets to be processed: 643
# Processing tweet. ID = 1242815892645240832
#
# Current indx: 1158
# Tweets to be processed: 642
# Processing tweet. ID = 1242815938673512448
#
# Current indx: 1159
# Tweets to be processed: 641
# Processing tweet. ID = 1242816130512597000
#
# Current indx: 1160
# Tweets to be processed: 640
# Processing tweet. ID = 1242816266894639104
#
# Current indx: 1161
# Tweets to be processed: 639
# Processing tweet. ID = 1242816306098946050
#
# Current indx: 1162
# Tweets to be processed: 638
# Processing tweet. ID = 1242816308078501890
#
# Current indx: 1163
# Tweets to be processed: 637
# Processing tweet. ID = 1242816331839225857
#
# Current indx: 1164
# Tweets to be processed: 636
# Processing tweet. ID = 1242816620235378689
#
# Current indx: 1165
# Tweets to be processed: 635
# Processing tweet. ID = 1242817063099314177
#
# Current indx: 1166
# Tweets to be processed: 634
# Processing tweet. ID = 1242817101649211394
#
# Current indx: 1167
# Tweets to be processed: 633
# Processing tweet. ID = 1242817236064059392
#
# Current indx: 1168
# Tweets to be processed: 632
# Processing tweet. ID = 1242817313260204035
#
# Current indx: 1169
# Tweets to be processed: 631
# Processing tweet. ID = 1242817320994648065
#
# Current indx: 1170
# Tweets to be processed: 630
# Processing tweet. ID = 1242817525131300864
#
# Current indx: 1171
# Tweets to be processed: 629
# Processing tweet. ID = 1242817561432969216
#
# Current indx: 1172
# Tweets to be processed: 628
# Processing tweet. ID = 1242817582710710273
#
# Current indx: 1173
# Tweets to be processed: 627
# Processing tweet. ID = 1242817649580691457
#
# Current indx: 1174
# Tweets to be processed: 626
# Processing tweet. ID = 1242818009820848130
#
# Current indx: 1175
# Tweets to be processed: 625
# Processing tweet. ID = 1242818012979183618
#
# Current indx: 1176
# Tweets to be processed: 624
# Processing tweet. ID = 1242818055488536576
#
# Current indx: 1177
# Tweets to be processed: 623
# Processing tweet. ID = 1242818059250745345
#
# Current indx: 1178
# Tweets to be processed: 622
# Processing tweet. ID = 1242818078355816448
#
# Current indx: 1179
# Tweets to be processed: 621
# Processing tweet. ID = 1242818177551208451
#
# Current indx: 1180
# Tweets to be processed: 620
# Processing tweet. ID = 1242818222140907521
#
# Current indx: 1181
# Tweets to be processed: 619
# Processing tweet. ID = 1242818290881155074
#
# Current indx: 1182
# Tweets to be processed: 618
# Processing tweet. ID = 1242818366730940416
#
# Current indx: 1183
# Tweets to be processed: 617
# Processing tweet. ID = 1242818415917535234
# Error while accessing tweet. ID: 1242818415917535234
#
# Current indx: 1184
# Tweets to be processed: 616
# Processing tweet. ID = 1242818532896841730
#
# Current indx: 1185
# Tweets to be processed: 615
# Processing tweet. ID = 1242818581924139008
#
# Current indx: 1186
# Tweets to be processed: 614
# Processing tweet. ID = 1242818640434454531
#
# Current indx: 1187
# Tweets to be processed: 613
# Processing tweet. ID = 1242818688522137601
#
# Current indx: 1188
# Tweets to be processed: 612
# Processing tweet. ID = 1242818730754621444
#
# Current indx: 1189
# Tweets to be processed: 611
# Processing tweet. ID = 1242818734609149952
#
# Current indx: 1190
# Tweets to be processed: 610
# Processing tweet. ID = 1242818740250529795
#
# Current indx: 1191
# Tweets to be processed: 609
# Processing tweet. ID = 1242818928327311360
#
# Current indx: 1192
# Tweets to be processed: 608
# Processing tweet. ID = 1242818956982751234
#
# Current indx: 1193
# Tweets to be processed: 607
# Processing tweet. ID = 1242818961357467648
#
# Current indx: 1194
# Tweets to be processed: 606
# Processing tweet. ID = 1242818990436544513
#
# Current indx: 1195
# Tweets to be processed: 605
# Processing tweet. ID = 1242819172972687360
#
# Current indx: 1196
# Tweets to be processed: 604
# Processing tweet. ID = 1242819175212433411
#
# Current indx: 1197
# Tweets to be processed: 603
# Processing tweet. ID = 1242819411653918720
#
# Current indx: 1198
# Tweets to be processed: 602
# Processing tweet. ID = 1242819419744567297
#
# Current indx: 1199
# Tweets to be processed: 601
# Processing tweet. ID = 1242819452900536322
# Text: @Graaamin Corona celebrations.
#
# Current indx: 1200
# Tweets to be processed: 600
# Processing tweet. ID = 1242819468012576773
#
# Current indx: 1201
# Tweets to be processed: 599
# Processing tweet. ID = 1242819607699820547
#
# Current indx: 1202
# Tweets to be processed: 598
# Processing tweet. ID = 1242819694945382402
#
# Current indx: 1203
# Tweets to be processed: 597
# Processing tweet. ID = 1242819712909598725
#
# Current indx: 1204
# Tweets to be processed: 596
# Processing tweet. ID = 1242819766617640960
#
# Current indx: 1205
# Tweets to be processed: 595
# Processing tweet. ID = 1242819840009633792
#
# Current indx: 1206
# Tweets to be processed: 594
# Processing tweet. ID = 1242819863535587328
#
# Current indx: 1207
# Tweets to be processed: 593
# Processing tweet. ID = 1242819948512030720
#
# Current indx: 1208
# Tweets to be processed: 592
# Processing tweet. ID = 1242819992854372353
#
# Current indx: 1209
# Tweets to be processed: 591
# Processing tweet. ID = 1242820058453364736
#
# Current indx: 1210
# Tweets to be processed: 590
# Processing tweet. ID = 1242820112224141314
#
# Current indx: 1211
# Tweets to be processed: 589
# Processing tweet. ID = 1242820134667862016
#
# Current indx: 1212
# Tweets to be processed: 588
# Processing tweet. ID = 1242820175704907776
#
# Current indx: 1213
# Tweets to be processed: 587
# Processing tweet. ID = 1242820276011692033
#
# Current indx: 1214
# Tweets to be processed: 586
# Processing tweet. ID = 1242820417607233537
#
# Current indx: 1215
# Tweets to be processed: 585
# Processing tweet. ID = 1242820442022219776
#
# Current indx: 1216
# Tweets to be processed: 584
# Processing tweet. ID = 1242820538155716609
#
# Current indx: 1217
# Tweets to be processed: 583
# Processing tweet. ID = 1242820552667983872
#
# Current indx: 1218
# Tweets to be processed: 582
# Processing tweet. ID = 1242820718749868033
#
# Current indx: 1219
# Tweets to be processed: 581
# Processing tweet. ID = 1242820727008448513
#
# Current indx: 1220
# Tweets to be processed: 580
# Processing tweet. ID = 1242820818582695936
#
# Current indx: 1221
# Tweets to be processed: 579
# Processing tweet. ID = 1242820917345939457
#
# Current indx: 1222
# Tweets to be processed: 578
# Processing tweet. ID = 1242820959628742657
#
# Current indx: 1223
# Tweets to be processed: 577
# Processing tweet. ID = 1242820971372793856
#
# Current indx: 1224
# Tweets to be processed: 576
# Processing tweet. ID = 1242821049181302784
#
# Current indx: 1225
# Tweets to be processed: 575
# Processing tweet. ID = 1242821136238309378
#
# Current indx: 1226
# Tweets to be processed: 574
# Processing tweet. ID = 1242821219298078724
#
# Current indx: 1227
# Tweets to be processed: 573
# Processing tweet. ID = 1242821282585931776
#
# Current indx: 1228
# Tweets to be processed: 572
# Processing tweet. ID = 1242821473129115649
#
# Current indx: 1229
# Tweets to be processed: 571
# Processing tweet. ID = 1242821485372133376
#
# Current indx: 1230
# Tweets to be processed: 570
# Processing tweet. ID = 1242821516632432640
#
# Current indx: 1231
# Tweets to be processed: 569
# Processing tweet. ID = 1242821529357807616
#
# Current indx: 1232
# Tweets to be processed: 568
# Processing tweet. ID = 1242821533027848192
#
# Current indx: 1233
# Tweets to be processed: 567
# Processing tweet. ID = 1242821537327005696
#
# Current indx: 1234
# Tweets to be processed: 566
# Processing tweet. ID = 1242821552594288640
#
# Current indx: 1235
# Tweets to be processed: 565
# Processing tweet. ID = 1242821598140198912
#
# Current indx: 1236
# Tweets to be processed: 564
# Processing tweet. ID = 1242821840663228417
#
# Current indx: 1237
# Tweets to be processed: 563
# Processing tweet. ID = 1242822077247184896
#
# Current indx: 1238
# Tweets to be processed: 562
# Processing tweet. ID = 1242822407900954626
#
# Current indx: 1239
# Tweets to be processed: 561
# Processing tweet. ID = 1242822498762153984
#
# Current indx: 1240
# Tweets to be processed: 560
# Processing tweet. ID = 1242822680400797696
#
# Current indx: 1241
# Tweets to be processed: 559
# Processing tweet. ID = 1242822926815989765
#
# Current indx: 1242
# Tweets to be processed: 558
# Processing tweet. ID = 1242822990921977856
#
# Current indx: 1243
# Tweets to be processed: 557
# Processing tweet. ID = 1242823025059221505
#
# Current indx: 1244
# Tweets to be processed: 556
# Processing tweet. ID = 1242823151077163009
#
# Current indx: 1245
# Tweets to be processed: 555
# Processing tweet. ID = 1242823214306217984
#
# Current indx: 1246
# Tweets to be processed: 554
# Processing tweet. ID = 1242823333365907458
#
# Current indx: 1247
# Tweets to be processed: 553
# Processing tweet. ID = 1242823399530889222
#
# Current indx: 1248
# Tweets to be processed: 552
# Processing tweet. ID = 1242823404392046594
#
# Current indx: 1249
# Tweets to be processed: 551
# Processing tweet. ID = 1242823422175895553
#
# Current indx: 1250
# Tweets to be processed: 550
# Processing tweet. ID = 1242823656117395457
#
# Current indx: 1251
# Tweets to be processed: 549
# Processing tweet. ID = 1242823666611585025
#
# Current indx: 1252
# Tweets to be processed: 548
# Processing tweet. ID = 1242823695703273475
#
# Current indx: 1253
# Tweets to be processed: 547
# Processing tweet. ID = 1242823819099869184
#
# Current indx: 1254
# Tweets to be processed: 546
# Processing tweet. ID = 1242823825781219329
#
# Current indx: 1255
# Tweets to be processed: 545
# Processing tweet. ID = 1242823943460769795
#
# Current indx: 1256
# Tweets to be processed: 544
# Processing tweet. ID = 1242823979368235009
#
# Current indx: 1257
# Tweets to be processed: 543
# Processing tweet. ID = 1242824010229899265
#
# Current indx: 1258
# Tweets to be processed: 542
# Processing tweet. ID = 1242824166291566592
#
# Current indx: 1259
# Tweets to be processed: 541
# Processing tweet. ID = 1242824491069108224
#
# Current indx: 1260
# Tweets to be processed: 540
# Processing tweet. ID = 1242824766253404162
#
# Current indx: 1261
# Tweets to be processed: 539
# Processing tweet. ID = 1242824902211588096
# Error while accessing tweet. ID: 1242824902211588096
#
# Current indx: 1262
# Tweets to be processed: 538
# Processing tweet. ID = 1242825041378545665
#
# Current indx: 1263
# Tweets to be processed: 537
# Processing tweet. ID = 1242825330156425216
#
# Current indx: 1264
# Tweets to be processed: 536
# Processing tweet. ID = 1242825578484510725
#
# Current indx: 1265
# Tweets to be processed: 535
# Processing tweet. ID = 1242825745950359552
#
# Current indx: 1266
# Tweets to be processed: 534
# Processing tweet. ID = 1242825933750276096
#
# Current indx: 1267
# Tweets to be processed: 533
# Processing tweet. ID = 1242826011911155718
#
# Current indx: 1268
# Tweets to be processed: 532
# Processing tweet. ID = 1242826025664270342
#
# Current indx: 1269
# Tweets to be processed: 531
# Processing tweet. ID = 1242826100289359873
#
# Current indx: 1270
# Tweets to be processed: 530
# Processing tweet. ID = 1242826368750161920
#
# Current indx: 1271
# Tweets to be processed: 529
# Processing tweet. ID = 1242826394658197507
#
# Current indx: 1272
# Tweets to be processed: 528
# Processing tweet. ID = 1242826458365493248
#
# Current indx: 1273
# Tweets to be processed: 527
# Processing tweet. ID = 1242826458369626112
#
# Current indx: 1274
# Tweets to be processed: 526
# Processing tweet. ID = 1242826494394720258
#
# Current indx: 1275
# Tweets to be processed: 525
# Processing tweet. ID = 1242826574023426048
#
# Current indx: 1276
# Tweets to be processed: 524
# Processing tweet. ID = 1242826725018554368
#
# Current indx: 1277
# Tweets to be processed: 523
# Processing tweet. ID = 1242826910633164800
#
# Current indx: 1278
# Tweets to be processed: 522
# Processing tweet. ID = 1242826918916960264
#
# Current indx: 1279
# Tweets to be processed: 521
# Processing tweet. ID = 1242826930472112128
#
# Current indx: 1280
# Tweets to be processed: 520
# Processing tweet. ID = 1242827163570597892
#
# Current indx: 1281
# Tweets to be processed: 519
# Processing tweet. ID = 1242827166024228870
#
# Current indx: 1282
# Tweets to be processed: 518
# Processing tweet. ID = 1242827278301548544
#
# Current indx: 1283
# Tweets to be processed: 517
# Processing tweet. ID = 1242827306088812544
#
# Current indx: 1284
# Tweets to be processed: 516
# Processing tweet. ID = 1242827326133399552
#
# Current indx: 1285
# Tweets to be processed: 515
# Processing tweet. ID = 1242827540160376836
#
# Current indx: 1286
# Tweets to be processed: 514
# Processing tweet. ID = 1242827747077939204
#
# Current indx: 1287
# Tweets to be processed: 513
# Processing tweet. ID = 1242827756246720514
#
# Current indx: 1288
# Tweets to be processed: 512
# Processing tweet. ID = 1242827912556032000
#
# Current indx: 1289
# Tweets to be processed: 511
# Processing tweet. ID = 1242828035088240641
#
# Current indx: 1290
# Tweets to be processed: 510
# Processing tweet. ID = 1242828124217171971
#
# Current indx: 1291
# Tweets to be processed: 509
# Processing tweet. ID = 1242828145402605574
#
# Current indx: 1292
# Tweets to be processed: 508
# Processing tweet. ID = 1242828237710843905
#
# Current indx: 1293
# Tweets to be processed: 507
# Processing tweet. ID = 1242828341419229184
#
# Current indx: 1294
# Tweets to be processed: 506
# Processing tweet. ID = 1242828430271336448
#
# Current indx: 1295
# Tweets to be processed: 505
# Processing tweet. ID = 1242828463116931076
#
# Current indx: 1296
# Tweets to be processed: 504
# Processing tweet. ID = 1242828533853859840
#
# Current indx: 1297
# Tweets to be processed: 503
# Processing tweet. ID = 1242828676279848966
#
# Current indx: 1298
# Tweets to be processed: 502
# Processing tweet. ID = 1242828728431861761
#
# Current indx: 1299
# Tweets to be processed: 501
# Processing tweet. ID = 1242828771637559300
# Text: just before announcing corona virus related counter measures,
# 5 to 7 Trump properties closed down operations- reports suggest
#
# that word 'control' leaves door open for manipulation https://t.co/hDUa0KnhV2
#
# Current indx: 1300
# Tweets to be processed: 500
# Processing tweet. ID = 1242828860875563012
#
# Current indx: 1301
# Tweets to be processed: 499
# Processing tweet. ID = 1242829013300596739
#
# Current indx: 1302
# Tweets to be processed: 498
# Processing tweet. ID = 1242829014349352962
#
# Current indx: 1303
# Tweets to be processed: 497
# Processing tweet. ID = 1242829039087173634
#
# Current indx: 1304
# Tweets to be processed: 496
# Processing tweet. ID = 1242829250945679367
#
# Current indx: 1305
# Tweets to be processed: 495
# Processing tweet. ID = 1242829304859201536
#
# Current indx: 1306
# Tweets to be processed: 494
# Processing tweet. ID = 1242829343287468032
#
# Current indx: 1307
# Tweets to be processed: 493
# Processing tweet. ID = 1242829408169127936
#
# Current indx: 1308
# Tweets to be processed: 492
# Processing tweet. ID = 1242829419716030464
#
# Current indx: 1309
# Tweets to be processed: 491
# Processing tweet. ID = 1242829441308344320
#
# Current indx: 1310
# Tweets to be processed: 490
# Processing tweet. ID = 1242829508551389192
#
# Current indx: 1311
# Tweets to be processed: 489
# Processing tweet. ID = 1242829578374017024
#
# Current indx: 1312
# Tweets to be processed: 488
# Processing tweet. ID = 1242829608178737153
#
# Current indx: 1313
# Tweets to be processed: 487
# Processing tweet. ID = 1242829616340967426
#
# Current indx: 1314
# Tweets to be processed: 486
# Processing tweet. ID = 1242829630844751873
#
# Current indx: 1315
# Tweets to be processed: 485
# Processing tweet. ID = 1242829658640408578
#
# Current indx: 1316
# Tweets to be processed: 484
# Processing tweet. ID = 1242829699803500547
#
# Current indx: 1317
# Tweets to be processed: 483
# Processing tweet. ID = 1242829746192310274
#
# Current indx: 1318
# Tweets to be processed: 482
# Processing tweet. ID = 1242829773446860800
#
# Current indx: 1319
# Tweets to be processed: 481
# Processing tweet. ID = 1242829890703015936
#
# Current indx: 1320
# Tweets to be processed: 480
# Processing tweet. ID = 1242829958944194560
#
# Current indx: 1321
# Tweets to be processed: 479
# Processing tweet. ID = 1242830120366354437
#
# Current indx: 1322
# Tweets to be processed: 478
# Processing tweet. ID = 1242830147599732737
#
# Current indx: 1323
# Tweets to be processed: 477
# Processing tweet. ID = 1242830215518154752
#
# Current indx: 1324
# Tweets to be processed: 476
# Processing tweet. ID = 1242830307952218112
#
# Current indx: 1325
# Tweets to be processed: 475
# Processing tweet. ID = 1242830473052565510
#
# Current indx: 1326
# Tweets to be processed: 474
# Processing tweet. ID = 1242830535690350593
#
# Current indx: 1327
# Tweets to be processed: 473
# Processing tweet. ID = 1242830543420444672
#
# Current indx: 1328
# Tweets to be processed: 472
# Processing tweet. ID = 1242830605047365633
#
# Current indx: 1329
# Tweets to be processed: 471
# Processing tweet. ID = 1242830690728566786
#
# Current indx: 1330
# Tweets to be processed: 470
# Processing tweet. ID = 1242830723062480903
#
# Current indx: 1331
# Tweets to be processed: 469
# Processing tweet. ID = 1242830872190922752
#
# Current indx: 1332
# Tweets to be processed: 468
# Processing tweet. ID = 1242830948007202818
#
# Current indx: 1333
# Tweets to be processed: 467
# Processing tweet. ID = 1242830962834075649
#
# Current indx: 1334
# Tweets to be processed: 466
# Processing tweet. ID = 1242831103435522049
#
# Current indx: 1335
# Tweets to be processed: 465
# Processing tweet. ID = 1242831240857673728
#
# Current indx: 1336
# Tweets to be processed: 464
# Processing tweet. ID = 1242831381421371392
#
# Current indx: 1337
# Tweets to be processed: 463
# Processing tweet. ID = 1242831480302125062
#
# Current indx: 1338
# Tweets to be processed: 462
# Processing tweet. ID = 1242831565069025282
#
# Current indx: 1339
# Tweets to be processed: 461
# Processing tweet. ID = 1242831641195749382
#
# Current indx: 1340
# Tweets to be processed: 460
# Processing tweet. ID = 1242831672548057089
#
# Current indx: 1341
# Tweets to be processed: 459
# Processing tweet. ID = 1242831707486724097
#
# Current indx: 1342
# Tweets to be processed: 458
# Processing tweet. ID = 1242831737689796608
#
# Current indx: 1343
# Tweets to be processed: 457
# Processing tweet. ID = 1242831775321096192
#
# Current indx: 1344
# Tweets to be processed: 456
# Processing tweet. ID = 1242831849140809728
#
# Current indx: 1345
# Tweets to be processed: 455
# Processing tweet. ID = 1242831884356214785
#
# Current indx: 1346
# Tweets to be processed: 454
# Processing tweet. ID = 1242831951502790659
#
# Current indx: 1347
# Tweets to be processed: 453
# Processing tweet. ID = 1242831965440499713
#
# Current indx: 1348
# Tweets to be processed: 452
# Processing tweet. ID = 1242832181107408898
#
# Current indx: 1349
# Tweets to be processed: 451
# Processing tweet. ID = 1242832238804418561
#
# Current indx: 1350
# Tweets to be processed: 450
# Processing tweet. ID = 1242832500180668419
#
# Current indx: 1351
# Tweets to be processed: 449
# Processing tweet. ID = 1242832559471394816
#
# Current indx: 1352
# Tweets to be processed: 448
# Processing tweet. ID = 1242832693059932160
#
# Current indx: 1353
# Tweets to be processed: 447
# Processing tweet. ID = 1242832721451220993
#
# Current indx: 1354
# Tweets to be processed: 446
# Processing tweet. ID = 1242832758214397952
#
# Current indx: 1355
# Tweets to be processed: 445
# Processing tweet. ID = 1242832829790076934
#
# Current indx: 1356
# Tweets to be processed: 444
# Processing tweet. ID = 1242832858965778433
#
# Current indx: 1357
# Tweets to be processed: 443
# Processing tweet. ID = 1242832874719477767
#
# Current indx: 1358
# Tweets to be processed: 442
# Processing tweet. ID = 1242833066428596226
#
# Current indx: 1359
# Tweets to be processed: 441
# Processing tweet. ID = 1242833203473403904
#
# Current indx: 1360
# Tweets to be processed: 440
# Processing tweet. ID = 1242833210788196356
#
# Current indx: 1361
# Tweets to be processed: 439
# Processing tweet. ID = 1242833211144556545
#
# Current indx: 1362
# Tweets to be processed: 438
# Processing tweet. ID = 1242833323728273408
#
# Current indx: 1363
# Tweets to be processed: 437
# Processing tweet. ID = 1242833469584977926
#
# Current indx: 1364
# Tweets to be processed: 436
# Processing tweet. ID = 1242833694286471168
#
# Current indx: 1365
# Tweets to be processed: 435
# Processing tweet. ID = 1242833803351076867
#
# Current indx: 1366
# Tweets to be processed: 434
# Processing tweet. ID = 1242833817229901824
#
# Current indx: 1367
# Tweets to be processed: 433
# Processing tweet. ID = 1242833833004679168
#
# Current indx: 1368
# Tweets to be processed: 432
# Processing tweet. ID = 1242833874331119621
#
# Current indx: 1369
# Tweets to be processed: 431
# Processing tweet. ID = 1242833924314632192
#
# Current indx: 1370
# Tweets to be processed: 430
# Processing tweet. ID = 1242833953360211968
#
# Current indx: 1371
# Tweets to be processed: 429
# Processing tweet. ID = 1242834002370691076
#
# Current indx: 1372
# Tweets to be processed: 428
# Processing tweet. ID = 1242834034482221056
#
# Current indx: 1373
# Tweets to be processed: 427
# Processing tweet. ID = 1242834049598541824
#
# Current indx: 1374
# Tweets to be processed: 426
# Processing tweet. ID = 1242834159464144896
#
# Current indx: 1375
# Tweets to be processed: 425
# Processing tweet. ID = 1242834171539513346
#
# Current indx: 1376
# Tweets to be processed: 424
# Processing tweet. ID = 1242834218557640704
#
# Current indx: 1377
# Tweets to be processed: 423
# Processing tweet. ID = 1242834247729078272
#
# Current indx: 1378
# Tweets to be processed: 422
# Processing tweet. ID = 1242834254280773635
#
# Current indx: 1379
# Tweets to be processed: 421
# Processing tweet. ID = 1242834276191580161
#
# Current indx: 1380
# Tweets to be processed: 420
# Processing tweet. ID = 1242834312350687239
#
# Current indx: 1381
# Tweets to be processed: 419
# Processing tweet. ID = 1242834330407161863
#
# Current indx: 1382
# Tweets to be processed: 418
# Processing tweet. ID = 1242834450896965632
#
# Current indx: 1383
# Tweets to be processed: 417
# Processing tweet. ID = 1242834559680393216
#
# Current indx: 1384
# Tweets to be processed: 416
# Processing tweet. ID = 1242834720829747202
#
# Current indx: 1385
# Tweets to be processed: 415
# Processing tweet. ID = 1242834743353323520
#
# Current indx: 1386
# Tweets to be processed: 414
# Processing tweet. ID = 1242834821690175488
#
# Current indx: 1387
# Tweets to be processed: 413
# Processing tweet. ID = 1242834824282308609
#
# Current indx: 1388
# Tweets to be processed: 412
# Processing tweet. ID = 1242834975080116225
#
# Current indx: 1389
# Tweets to be processed: 411
# Processing tweet. ID = 1242835229624041473
#
# Current indx: 1390
# Tweets to be processed: 410
# Processing tweet. ID = 1242835242899001351
#
# Current indx: 1391
# Tweets to be processed: 409
# Processing tweet. ID = 1242835290508521472
#
# Current indx: 1392
# Tweets to be processed: 408
# Processing tweet. ID = 1242835320023867394
#
# Current indx: 1393
# Tweets to be processed: 407
# Processing tweet. ID = 1242835419559010304
#
# Current indx: 1394
# Tweets to be processed: 406
# Processing tweet. ID = 1242835469760696320
#
# Current indx: 1395
# Tweets to be processed: 405
# Processing tweet. ID = 1242835535145709568
#
# Current indx: 1396
# Tweets to be processed: 404
# Processing tweet. ID = 1242835573045256192
#
# Current indx: 1397
# Tweets to be processed: 403
# Processing tweet. ID = 1242835617022533633
#
# Current indx: 1398
# Tweets to be processed: 402
# Processing tweet. ID = 1242835668033658880
#
# Current indx: 1399
# Tweets to be processed: 401
# Processing tweet. ID = 1242835673318449152
# Text: @iamsrk My sincere request to every indian to call Corona virus as CHINA  virus.  Let them reap what they have sown.  Let's pledge and make it movement to use CHINA virus rather than Corona.
#
# Current indx: 1400
# Tweets to be processed: 400
# Processing tweet. ID = 1242835813513084929
#
# Current indx: 1401
# Tweets to be processed: 399
# Processing tweet. ID = 1242835951476297728
#
# Current indx: 1402
# Tweets to be processed: 398
# Processing tweet. ID = 1242836146620694528
#
# Current indx: 1403
# Tweets to be processed: 397
# Processing tweet. ID = 1242836184176312320
#
# Current indx: 1404
# Tweets to be processed: 396
# Processing tweet. ID = 1242836199049322497
#
# Current indx: 1405
# Tweets to be processed: 395
# Processing tweet. ID = 1242836200710234114
#
# Current indx: 1406
# Tweets to be processed: 394
# Processing tweet. ID = 1242836236055662592
#
# Current indx: 1407
# Tweets to be processed: 393
# Processing tweet. ID = 1242836375042289666
#
# Current indx: 1408
# Tweets to be processed: 392
# Processing tweet. ID = 1242836400539676672
#
# Current indx: 1409
# Tweets to be processed: 391
# Processing tweet. ID = 1242836466306183168
#
# Current indx: 1410
# Tweets to be processed: 390
# Processing tweet. ID = 1242836543481319424
#
# Current indx: 1411
# Tweets to be processed: 389
# Processing tweet. ID = 1242836595067080706
#
# Current indx: 1412
# Tweets to be processed: 388
# Processing tweet. ID = 1242836725379944448
#
# Current indx: 1413
# Tweets to be processed: 387
# Processing tweet. ID = 1242836732547985408
#
# Current indx: 1414
# Tweets to be processed: 386
# Processing tweet. ID = 1242836821496565761
#
# Current indx: 1415
# Tweets to be processed: 385
# Processing tweet. ID = 1242836938417156098
#
# Current indx: 1416
# Tweets to be processed: 384
# Processing tweet. ID = 1242837220492378113
#
# Current indx: 1417
# Tweets to be processed: 383
# Processing tweet. ID = 1242837276914147330
#
# Current indx: 1418
# Tweets to be processed: 382
# Processing tweet. ID = 1242837319532462080
#
# Current indx: 1419
# Tweets to be processed: 381
# Processing tweet. ID = 1242837369197219842
#
# Current indx: 1420
# Tweets to be processed: 380
# Processing tweet. ID = 1242837477615788036
#
# Current indx: 1421
# Tweets to be processed: 379
# Processing tweet. ID = 1242837486079893504
#
# Current indx: 1422
# Tweets to be processed: 378
# Processing tweet. ID = 1242837533358206982
#
# Current indx: 1423
# Tweets to be processed: 377
# Processing tweet. ID = 1242837541167828994
#
# Current indx: 1424
# Tweets to be processed: 376
# Processing tweet. ID = 1242837923663237121
#
# Current indx: 1425
# Tweets to be processed: 375
# Processing tweet. ID = 1242837945616224257
#
# Current indx: 1426
# Tweets to be processed: 374
# Processing tweet. ID = 1242838076025524229
#
# Current indx: 1427
# Tweets to be processed: 373
# Processing tweet. ID = 1242838503810973701
#
# Current indx: 1428
# Tweets to be processed: 372
# Processing tweet. ID = 1242838543434645504
#
# Current indx: 1429
# Tweets to be processed: 371
# Processing tweet. ID = 1242838735848460289
#
# Current indx: 1430
# Tweets to be processed: 370
# Processing tweet. ID = 1242838819801403392
#
# Current indx: 1431
# Tweets to be processed: 369
# Processing tweet. ID = 1242838842962403328
#
# Current indx: 1432
# Tweets to be processed: 368
# Processing tweet. ID = 1242838858192093184
#
# Current indx: 1433
# Tweets to be processed: 367
# Processing tweet. ID = 1242838987024162818
#
# Current indx: 1434
# Tweets to be processed: 366
# Processing tweet. ID = 1242839065289875466
#
# Current indx: 1435
# Tweets to be processed: 365
# Processing tweet. ID = 1242839102463946757
#
# Current indx: 1436
# Tweets to be processed: 364
# Processing tweet. ID = 1242839179437858816
#
# Current indx: 1437
# Tweets to be processed: 363
# Processing tweet. ID = 1242839201025945601
#
# Current indx: 1438
# Tweets to be processed: 362
# Processing tweet. ID = 1242839358878564352
#
# Current indx: 1439
# Tweets to be processed: 361
# Processing tweet. ID = 1242839388486340609
#
# Current indx: 1440
# Tweets to be processed: 360
# Processing tweet. ID = 1242839481146683397
#
# Current indx: 1441
# Tweets to be processed: 359
# Processing tweet. ID = 1242839582908899330
#
# Current indx: 1442
# Tweets to be processed: 358
# Processing tweet. ID = 1242839715272892418
#
# Current indx: 1443
# Tweets to be processed: 357
# Processing tweet. ID = 1242839742770597889
#
# Current indx: 1444
# Tweets to be processed: 356
# Processing tweet. ID = 1242839860886376448
#
# Current indx: 1445
# Tweets to be processed: 355
# Processing tweet. ID = 1242839865340743680
#
# Current indx: 1446
# Tweets to be processed: 354
# Processing tweet. ID = 1242839871955152897
#
# Current indx: 1447
# Tweets to be processed: 353
# Processing tweet. ID = 1242839899243286533
#
# Current indx: 1448
# Tweets to be processed: 352
# Processing tweet. ID = 1242839941299580929
#
# Current indx: 1449
# Tweets to be processed: 351
# Processing tweet. ID = 1242840050917871617
#
# Current indx: 1450
# Tweets to be processed: 350
# Processing tweet. ID = 1242840075404054529
#
# Current indx: 1451
# Tweets to be processed: 349
# Processing tweet. ID = 1242840096392396801
#
# Current indx: 1452
# Tweets to be processed: 348
# Processing tweet. ID = 1242840310356439043
#
# Current indx: 1453
# Tweets to be processed: 347
# Processing tweet. ID = 1242840333626429441
#
# Current indx: 1454
# Tweets to be processed: 346
# Processing tweet. ID = 1242840340832256002
#
# Current indx: 1455
# Tweets to be processed: 345
# Processing tweet. ID = 1242840407697788930
#
# Current indx: 1456
# Tweets to be processed: 344
# Processing tweet. ID = 1242840559288324099
#
# Current indx: 1457
# Tweets to be processed: 343
# Processing tweet. ID = 1242840744907309056
#
# Current indx: 1458
# Tweets to be processed: 342
# Processing tweet. ID = 1242841113666478080
#
# Current indx: 1459
# Tweets to be processed: 341
# Processing tweet. ID = 1242841198336729088
#
# Current indx: 1460
# Tweets to be processed: 340
# Processing tweet. ID = 1242841211209220096
#
# Current indx: 1461
# Tweets to be processed: 339
# Processing tweet. ID = 1242841239017250816
#
# Current indx: 1462
# Tweets to be processed: 338
# Processing tweet. ID = 1242841295812317184
#
# Current indx: 1463
# Tweets to be processed: 337
# Processing tweet. ID = 1242841503661281281
#
# Current indx: 1464
# Tweets to be processed: 336
# Processing tweet. ID = 1242841583738740736
#
# Current indx: 1465
# Tweets to be processed: 335
# Processing tweet. ID = 1242841637438418945
#
# Current indx: 1466
# Tweets to be processed: 334
# Processing tweet. ID = 1242841642626768898
#
# Current indx: 1467
# Tweets to be processed: 333
# Processing tweet. ID = 1242841794074869765
#
# Current indx: 1468
# Tweets to be processed: 332
# Processing tweet. ID = 1242841809891610627
#
# Current indx: 1469
# Tweets to be processed: 331
# Processing tweet. ID = 1242841830422507521
#
# Current indx: 1470
# Tweets to be processed: 330
# Processing tweet. ID = 1242841926811783170
#
# Current indx: 1471
# Tweets to be processed: 329
# Processing tweet. ID = 1242841943614410755
#
# Current indx: 1472
# Tweets to be processed: 328
# Processing tweet. ID = 1242841960915726337
#
# Current indx: 1473
# Tweets to be processed: 327
# Processing tweet. ID = 1242842009146208258
#
# Current indx: 1474
# Tweets to be processed: 326
# Processing tweet. ID = 1242842321835536385
#
# Current indx: 1475
# Tweets to be processed: 325
# Processing tweet. ID = 1242842435782238208
#
# Current indx: 1476
# Tweets to be processed: 324
# Processing tweet. ID = 1242842448839106561
#
# Current indx: 1477
# Tweets to be processed: 323
# Processing tweet. ID = 1242842480015360001
#
# Current indx: 1478
# Tweets to be processed: 322
# Processing tweet. ID = 1242842514282987520
#
# Current indx: 1479
# Tweets to be processed: 321
# Processing tweet. ID = 1242842582939357184
#
# Current indx: 1480
# Tweets to be processed: 320
# Processing tweet. ID = 1242842767841054722
#
# Current indx: 1481
# Tweets to be processed: 319
# Processing tweet. ID = 1242842921851748354
#
# Current indx: 1482
# Tweets to be processed: 318
# Processing tweet. ID = 1242842978919624704
#
# Current indx: 1483
# Tweets to be processed: 317
# Processing tweet. ID = 1242843228841353216
#
# Current indx: 1484
# Tweets to be processed: 316
# Processing tweet. ID = 1242843349788196864
#
# Current indx: 1485
# Tweets to be processed: 315
# Processing tweet. ID = 1242843356482301952
# Error while accessing tweet. ID: 1242843356482301952
#
# Current indx: 1486
# Tweets to be processed: 314
# Processing tweet. ID = 1242843491845079040
#
# Current indx: 1487
# Tweets to be processed: 313
# Processing tweet. ID = 1242843710078865408
#
# Current indx: 1488
# Tweets to be processed: 312
# Processing tweet. ID = 1242843718031306753
#
# Current indx: 1489
# Tweets to be processed: 311
# Processing tweet. ID = 1242843737593503744
#
# Current indx: 1490
# Tweets to be processed: 310
# Processing tweet. ID = 1242843747878162432
#
# Current indx: 1491
# Tweets to be processed: 309
# Processing tweet. ID = 1242843816106668039
#
# Current indx: 1492
# Tweets to be processed: 308
# Processing tweet. ID = 1242844050396344320
#
# Current indx: 1493
# Tweets to be processed: 307
# Processing tweet. ID = 1242844286435168256
#
# Current indx: 1494
# Tweets to be processed: 306
# Processing tweet. ID = 1242844318563328000
#
# Current indx: 1495
# Tweets to be processed: 305
# Processing tweet. ID = 1242844343351808004
#
# Current indx: 1496
# Tweets to be processed: 304
# Processing tweet. ID = 1242844359336198145
#
# Current indx: 1497
# Tweets to be processed: 303
# Processing tweet. ID = 1242844482346733568
#
# Current indx: 1498
# Tweets to be processed: 302
# Processing tweet. ID = 1242844534595297280
#
# Current indx: 1499
# Tweets to be processed: 301
# Processing tweet. ID = 1242844545928146944
# Text: @PMOIndia  For checking  CORONA, hot water treatment before santization  and cleaning the utensils of kitchen and also surrounding with hot water may be one of the best remedy as hot water almost kills all pathogens . Hot water is easily accessible to all  and economical
#
# Current indx: 1500
# Tweets to be processed: 300
# Processing tweet. ID = 1242844587577626633
#
# Current indx: 1501
# Tweets to be processed: 299
# Processing tweet. ID = 1242844622306439173
#
# Current indx: 1502
# Tweets to be processed: 298
# Processing tweet. ID = 1242844740598534144
#
# Current indx: 1503
# Tweets to be processed: 297
# Processing tweet. ID = 1242844791286743042
#
# Current indx: 1504
# Tweets to be processed: 296
# Processing tweet. ID = 1242844867140583430
#
# Current indx: 1505
# Tweets to be processed: 295
# Processing tweet. ID = 1242844880310657024
#
# Current indx: 1506
# Tweets to be processed: 294
# Processing tweet. ID = 1242844939945459713
#
# Current indx: 1507
# Tweets to be processed: 293
# Processing tweet. ID = 1242845110003314690
#
# Current indx: 1508
# Tweets to be processed: 292
# Processing tweet. ID = 1242845229394190337
#
# Current indx: 1509
# Tweets to be processed: 291
# Processing tweet. ID = 1242845286717779969
#
# Current indx: 1510
# Tweets to be processed: 290
# Processing tweet. ID = 1242845376073199618
#
# Current indx: 1511
# Tweets to be processed: 289
# Processing tweet. ID = 1242845406330933248
#
# Current indx: 1512
# Tweets to be processed: 288
# Processing tweet. ID = 1242845412634968066
#
# Current indx: 1513
# Tweets to be processed: 287
# Processing tweet. ID = 1242845416879616002
#
# Current indx: 1514
# Tweets to be processed: 286
# Processing tweet. ID = 1242845528762679303
#
# Current indx: 1515
# Tweets to be processed: 285
# Processing tweet. ID = 1242845554586947584
#
# Current indx: 1516
# Tweets to be processed: 284
# Processing tweet. ID = 1242845715220463617
#
# Current indx: 1517
# Tweets to be processed: 283
# Processing tweet. ID = 1242845758006505474
#
# Current indx: 1518
# Tweets to be processed: 282
# Processing tweet. ID = 1242845883378487296
#
# Current indx: 1519
# Tweets to be processed: 281
# Processing tweet. ID = 1242845964391419904
#
# Current indx: 1520
# Tweets to be processed: 280
# Processing tweet. ID = 1242846032062365703
#
# Current indx: 1521
# Tweets to be processed: 279
# Processing tweet. ID = 1242846094431621122
#
# Current indx: 1522
# Tweets to be processed: 278
# Processing tweet. ID = 1242846112932941825
#
# Current indx: 1523
# Tweets to be processed: 277
# Processing tweet. ID = 1242846341392285696
#
# Current indx: 1524
# Tweets to be processed: 276
# Processing tweet. ID = 1242846360375713792
#
# Current indx: 1525
# Tweets to be processed: 275
# Processing tweet. ID = 1242846431003566081
#
# Current indx: 1526
# Tweets to be processed: 274
# Processing tweet. ID = 1242846800538525696
#
# Current indx: 1527
# Tweets to be processed: 273
# Processing tweet. ID = 1242847316303695873
#
# Current indx: 1528
# Tweets to be processed: 272
# Processing tweet. ID = 1242847491940159489
#
# Current indx: 1529
# Tweets to be processed: 271
# Processing tweet. ID = 1242847536794210305
#
# Current indx: 1530
# Tweets to be processed: 270
# Processing tweet. ID = 1242847559980167168
#
# Current indx: 1531
# Tweets to be processed: 269
# Processing tweet. ID = 1242847728310161408
#
# Current indx: 1532
# Tweets to be processed: 268
# Processing tweet. ID = 1242847855947034626
#
# Current indx: 1533
# Tweets to be processed: 267
# Processing tweet. ID = 1242847974583042049
#
# Current indx: 1534
# Tweets to be processed: 266
# Processing tweet. ID = 1242847993788678145
#
# Current indx: 1535
# Tweets to be processed: 265
# Processing tweet. ID = 1242848017872453634
#
# Current indx: 1536
# Tweets to be processed: 264
# Processing tweet. ID = 1242848020892233733
#
# Current indx: 1537
# Tweets to be processed: 263
# Processing tweet. ID = 1242848078844940288
#
# Current indx: 1538
# Tweets to be processed: 262
# Processing tweet. ID = 1242848113104019457
#
# Current indx: 1539
# Tweets to be processed: 261
# Processing tweet. ID = 1242848197115928577
#
# Current indx: 1540
# Tweets to be processed: 260
# Processing tweet. ID = 1242848205156433926
#
# Current indx: 1541
# Tweets to be processed: 259
# Processing tweet. ID = 1242848293253595136
#
# Current indx: 1542
# Tweets to be processed: 258
# Processing tweet. ID = 1242848490868183041
#
# Current indx: 1543
# Tweets to be processed: 257
# Processing tweet. ID = 1242848529011200001
#
# Current indx: 1544
# Tweets to be processed: 256
# Processing tweet. ID = 1242848538293202944
#
# Current indx: 1545
# Tweets to be processed: 255
# Processing tweet. ID = 1242848764060028929
#
# Current indx: 1546
# Tweets to be processed: 254
# Processing tweet. ID = 1242848962589216775
#
# Current indx: 1547
# Tweets to be processed: 253
# Processing tweet. ID = 1242849051495694336
#
# Current indx: 1548
# Tweets to be processed: 252
# Processing tweet. ID = 1242849354722902016
#
# Current indx: 1549
# Tweets to be processed: 251
# Processing tweet. ID = 1242849508284936192
#
# Current indx: 1550
# Tweets to be processed: 250
# Processing tweet. ID = 1242849508301500418
#
# Current indx: 1551
# Tweets to be processed: 249
# Processing tweet. ID = 1242849577796907008
#
# Current indx: 1552
# Tweets to be processed: 248
# Processing tweet. ID = 1242849599619887106
#
# Current indx: 1553
# Tweets to be processed: 247
# Processing tweet. ID = 1242850019822063616
#
# Current indx: 1554
# Tweets to be processed: 246
# Processing tweet. ID = 1242850083353161728
#
# Current indx: 1555
# Tweets to be processed: 245
# Processing tweet. ID = 1242850130228850688
#
# Current indx: 1556
# Tweets to be processed: 244
# Processing tweet. ID = 1242850200575565824
#
# Current indx: 1557
# Tweets to be processed: 243
# Processing tweet. ID = 1242850234083856384
#
# Current indx: 1558
# Tweets to be processed: 242
# Processing tweet. ID = 1242850340539486208
#
# Current indx: 1559
# Tweets to be processed: 241
# Processing tweet. ID = 1242850775841177601
#
# Current indx: 1560
# Tweets to be processed: 240
# Processing tweet. ID = 1242850802131075072
#
# Current indx: 1561
# Tweets to be processed: 239
# Processing tweet. ID = 1242850870468861952
#
# Current indx: 1562
# Tweets to be processed: 238
# Processing tweet. ID = 1242850969353728007
#
# Current indx: 1563
# Tweets to be processed: 237
# Processing tweet. ID = 1242851145652916229
#
# Current indx: 1564
# Tweets to be processed: 236
# Processing tweet. ID = 1242851173477912576
#
# Current indx: 1565
# Tweets to be processed: 235
# Processing tweet. ID = 1242851325064310790
#
# Current indx: 1566
# Tweets to be processed: 234
# Processing tweet. ID = 1242851358144737281
#
# Current indx: 1567
# Tweets to be processed: 233
# Processing tweet. ID = 1242851395398545408
#
# Current indx: 1568
# Tweets to be processed: 232
# Processing tweet. ID = 1242851408346361856
#
# Current indx: 1569
# Tweets to be processed: 231
# Processing tweet. ID = 1242851428554534914
#
# Current indx: 1570
# Tweets to be processed: 230
# Processing tweet. ID = 1242851562315223041
#
# Current indx: 1571
# Tweets to be processed: 229
# Processing tweet. ID = 1242851575443279875
#
# Current indx: 1572
# Tweets to be processed: 228
# Processing tweet. ID = 1242851734067671041
# Error while accessing tweet. ID: 1242851734067671041
#
# Current indx: 1573
# Tweets to be processed: 227
# Processing tweet. ID = 1242851964884566019
#
# Current indx: 1574
# Tweets to be processed: 226
# Processing tweet. ID = 1242852098577813505

# %%
indx_manager_write = open('index_manager.txt', 'w')
indx_manager_write.write(str(indx))
indx_manager_write.close()
print(str(indx))
# Out:
# 900

# %%
text_2 = text
for ttext in text:
    ttext = ttext.strip("\n")

# %%
#         text.append(tweet.full_text)
#         created_at.append(tweet.created_at)
#         id_str.append(tweet.id_str)
#         entities.append(tweet.entities)
#         user_id.append(tweet.user.id)
#         location.append(tweet.user.location)
#         lang.append(tweet.lang)
#         time_zone.append(tweet.user.time_zone)

# for loc in location[:10]:
#     print(loc)
# Out:
# India
#
# India
# India
# Brunswick, Germany
#
# Narayanpet, India
# Kolkata
# New Delhi,Mumbai,India,Dubai..

# %%
import pandas as pd

# df = pd.DataFrame(columns=['id_str', 'user_id', 'text', 'created_at', 'entities', 'location', 'lang', 'time_zone'])
df = pd.DataFrame(columns=['id_str', 'user_id', 'text', 'created_at', 'entities', 'lang', 'time_zone'])
df.head()

df['id_str'] = id_str
df['user_id'] = user_id
df['text'] = text
df['created_at'] = created_at
df['entities'] = entities
# df['location'] = location
df['lang'] = lang
df['time_zone'] = time_zone

# %%
df.head()
# Out:
#                 id_str              user_id  \
# 0  1242693402971406342  1211110380249858049
# 1  1242693578817597442           2558507150
# 2  1242693609725575168  1242691555628060672
# 3  1242693680143544325   787255787961872388
# 4  1242693745755262977  1230923356519555072
#
#                                                 text          created_at  \
# 0  CORONA 19 UPDATE \n---------------------------... 2020-03-25 06:02:50
# 1  Anti Corona T-shirt collection is online for s... 2020-03-25 06:03:31
# 2  The matter is serious. Take full care not to b... 2020-03-25 06:03:39
# 3  All Mosque committee members headed by Syed Ga... 2020-03-25 06:03:56
# 4  @aajtak If these Indians are already infected ... 2020-03-25 06:04:11
#
#                                             entities lang time_zone
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...   en      None
# 1  {'hashtags': [{'text': '21daysLockdown', 'indi...   en      None
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...   en      None
# 3  {'hashtags': [{'text': 'Narayanpet', 'indices'...   en      None
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...   en      None

# %%
# file_new = open('file_manager.txt', 'r')
# file_indx = file_new.read()
# file_new.close()
# filename = 'final_tweets_' + file_indx + '.csv'
filename = 'final_tweets_1.csv'
print(filename)
# Out:
# final_tweets_1.csv

# %%
df.to_csv(filename)

# %%
file_indx = int(file_indx)
file_indx += 1

file_write = open('file_manager.txt', 'w')
file_write.write(str(file_indx))
file_write.close()

# %%
print(file_indx)
# Out:
# 2

# %%
######## DO NOT RUN #################


# print("writing to dataset")
# with open("tweets.txt", "w+") as f:
#     for tweet in tweets:
#         print("writing to txt file. tweet: " + str(tweet))
#         f.write("%s\n" % str(tweet))
        
# print("writing to dataset")
# with open("dates.txt", "w+") as f:
#     for date in dates:
#         print("writing to txt file. tweet: " + str(date))
#         f.write("%s\n" % str(date))

# %%
id_t = tweets_df['tweet_id'].tolist()[1]
tweet_2 = api.get_status(id_t, tweet_mode = 'extended')
print(tweet_2.full_text)
# Out:
# CORONA 19 UPDATE
# ----------------------------------------------------------
# Total effected : 420000
# Recovered : 107000
# Fatality : 18500
# Under Treatment : ( 420000-107000) = 313000
# Fatality Rate = 18500/420000×100=  4.4 %
# UT Rate = 74.52%
#
# GLOBAL FIGURE
